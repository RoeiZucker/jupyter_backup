# %%
import pandas as pd
import numpy as np

# %%
DISCRIPTION_FILE_PATH = "/cs/labs/michall/roeizucker/phewas_run/discription10.csv"
PHENS =[
    "Phecode_714.1",
    "Phecode_696.4",
    "Phecode_557.1",
    "Phecode_250.1",
    "Phecode_335.0",
    "Phecode_358.1",
    "Phecode_245.0",
    "Phecode_242.1",
    "Phecode_555.1",
    "Phecode_645.22",
    "Phecode_694.2",
    "Phecode_695.42",
    "Phecode_495.0",
    "Phecode_704.1"    
]
ICD10_FILE_PATH = '/cs/labs/michall/roeizucker/phewas_run/phecode_icd10.csv'

RESULT_FILE_NAME = "AID_basic_table_with_name.csv"

for phen in PHENS[:]:
    PHENS.append(phen + "_M")
    PHENS.append(phen + "_F")

# %%
discription_df = pd.read_csv(DISCRIPTION_FILE_PATH)
discription_df["other_name"] = discription_df["name"].str.replace("_M","")
discription_df["other_name"] = discription_df["other_name"].str.replace("_F","")
discription_df = discription_df.sort_values(by="name")
# discription_df

# %%
df = discription_df[discription_df["name"].isin(PHENS)]
# print(df)
# print(df)
df = (df.groupby(['other_name','icd_codes','dataset_path'])
      .agg({
          'num_of_cases': lambda x: x.tolist(),
          "num_of_controls":lambda x: x.tolist(),
          "num_relevant_genes":lambda x: x.tolist(),
          
      }))

df[["num_of_cases_B","num_of_cases_F","num_of_cases_M"]] = pd.DataFrame(df["num_of_cases"].tolist(),index=df.index)
df[["num_of_controls_B","num_of_controls_F","num_of_controls_M"]] = pd.DataFrame(df["num_of_controls"].tolist(),index=df.index)
df[["num_relevant_genes_B","num_relevant_genes_F","num_relevant_genes_M"]] = pd.DataFrame(df["num_relevant_genes"].tolist(),index=df.index)

df_final = df.drop(["num_of_cases","num_of_controls","num_relevant_genes"],axis=1).reset_index()
df_final
# Out:
#         other_name                                          icd_codes  \
# 0    Phecode_242.1                                           ['E050']
# 1    Phecode_245.0                            ['E069'; 'E064'; 'E06']
# 2    Phecode_250.1    ['E108'; 'E106'; 'E100'; 'E10'; 'E109'; 'E107']
# 3    Phecode_335.0                                            ['G35']
# 4    Phecode_358.1                                           ['G700']
# 5    Phecode_495.0            ['J45'; 'J450'; 'J451'; 'J458'; 'J459']
# 6    Phecode_555.1            ['K508'; 'K500'; 'K509'; 'K50'; 'K501']
# 7    Phecode_557.1                                   ['K901'; 'K900']
# 8    Phecode_694.1                                            ['L80']
# 9    Phecode_694.1                                            ['L80']
# 10   Phecode_694.2  ['L817'; 'L818'; 'L819'; 'L81'; 'L810'; 'L811'...
# 11  Phecode_695.42            ['M32'; 'M321'; 'M328'; 'M329'; 'M320']
# 12   Phecode_696.4                                    ['L409'; 'L40']
# 13   Phecode_704.1  ['L669'; 'L662'; 'L660'; 'L66'; 'L659'; 'L658'...
# 14   Phecode_714.1  ['J990'; 'M051'; 'M063'; 'M062'; 'M061'; 'M060...
#
#                                          dataset_path  num_of_cases_B  \
# 0   /cs/labs/michall/roeizucker/phewas_run/runs1/5...             414
# 1   /cs/labs/michall/roeizucker/phewas_run/runs1/5...             284
# 2   /cs/labs/michall/roeizucker/phewas_run/runs1/6...            2563
# 3   /cs/labs/michall/roeizucker/phewas_run/runs1/1...            1205
# 4   /cs/labs/michall/roeizucker/phewas_run/runs1/1...             174
# 5   /cs/labs/michall/roeizucker/phewas_run/runs1/2...           24574
# 6   /cs/labs/michall/roeizucker/phewas_run/runs1/2...            1564
# 7   /cs/labs/michall/roeizucker/phewas_run/runs1/2...            1714
# 8   /cs/labs/michall/roeizucker/phewas_run/runs1/3...              62
# 9   /cs/labs/michall/roeizucker/phewas_run/runs1/3...              45
# 10  /cs/labs/michall/roeizucker/phewas_run/runs1/3...             765
# 11  /cs/labs/michall/roeizucker/phewas_run/runs1/3...             312
# 12  /cs/labs/michall/roeizucker/phewas_run/runs1/3...            2233
# 13  /cs/labs/michall/roeizucker/phewas_run/runs1/3...             130
# 14  /cs/labs/michall/roeizucker/phewas_run/runs1/3...            4259
#
#     num_of_cases_F  num_of_cases_M  num_of_controls_B  num_of_controls_F  \
# 0            334.0            80.0             274410           148849.0
# 1            253.0            31.0             274540           148930.0
# 2           1042.0          1521.0             272261           148141.0
# 3            880.0           325.0             273619           148303.0
# 4             89.0            85.0             274650           149094.0
# 5          14711.0          9863.0             250250           134472.0
# 6            887.0           677.0             273260           148296.0
# 7           1103.0           611.0             273110           148080.0
# 8              NaN             NaN             274762                NaN
# 9             17.0             NaN             149138           125624.0
# 10           470.0           295.0             274059           148713.0
# 11           262.0            50.0             274512           148921.0
# 12          1030.0          1203.0             272591           148153.0
# 13           107.0            23.0             274694           149076.0
# 14          2889.0          1370.0             270565           146294.0
#
#     num_of_controls_M  num_relevant_genes_B  num_relevant_genes_F  \
# 0            125561.0                    35                  23.0
# 1            125610.0                    13                  13.0
# 2            124120.0                    71                  48.0
# 3            125316.0                    37                  34.0
# 4            125556.0                    16                  -1.0
# 5            115778.0                    27                   9.0
# 6            124964.0                     3                   1.0
# 7            125030.0                   136                 124.0
# 8                 NaN                    -1                   NaN
# 9                 NaN                    -1                  -1.0
# 10           125346.0                     7                   0.0
# 11           125591.0                    52                  27.0
# 12           124438.0                    58                  29.0
# 13           125618.0                    -1                  -1.0
# 14           124271.0                    28                  15.0
#
#     num_relevant_genes_M
# 0                   -1.0
# 1                   -1.0
# 2                   28.0
# 3                    9.0
# 4                   -1.0
# 5                    9.0
# 6                    6.0
# 7                  109.0
# 8                    NaN
# 9                    NaN
# 10                  13.0
# 11                  -1.0
# 12                  44.0
# 13                  -1.0
# 14                  17.0

# %%
names_df = pd.read_csv(ICD10_FILE_PATH)
names_df = names_df[["PheCode","Phenotype"]]
# names_df["PheCode"] = names_df["PheCode"].astype(str)
names_dict = names_df.set_index("PheCode").to_dict()
print(names_dict["Phenotype"][8.0])
# Out:
# Intestinal infection

# %%
df_final["phenotype"] = df_final["other_name"].apply(lambda x: names_dict["Phenotype"][float(str(x).split("_")[1])])

# %%
df_final.to_csv(RESULT_FILE_NAME)

# %%
res = []
for val in list(df_final["icd_codes"]):
    res.extend(val.replace("'","").replace("[","").replace("]","").replace(" ","").split(";"))
for i in range(len(res)):
    if len(res[i]) >=4:
        res[i] = (res[i][:3] + "." + res[i][3:])

# %%
dic = {}
for val in res:
    if val not in dic:
        dic[val] = 0
    dic[val]+=1
# dic

# %%
df_final
# Out:
#         other_name                                          icd_codes  \
# 0    Phecode_242.1                                           ['E050']
# 1    Phecode_245.0                            ['E069'; 'E064'; 'E06']
# 2    Phecode_250.1    ['E108'; 'E106'; 'E100'; 'E10'; 'E109'; 'E107']
# 3    Phecode_335.0                                            ['G35']
# 4    Phecode_358.1                                           ['G700']
# 5    Phecode_495.0            ['J45'; 'J450'; 'J451'; 'J458'; 'J459']
# 6    Phecode_555.1            ['K508'; 'K500'; 'K509'; 'K50'; 'K501']
# 7    Phecode_557.1                                   ['K901'; 'K900']
# 8    Phecode_694.1                                            ['L80']
# 9    Phecode_694.1                                            ['L80']
# 10   Phecode_694.2  ['L817'; 'L818'; 'L819'; 'L81'; 'L810'; 'L811'...
# 11  Phecode_695.42            ['M32'; 'M321'; 'M328'; 'M329'; 'M320']
# 12   Phecode_696.4                                    ['L409'; 'L40']
# 13   Phecode_704.1  ['L669'; 'L662'; 'L660'; 'L66'; 'L659'; 'L658'...
# 14   Phecode_714.1  ['J990'; 'M051'; 'M063'; 'M062'; 'M061'; 'M060...
#
#                                          dataset_path  num_of_cases_B  \
# 0   /cs/labs/michall/roeizucker/phewas_run/runs1/5...             414
# 1   /cs/labs/michall/roeizucker/phewas_run/runs1/5...             284
# 2   /cs/labs/michall/roeizucker/phewas_run/runs1/6...            2563
# 3   /cs/labs/michall/roeizucker/phewas_run/runs1/1...            1205
# 4   /cs/labs/michall/roeizucker/phewas_run/runs1/1...             174
# 5   /cs/labs/michall/roeizucker/phewas_run/runs1/2...           24574
# 6   /cs/labs/michall/roeizucker/phewas_run/runs1/2...            1564
# 7   /cs/labs/michall/roeizucker/phewas_run/runs1/2...            1714
# 8   /cs/labs/michall/roeizucker/phewas_run/runs1/3...              62
# 9   /cs/labs/michall/roeizucker/phewas_run/runs1/3...              45
# 10  /cs/labs/michall/roeizucker/phewas_run/runs1/3...             765
# 11  /cs/labs/michall/roeizucker/phewas_run/runs1/3...             312
# 12  /cs/labs/michall/roeizucker/phewas_run/runs1/3...            2233
# 13  /cs/labs/michall/roeizucker/phewas_run/runs1/3...             130
# 14  /cs/labs/michall/roeizucker/phewas_run/runs1/3...            4259
#
#     num_of_cases_F  num_of_cases_M  num_of_controls_B  num_of_controls_F  \
# 0            334.0            80.0             274410           148849.0
# 1            253.0            31.0             274540           148930.0
# 2           1042.0          1521.0             272261           148141.0
# 3            880.0           325.0             273619           148303.0
# 4             89.0            85.0             274650           149094.0
# 5          14711.0          9863.0             250250           134472.0
# 6            887.0           677.0             273260           148296.0
# 7           1103.0           611.0             273110           148080.0
# 8              NaN             NaN             274762                NaN
# 9             17.0             NaN             149138           125624.0
# 10           470.0           295.0             274059           148713.0
# 11           262.0            50.0             274512           148921.0
# 12          1030.0          1203.0             272591           148153.0
# 13           107.0            23.0             274694           149076.0
# 14          2889.0          1370.0             270565           146294.0
#
#     num_of_controls_M  num_relevant_genes_B  num_relevant_genes_F  \
# 0            125561.0                    35                  23.0
# 1            125610.0                    13                  13.0
# 2            124120.0                    71                  48.0
# 3            125316.0                    37                  34.0
# 4            125556.0                    16                  -1.0
# 5            115778.0                    27                   9.0
# 6            124964.0                     3                   1.0
# 7            125030.0                   136                 124.0
# 8                 NaN                    -1                   NaN
# 9                 NaN                    -1                  -1.0
# 10           125346.0                     7                   0.0
# 11           125591.0                    52                  27.0
# 12           124438.0                    58                  29.0
# 13           125618.0                    -1                  -1.0
# 14           124271.0                    28                  15.0
#
#     num_relevant_genes_M                     phenotype
# 0                   -1.0               Graves' disease
# 1                   -1.0                   Thyroiditis
# 2                   28.0               Type 1 diabetes
# 3                    9.0            Multiple sclerosis
# 4                   -1.0             Myasthenia gravis
# 5                    9.0                        Asthma
# 6                    6.0            Regional enteritis
# 7                  109.0                Celiac disease
# 8                    NaN                      Vitiligo
# 9                    NaN                      Vitiligo
# 10                  13.0              Other dyschromia
# 11                  -1.0  Systemic lupus erythematosus
# 12                  44.0                     Psoriasis
# 13                  -1.0                      Alopecia
# 14                  17.0          Rheumatoid arthritis
