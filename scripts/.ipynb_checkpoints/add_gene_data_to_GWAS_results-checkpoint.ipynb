# %%
# jupyter imports
from IPython.display import clear_output

# %%
import pandas as pd

# %%
FILE_TO_ADD_PATH =  '/cs/labs/michall/roeizucker/IIH/GWAS2/results/IIH_mod.csv'
FILE_TO_CREATE_PATH = '/cs/labs/michall/roeizucker/IIH/GWAS2/results/IIH_mod_with_genes.csv'
GENE_FILE_PATH = '/cs/labs/michall/roeizucker/virt_env_install_test/genes_hg19.csv'
WORK_ONLY_FOR_RES_VARIANTS = True

# %%
CHR_SYMBOL = "#CHROM"
POS_SYMBOL = "POS"
PVAL_SYMBOL = "P"

# %%
    # def add_genes_for_snps_symbol(df,genes_csv):
#     df_length = len(df)
#     sig_genes = set()
#     for index, row in df.iterrows():
#         if index % 1000 == 0:
#             print(f"{index}/{df_length}")
#         curr = (genes_csv.query("chr == '" + str(row[CHR_SYMBOL]) + "' and cds_start <= " + str(row[POS_SYMBOL]) + "and cds_end >= " + str(row[POS_SYMBOL])))
#         if len(list(curr["symbol"])) == 0:
#             df.loc[index,"gene"] = "no gene found"
#             df.loc[index,"length"] = -1
#         else:
#             df.loc[index,"gene_symbol"] = str(list(curr["symbol"])[0])
#             df.loc[index,"uniprot_id"] = str(list(curr["uniprot_id"])[0])
#             df.loc[index,"length"] = int(list(curr["cds_end"])[0]) - int(list(curr["cds_start"])[0])
#             df.loc[index,"name"] = str(list(curr["name"])[0])

# %%
def add_genes_for_snps_symbol(df,genes_csv):
    df_length = len(genes_csv)
    df["gene_symbol"] = "no_gene_found"
    df["length"] = -1
    for index, row in genes_csv.iterrows():
        if index % 100 == 0:
            clear_output(wait=True)
            print(str(int(index/df_length * 100)) + "%")
        condition = (df["#CHROM"].astype(str) == str(row['chr'])) & (df["POS"].astype(int) >= int(row["cds_start"]))  & (df["POS"].astype(int) <= int(row["cds_end"]))
        df.loc[condition, "gene_symbol"] = row["symbol"]
        df.loc[condition, "uniprot_id"] = row["uniprot_id"]
        df.loc[condition, "length"] = int( int(row["cds_end"] - row["cds_start"]))
        df.loc[condition, "name"] = row["name"]

# %%
df = pd.read_csv(FILE_TO_ADD_PATH)
if WORK_ONLY_FOR_RES_VARIANTS:
    df = df[df[PVAL_SYMBOL].notnull()]
genes_df = pd.read_csv(GENE_FILE_PATH)
add_genes_for_snps_symbol(df,genes_df)
df["length"] = df["length"].astype(int)
df.to_csv(FILE_TO_CREATE_PATH)
# Out:
# 99%

# %%
df[df["P"] < 0.00005]
# Out:
#         #CHROM       POS           ID REF ALT A1 TEST  OBS_CT        OR  \
# 186          1   1007633  rs533904118   A   G  A  ADD  266098   63.6110
# 209          1   1025796  rs145234046   T   C  T  ADD  264840   71.9070
# 487          1   1271710  rs374846579   A   C  A  ADD  266068  234.7670
# 653          1   1423256  rs148709813   G   A  G  ADD  266047  112.8050
# 859          1   2253010  rs201084172   T   C  T  ADD  265669   63.5823
# ...        ...       ...          ...  ..  .. ..  ...     ...       ...
# 289248      22  46631108    rs9615759   T   A  T  ADD  266045   79.0387
# 289416      22  46785308  rs186625018   A   G  A  ADD  265916  256.2240
# 289744      22  50659135  rs546577072   C   A  C  ADD  265730   73.9314
# 290016      22  50905817  rs117163826   T   C  T  ADD  266057  108.3460
# 290039      22  50927468  rs556066986   A   G  A  ADD  265986  261.6430
#
#         LOG(OR)_SE   Z_STAT             P gene_symbol  length uniprot_id  \
# 186       1.019730  4.07246  4.652010e-05      RNF223     746     E7ERA6
# 209       1.020330  4.19019  2.787180e-05    C1orf159    8647     Q96HA4
# 487       1.049690  5.20020  1.990720e-07        DVL1   12920     O14640
# 653       0.730621  6.46801  9.930500e-11      ATAD3B   23929     Q5T9A4
# 859       1.018050  4.07873  4.528160e-05       MORN1   70147     Q5T089
# ...            ...      ...           ...         ...     ...        ...
# 289248    1.020160  4.28357  1.839200e-05       PPARA   36993     Q07869
# 289416    1.048170  5.29119  1.215210e-07      CELSR1  173989     Q9NYQ6
# 289744    1.019100  4.22247  2.416390e-05     TUBGCP6   26720     Q96RT7
# 290016    1.028360  4.55612  5.210780e-06        SBF1   27695     O95248
# 290039    1.048530  5.30934  1.100240e-07        MIOX    2955     Q9UGB7
#
#                                                     name
# 186                              ring finger protein 223
# 209                  chromosome 1 open reading frame 159
# 487               dishevelled segment polarity protein 1
# 653               ATPase family AAA domain containing 3B
# 859                             MORN repeat containing 1
# ...                                                  ...
# 289248  peroxisome proliferator activated receptor alpha
# 289416     cadherin EGF LAG seven-pass G-type receptor 1
# 289744        tubulin gamma complex associated protein 6
# 290016                              SET binding factor 1
# 290039                            myo-inositol oxygenase
#
# [849 rows x 16 columns]

# %%
# df = df.drop("GENE",axis='columns')
# df.to_csv(FILE_TO_CREATE_PATH)

# %%
genes_df[(genes_df["chr"] == "1") & (genes_df["cds_start"] < 11253684) & (genes_df["cds_end"] > 11253684)]
# Out:
#       Unnamed: 0 uniprot_id   symbol                                    name  \
# 1467        1467     O43827  ANGPTL7                     angiopoietin like 7
# 4715        4715     P42345     MTOR  mechanistic target of rapamycin kinase
#
#          refseq_ids chr  cds_start   cds_end
# 1467  ['NM_021146']   1   11249637  11255077
# 4715  ['NM_004958']   1   11167545  11319466
