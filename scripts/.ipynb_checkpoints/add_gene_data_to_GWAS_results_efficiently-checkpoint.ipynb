# %%
# jupyter imports
from IPython.display import clear_output

# %%
import pandas as pd

# %%
FILE_TO_ADD_PATH =  '/cs/labs/michall/roeizucker/IIH/updated_phenotypes/GWAS_standart_low_hwe/results/both_phen.csv'
FILE_TO_CREATE_PATH = '/cs/labs/michall/roeizucker/IIH/updated_phenotypes/GWAS_standart_low_hwe/results/both_phen_whole_genome_fixed_with_genes_-e-5.csv'
GENE_FILE_PATH = '/cs/labs/michall/roeizucker/virt_env_install_test/genes_hg19.csv'
WORK_ONLY_FOR_RES_VARIANTS = True
FILTER_PVAL = True
FILTER = 10**-5

# %%
CHR_SYMBOL = "#CHROM"
POS_SYMBOL = "POS"
PVAL_SYMBOL = "P"

# %%
def find_gene_heler(tree,row):
    if tree is None:
        return None
    if row["POS"] <= tree.val["cds_end"] and row["POS"] >= tree.val["cds_start"]:
        return tree.val
    if row["POS"] <= tree.val["cds_start"]:
        return find_gene_heler(tree.left,row)
    return find_gene_heler(tree.right,row)
    
def find_gene(genes_dict,row):
    return find_gene_heler((genes_dict[str(row["#CHROM"])]),row)
    pass

def add_genes_for_snps_symbol(df,genes_csv):
    rows = []
    for index,row in df.iterrows():
        if index % 10000 == 0:
            clear_output(wait=True)
            print(str(int(index/len(df) * 100)) + "%")

        val = row
        gene = find_gene(genes_dict,row)
        rows.append([row,gene])
    return rows

# %%
# create gene tree
class TreeNode:
    def __init__(self,val=None,left=None,right=None):
        self.val = val
        self.left = left
        self.right = right

def add_to_node(node,val):
    if val["cds_start"] < node.val["cds_start"]:
        if node.left is None:
            node.left = TreeNode(val)
        else:
            add_to_node(node.left,val)
    else:
        if node.right is None:
            node.right = TreeNode(val)
        else:
            add_to_node(node.right,val)
    pass
genes_df = pd.read_csv(GENE_FILE_PATH)
genes_dict = {}
for index, row in genes_df.iterrows():
    if row['chr'] not in genes_dict:
        genes_dict[row['chr']] = TreeNode(row)
    else:
        add_to_node(genes_dict[row['chr']],row)

# %%
# genes_dict

# %%
# print(find_gene(genes_dict,first_row))

# %%
# test_csv = "/cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov.csv"
# test_df = pd.read_csv(test_csv)
# first_row = None
# for val in test_df.iterrows():
#     first_row = val[1]
#     if find_gene(genes_dict,first_row) is not None:
#         print(find_gene(genes_dict,first_row) ,val)
#         print("#"*30)
    
# first_row

# %%
# add_genes_for_snps_symbol(df,genes_df)

# %%
df = pd.read_csv(FILE_TO_ADD_PATH)
# df["length"] = df["length"].astype(int)
# df.to_csv(FILE_TO_CREATE_PATH)

# %%
if WORK_ONLY_FOR_RES_VARIANTS:
    df = df[df[PVAL_SYMBOL].notnull()]
if FILTER_PVAL:
    df = df[df["P"] < FILTER]
vals = add_genes_for_snps_symbol(df,genes_df)

# %%
index = 0
final_results = []
for val in vals:
    if index % 10000 == 0:
        clear_output(wait=True)
        print(str(int(index/len(df) * 100)) + "%")
    index+=1    
    new_0 = val[0].to_dict()
    if val[1] is None:
#         val[0]["gene_symbol"] = "no_gene_found"
#         val[0]["length"] = -1
#         val[0]["name"] = "no_gene_found"
#         final_results.append(val[0])
        new_0["gene_symbol"] = "no_gene_found"
        new_0["length"] = -1
        new_0["name"] = "no_gene_found"
        final_results.append(new_0)

        continue
    new_1 = val[1].to_dict()
    new_0["gene_symbol"] = new_1["symbol"]
    new_0["length"] =  int(new_1["cds_end"]) -  int(new_1["cds_start"])
    new_0["name"] = new_1["name"]
    final_results.append(new_0)
# Out:
# 0%

# %%
len(final_results)
# Out:
# 1246

# %%
new_df = pd.DataFrame.from_records(final_results)

# %%
new_df.to_csv(FILE_TO_CREATE_PATH)

# %%
new_df[new_df["length"] > 0]
# Out:
#       #CHROM       POS                ID REF ALT PROVISIONAL_REF? A1 OMITTED  \
# 0          1   7090989       rs537339895   G   T                Y  T       G
# 2          1  15860361       rs118052077   C   T                Y  T       C
# 5          1  21168921       rs572988985   C   T                Y  T       C
# 6          1  22203106       rs137904249   C   T                Y  T       C
# 8          1  25632654       rs146963645   C   T                Y  T       C
# ...      ...       ...               ...  ..  ..              ... ..     ...
# 1236      22  26225280  22:26225280_CA_C  CA   C                Y  C      CA
# 1238      22  32448348       rs117295807   G   A                Y  A       G
# 1239      22  33292239       rs185554518   G   A                Y  A       G
# 1242      22  43218661        rs80206005   C   T                Y  T       C
# 1245      22  45570408       rs186028088   T   C                Y  C       T
#
#        A1_FREQ FIRTH? TEST  OBS_CT        OR  LOG(OR)_SE   Z_STAT  \
# 0     0.000853      N  ADD  295550  15.85180    0.587316  4.70493
# 2     0.000944      N  ADD  295574  13.70470    0.577692  4.53137
# 5     0.001511      N  ADD  292903  12.27360    0.505988  4.95555
# 6     0.001758      N  ADD  296013  10.00110    0.508014  4.53274
# 8     0.046183      N  ADD  288309   2.65043    0.207833  4.68994
# ...        ...    ...  ...     ...       ...         ...      ...
# 1236  0.002822      N  ADD  293378   7.69428    0.448194  4.55266
# 1238  0.002945      N  ADD  295074   7.60348    0.456672  4.44215
# 1239  0.006415      N  ADD  292919   5.78378    0.362097  4.84693
# 1242  0.002303      N  ADD  295541   9.76621    0.455446  5.00374
# 1245  0.001736      N  ADD  295523   9.97184    0.499862  4.60080
#
#                  P ERRCODE gene_symbol  length  \
# 0     2.539530e-06       .      CAMTA1  980957
# 2     5.860140e-06       .     DNAJC16   39068
# 5     7.212720e-07       .      EIF4G3  195420
# 6     5.822450e-06       .       HSPG2  113898
# 8     2.732880e-06       .         RHD   56373
# ...            ...     ...         ...     ...
# 1236  5.297170e-06       .      MYO18B  266581
# 1238  8.906510e-06       .      SLC5A1   66928
# 1239  1.253860e-06       .        SYN3  492965
# 1242  5.623000e-07       .     ARFGAP3   59591
# 1245  4.208660e-06       .       NUP50   16474
#
#                                                    name
# 0          calmodulin binding transcription activator 1
# 2     DnaJ heat shock protein family (Hsp40) member C16
# 5     eukaryotic translation initiation factor 4 gam...
# 6                        heparan sulfate proteoglycan 2
# 8                              Rh blood group D antigen
# ...                                                 ...
# 1236                                      myosin XVIIIB
# 1238                   solute carrier family 5 member 1
# 1239                                       synapsin III
# 1242  ADP ribosylation factor GTPase activating prot...
# 1245                                     nucleoporin 50
#
# [373 rows x 20 columns]

# %%
df[df["P"] < 0.00005]
# Out:
#           #CHROM       POS           ID REF ALT PROVISIONAL_REF? A1 OMITTED  \
# 28993          1   7090989  rs537339895   G   T                Y  T       G
# 51503          1  12915645  rs576880983   C   T                Y  T       C
# 62508          1  15860361  rs118052077   C   T                Y  T       C
# 65244          1  16426548  rs114600152   G   C                Y  C       G
# 72591          1  18295369    rs7412790   A   G                Y  G       A
# ...          ...       ...          ...  ..  ..              ... ..     ...
# 11013373      22  37513580  rs191621416   C   T                Y  T       C
# 11033716      22  43218661   rs80206005   C   T                Y  T       C
# 11036233      22  43785195   rs75915247   A   C                Y  C       A
# 11036254      22  43789894   rs77462112   G   A                Y  A       G
# 11045922      22  45570408  rs186028088   T   C                Y  C       T
#
#            A1_FREQ FIRTH? TEST  OBS_CT        OR  LOG(OR)_SE   Z_STAT  \
# 28993     0.000853      N  ADD  295550  15.85180    0.587316  4.70493
# 51503     0.003181      N  ADD  284231   8.58362    0.414296  5.18917
# 62508     0.000944      N  ADD  295574  13.70470    0.577692  4.53137
# 65244     0.001377      N  ADD  295555  13.15020    0.510560  5.04630
# 72591     0.001138      N  ADD  294711  15.80100    0.510818  5.40324
# ...            ...    ...  ...     ...       ...         ...      ...
# 11013373  0.002813      N  ADD  294858   7.54918    0.451608  4.47610
# 11033716  0.002303      N  ADD  295541   9.76621    0.455446  5.00374
# 11036233  0.003555      N  ADD  294541   7.46623    0.415838  4.83455
# 11036254  0.003740      N  ADD  294667   7.08360    0.415060  4.71686
# 11045922  0.001736      N  ADD  295523   9.97184    0.499862  4.60080
#
#                      P ERRCODE
# 28993     2.539530e-06       .
# 51503     2.112300e-07       .
# 62508     5.860140e-06       .
# 65244     4.504440e-07       .
# 72591     6.544910e-08       .
# ...                ...     ...
# 11013373  7.602040e-06       .
# 11033716  5.623000e-07       .
# 11036233  1.334470e-06       .
# 11036254  2.395140e-06       .
# 11045922  4.208660e-06       .
#
# [1246 rows x 17 columns]

# %%
# df = df.drop("GENE",axis='columns')
# df.to_csv(FILE_TO_CREATE_PATH)

# %%
genes_df[(genes_df["chr"] == "1") & (genes_df["cds_start"] < 11253684) & (genes_df["cds_end"] > 11253684)]
# Out:
#       Unnamed: 0 uniprot_id   symbol                                    name  \
# 1467        1467     O43827  ANGPTL7                     angiopoietin like 7
# 4715        4715     P42345     MTOR  mechanistic target of rapamycin kinase
#
#          refseq_ids chr  cds_start   cds_end
# 1467  ['NM_021146']   1   11249637  11255077
# 4715  ['NM_004958']   1   11167545  11319466

# %%
FILE_TO_CREATE_PATH
# Out:
# '/cs/labs/michall/roeizucker/IIH/updated_phenotypes/GWAS_standart_low_hwe/results/G93.2_whole_genome_fixed_with_genes_-e-5.csv'

# %%
new_df
# Out:
#       #CHROM       POS           ID REF ALT PROVISIONAL_REF? A1 OMITTED  \
# 0          1   7090989  rs537339895   G   T                Y  T       G
# 1          1  12915645  rs576880983   C   T                Y  T       C
# 2          1  15860361  rs118052077   C   T                Y  T       C
# 3          1  16426548  rs114600152   G   C                Y  C       G
# 4          1  18295369    rs7412790   A   G                Y  G       A
# ...      ...       ...          ...  ..  ..              ... ..     ...
# 1241      22  37513580  rs191621416   C   T                Y  T       C
# 1242      22  43218661   rs80206005   C   T                Y  T       C
# 1243      22  43785195   rs75915247   A   C                Y  C       A
# 1244      22  43789894   rs77462112   G   A                Y  A       G
# 1245      22  45570408  rs186028088   T   C                Y  C       T
#
#        A1_FREQ FIRTH? TEST  OBS_CT        OR  LOG(OR)_SE   Z_STAT  \
# 0     0.000853      N  ADD  295550  15.85180    0.587316  4.70493
# 1     0.003181      N  ADD  284231   8.58362    0.414296  5.18917
# 2     0.000944      N  ADD  295574  13.70470    0.577692  4.53137
# 3     0.001377      N  ADD  295555  13.15020    0.510560  5.04630
# 4     0.001138      N  ADD  294711  15.80100    0.510818  5.40324
# ...        ...    ...  ...     ...       ...         ...      ...
# 1241  0.002813      N  ADD  294858   7.54918    0.451608  4.47610
# 1242  0.002303      N  ADD  295541   9.76621    0.455446  5.00374
# 1243  0.003555      N  ADD  294541   7.46623    0.415838  4.83455
# 1244  0.003740      N  ADD  294667   7.08360    0.415060  4.71686
# 1245  0.001736      N  ADD  295523   9.97184    0.499862  4.60080
#
#                  P ERRCODE    gene_symbol  length  \
# 0     2.539530e-06       .         CAMTA1  980957
# 1     2.112300e-07       .  no_gene_found      -1
# 2     5.860140e-06       .        DNAJC16   39068
# 3     4.504440e-07       .  no_gene_found      -1
# 4     6.544910e-08       .  no_gene_found      -1
# ...            ...     ...            ...     ...
# 1241  7.602040e-06       .  no_gene_found      -1
# 1242  5.623000e-07       .        ARFGAP3   59591
# 1243  1.334470e-06       .  no_gene_found      -1
# 1244  2.395140e-06       .  no_gene_found      -1
# 1245  4.208660e-06       .          NUP50   16474
#
#                                                    name
# 0          calmodulin binding transcription activator 1
# 1                                         no_gene_found
# 2     DnaJ heat shock protein family (Hsp40) member C16
# 3                                         no_gene_found
# 4                                         no_gene_found
# ...                                                 ...
# 1241                                      no_gene_found
# 1242  ADP ribosylation factor GTPase activating prot...
# 1243                                      no_gene_found
# 1244                                      no_gene_found
# 1245                                     nucleoporin 50
#
# [1246 rows x 20 columns]
