# %%
# jupyter imports
from IPython.display import clear_output

# %%
import pandas as pd

# %%
FILE_TO_ADD_PATH =  '/sci/archive/michall/roeizucker/IIH/GWAS_standart/results/updated_Both.csv'
FILE_TO_CREATE_PATH = '/sci/archive/michall/roeizucker/IIH/GWAS_standart/results/updated_Both_with_genes.csv'
GENE_FILE_PATH = '/cs/labs/michall/roeizucker/virt_env_install_test/genes_hg19.csv'
WORK_ONLY_FOR_RES_VARIANTS = True

# %%
CHR_SYMBOL = "#CHROM"
POS_SYMBOL = "POS"
PVAL_SYMBOL = "P"

# %%
def find_gene_heler(tree,row):
    if tree is None:
        return None
    if row["POS"] <= tree.val["cds_end"] and row["POS"] >= tree.val["cds_start"]:
        return tree.val
    if row["POS"] <= tree.val["cds_start"]:
        return find_gene_heler(tree.left,row)
    return find_gene_heler(tree.right,row)
    
def find_gene(genes_dict,row):
    return find_gene_heler((genes_dict[str(row["#CHROM"])]),row)
    pass

def add_genes_for_snps_symbol(df,genes_csv):
    rows = []
    for index,row in df.iterrows():
        if index % 10000 == 0:
            clear_output(wait=True)
            print(str(int(index/len(df) * 100)) + "%")

        val = row
        gene = find_gene(genes_dict,row)
        rows.append([row,gene])
    return rows

# %%
# create gene tree
class TreeNode:
    def __init__(self,val=None,left=None,right=None):
        self.val = val
        self.left = left
        self.right = right

def add_to_node(node,val):
    if val["cds_start"] < node.val["cds_start"]:
        if node.left is None:
            node.left = TreeNode(val)
        else:
            add_to_node(node.left,val)
    else:
        if node.right is None:
            node.right = TreeNode(val)
        else:
            add_to_node(node.right,val)
    pass
genes_df = pd.read_csv(GENE_FILE_PATH)
genes_dict = {}
for index, row in genes_df.iterrows():
    if row['chr'] not in genes_dict:
        genes_dict[row['chr']] = TreeNode(row)
    else:
        add_to_node(genes_dict[row['chr']],row)

# %%
# genes_dict

# %%
# print(find_gene(genes_dict,first_row))

# %%
# test_csv = "/cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov.csv"
# test_df = pd.read_csv(test_csv)
# first_row = None
# for val in test_df.iterrows():
#     first_row = val[1]
#     if find_gene(genes_dict,first_row) is not None:
#         print(find_gene(genes_dict,first_row) ,val)
#         print("#"*30)
    
# first_row

# %%
# add_genes_for_snps_symbol(df,genes_df)

# %%
df = pd.read_csv(FILE_TO_ADD_PATH)
# df["length"] = df["length"].astype(int)
# df.to_csv(FILE_TO_CREATE_PATH)

# %%
if WORK_ONLY_FOR_RES_VARIANTS:
    df = df[df[PVAL_SYMBOL].notnull()]
vals = add_genes_for_snps_symbol(df,genes_df)
# Out:
# 99%

# %%
index = 0
final_results = []
for val in vals:
    if index % 10000 == 0:
        clear_output(wait=True)
        print(str(int(index/len(df) * 100)) + "%")
    index+=1    
    new_0 = val[0].to_dict()
    if val[1] is None:
#         val[0]["gene_symbol"] = "no_gene_found"
#         val[0]["length"] = -1
#         val[0]["name"] = "no_gene_found"
#         final_results.append(val[0])
        new_0["gene_symbol"] = "no_gene_found"
        new_0["length"] = -1
        new_0["name"] = "no_gene_found"
        final_results.append(new_0)

        continue
    new_1 = val[1].to_dict()
    new_0["gene_symbol"] = new_1["symbol"]
    new_0["length"] =  int(new_1["cds_end"]) -  int(new_1["cds_start"])
    new_0["name"] = new_1["name"]
    final_results.append(new_0)
# Out:
# 99%

# %%
len(final_results)
# Out:
# 10258516

# %%
new_df = pd.DataFrame.from_records(final_results)

# %%
new_df.to_csv(FILE_TO_CREATE_PATH)

# %%
new_df[new_df["length"] > 0]
# Out:
#           #CHROM       POS           ID REF ALT PROVISIONAL_REF? A1 OMITTED  \
# 513            1    861920  rs537774543   C   T                Y  T       C
# 514            1    862772  rs192998324   A   G                Y  G       A
# 515            1    863360  rs568926072   C   G                Y  G       C
# 516            1    863499   rs28718350   T   C                Y  C       T
# 517            1    863538  rs570731716   C   T                Y  T       C
# ...          ...       ...          ...  ..  ..              ... ..     ...
# 10258481      22  51219704  rs147475742   G   A                Y  A       G
# 10258482      22  51220088  rs566371895   G   A                Y  A       G
# 10258483      22  51220249    rs9616977   A   T                Y  T       A
# 10258484      22  51220319    rs9616978   C   G                Y  G       C
# 10258485      22  51220517    rs9616980   C   G                Y  G       C
#
#            A1_FREQ FIRTH? TEST  OBS_CT        OR  LOG(OR)_SE    Z_STAT  \
# 513       0.001784      Y  ADD  284223  1.335380    1.390380  0.208014
# 514       0.030979      N  ADD  291312  1.246710    0.360328  0.611968
# 515       0.005664      N  ADD  289567  0.838254    1.003730 -0.175778
# 516       0.032279      N  ADD  273519  1.069100    0.384685  0.173697
# 517       0.003486      Y  ADD  287618  0.679795    1.388090 -0.278055
# ...            ...    ...  ...     ...       ...         ...       ...
# 10258481  0.037112      N  ADD  284541  0.893940    0.384671 -0.291462
# 10258482  0.002286      Y  ADD  289865  1.063390    1.391920  0.044157
# 10258483  0.071194      N  ADD  290129  0.861087    0.286714 -0.521636
# 10258484  0.067436      N  ADD  288594  0.912847    0.286840 -0.317902
# 10258485  0.004633      N  ADD  284789  1.023490    1.002340  0.023167
#
#                  P ERRCODE gene_symbol  length  \
# 513       0.835218       .      SAMD11   18208
# 514       0.540559       .      SAMD11   18208
# 515       0.860468       .      SAMD11   18208
# 516       0.862104       .      SAMD11   18208
# 517       0.780970       .      SAMD11   18208
# ...            ...     ...         ...     ...
# 10258481  0.770698       .      RABL2B   13515
# 10258482  0.964779       .      RABL2B   13515
# 10258483  0.601924       .      RABL2B   13515
# 10258484  0.750559       .      RABL2B   13515
# 10258485  0.981517       .      RABL2B   13515
#
#                                                 name
# 513         sterile alpha motif domain containing 11
# 514         sterile alpha motif domain containing 11
# 515         sterile alpha motif domain containing 11
# 516         sterile alpha motif domain containing 11
# 517         sterile alpha motif domain containing 11
# ...                                              ...
# 10258481  RAB, member of RAS oncogene family like 2B
# 10258482  RAB, member of RAS oncogene family like 2B
# 10258483  RAB, member of RAS oncogene family like 2B
# 10258484  RAB, member of RAS oncogene family like 2B
# 10258485  RAB, member of RAS oncogene family like 2B
#
# [3150092 rows x 20 columns]

# %%
df[df["P"] < 0.00005]
# Out:
#           #CHROM       POS           ID REF   ALT PROVISIONAL_REF?    A1  \
# 3068           1   1518469  rs184857320   C     T                Y     T
# 6804           1   2466453    rs3001340   G     A                Y     A
# 12345          1   3756568  rs530230016   C     T                Y     T
# 17198          1   4785531     rs242042   C     T                Y     T
# 27210          1   7090989  rs537339895   G     T                Y     T
# ...          ...       ...          ...  ..   ...              ...   ...
# 10238508      22  47412065  rs528692927   C     T                Y     T
# 10238703      22  47443915  rs189815220   A     G                Y     G
# 10239393      22  47586705  rs138520989   G     T                Y     T
# 10240610      22  47843277  rs186238739   C     T                Y     T
# 10253857      22  50181294  rs758080640   G  GGCC                Y  GGCC
#
#          OMITTED   A1_FREQ FIRTH? TEST  OBS_CT        OR  LOG(OR)_SE   Z_STAT  \
# 3068           C  0.001359      N  ADD  287801  11.18260    0.587647  4.10852
# 6804           G  0.003608      N  ADD  290460   6.90159    0.457852  4.21916
# 12345          C  0.001346      N  ADD  290768  10.40680    0.572739  4.08993
# 17198          C  0.004895      N  ADD  289969   6.06268    0.416169  4.33033
# 27210          G  0.000861      N  ADD  290854  17.17930    0.588147  4.83503
# ...          ...       ...    ...  ...     ...       ...         ...      ...
# 10238508       C  0.002030      N  ADD  290089   9.59712    0.508112  4.45072
# 10238703       A  0.003109      N  ADD  290777   7.77640    0.455569  4.50227
# 10239393       G  0.001077      N  ADD  289652  13.24110    0.575761  4.48680
# 10240610       C  0.001350      N  ADD  290713  10.73560    0.580275  4.09041
# 10253857       G  0.001168      N  ADD  289782  12.62760    0.587633  4.31542
#
#                  P ERRCODE
# 3068      0.000040       .
# 6804      0.000025       .
# 12345     0.000043       .
# 17198     0.000015       .
# 27210     0.000001       .
# ...            ...     ...
# 10238508  0.000009       .
# 10238703  0.000007       .
# 10239393  0.000007       .
# 10240610  0.000043       .
# 10253857  0.000016       .
#
# [3957 rows x 17 columns]

# %%
# df = df.drop("GENE",axis='columns')
# df.to_csv(FILE_TO_CREATE_PATH)

# %%
genes_df[(genes_df["chr"] == "1") & (genes_df["cds_start"] < 11253684) & (genes_df["cds_end"] > 11253684)]
# Out:
#       Unnamed: 0 uniprot_id   symbol                                    name  \
# 1467        1467     O43827  ANGPTL7                     angiopoietin like 7
# 4715        4715     P42345     MTOR  mechanistic target of rapamycin kinase
#
#          refseq_ids chr  cds_start   cds_end
# 1467  ['NM_021146']   1   11249637  11255077
# 4715  ['NM_004958']   1   11167545  11319466

# %%
df
# Out:
#           #CHROM       POS                                ID  \
# 0              1     10616  1:10616_CCGCCGTTGCAAAGGCGCGCCG_C
# 1              1     13453                       rs568927457
# 2              1     13483                       rs554760071
# 3              1     15585                       rs533630043
# 4              1     15774                       rs374029747
# ...          ...       ...                               ...
# 10258622      22  51239296                         rs8137179
# 10258623      22  51239304                         rs8142977
# 10258624      22  51239586                       rs535432390
# 10258625      22  51241386                       rs568168135
# 10258626      22  51244237                       rs575160859
#
#                              REF ALT PROVISIONAL_REF?                      A1  \
# 0         CCGCCGTTGCAAAGGCGCGCCG   C                Y  CCGCCGTTGCAAAGGCGCGCCG
# 1                              T   C                Y                       C
# 2                              G   C                Y                       C
# 3                              G   A                Y                       A
# 4                              G   A                Y                       A
# ...                          ...  ..              ...                     ...
# 10258622                       T   C                Y                       C
# 10258623                       C   T                Y                       T
# 10258624                       T   G                Y                       G
# 10258625                       C   G                Y                       G
# 10258626                       C   T                Y                       T
#
#          OMITTED   A1_FREQ FIRTH? TEST  OBS_CT        OR  LOG(OR)_SE  \
# 0              C  0.001399      Y  ADD  285564  1.736770    1.385420
# 1              T  0.001221      Y  ADD  282252  2.031600    1.391720
# 2              G  0.001212      Y  ADD  284137  1.956750    1.391580
# 3              G  0.001966      Y  ADD  283783  1.234680    1.390980
# 4              G  0.000896      Y  ADD  280246  2.722120    1.371860
# ...          ...       ...    ...  ...     ...       ...         ...
# 10258622       T  0.000878      N  ADD  290556  5.505940    1.006010
# 10258623       C  0.000878      N  ADD  290556  5.505940    1.006010
# 10258624       T  0.001024      N  ADD  289420  9.203460    0.715421
# 10258625       C  0.002572      N  ADD  284411  1.891480    1.003560
# 10258626       C  0.004155      Y  ADD  275085  0.618403    1.385950
#
#             Z_STAT         P ERRCODE
# 0         0.398454  0.690296       .
# 1         0.509314  0.610532       .
# 2         0.482389  0.629530       .
# 3         0.151556  0.879537       .
# 4         0.729967  0.465410       .
# ...            ...       ...     ...
# 10258622  1.695640  0.089954       .
# 10258623  1.695640  0.089954       .
# 10258624  3.102480  0.001919       .
# 10258625  0.635095  0.525366       .
# 10258626 -0.346776  0.728759       .
#
# [10258516 rows x 17 columns]
