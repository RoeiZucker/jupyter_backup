# %%
import pandas as pd
import os

# %%
# # input files
# PHEN_PATH = "/sci/nosnap/michall/roeizucker/rosacea/ukbb_dataset.csv"
# GWAS_PATH = "/sci/nosnap/michall/roeizucker/rosacea/GWAS"
# PHENOTYPES = ['rosacea_extended','rosacea_extended_M','rosacea_extended_F']
# RESULT_SUFFIX = "PHENO1.glm.logistic"

# %%
# input files
PHEN_PATH = "/cs/labs/michall/roeizucker/Miki/ukbb_dataset.csv"
GWAS_PATH = "/cs/labs/michall/roeizucker/Miki"
PHENOTYPES = ["K760",]
RESULT_SUFFIX = "PHENO1.glm.logistic"
SPLIT_TO_TRAIN_TEST = True
TRAIN_RATIO = 0.8

# %%
# !ls {GWAS_PATH}
# Out:
# ls: cannot access '/sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS': No such file or directory

# %%
# dataset = pd.read_csv(phen_path)

# %%
# # dataset
# for phen in PHENOTYPES:
#     base_path =  GWAS_PATH
#     for j in range(1,23):
#         print((os.path.join(base_path ,f"results/{phen.lower()}_chr{j}.PHENO1.glm.linear")))
#         if os.path.exists(os.path.join(base_path ,f"results/{phen.lower()}_chr{j}.PHENO1.glm.linear")):
#             print("a")
#             continue
# Out:
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_f_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e03_m_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_f_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e04_m_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_f_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e05_m_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_f_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e06_m_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_f_reduced_chr22.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr1.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr2.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr3.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr4.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr5.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr6.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr7.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr8.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr9.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr10.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr11.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr12.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr13.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr14.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr15.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr16.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr17.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr18.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr19.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr20.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr21.PHENO1.glm.linear
# /sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/e07_m_reduced_chr22.PHENO1.glm.linear

# %%
# script body (will be transferred to another file)

# script consts
PHEN_START = 2
VALUE_AT_END_OF_PHENOTYPES = 'const'
PLINK_PATH = "/cs/usr/nadavb/third_party/plink2"
BATCH_LENGTH = 250
MAX_JOBS_BEFORE_SUBMITTING_NEW_ARRAY = 200

# TODO: add verbous argument, and better explain the output
def create_files(gwas_path,phen_path,phenotypes):
    # !mkdir {gwas_path}
    # !mkdir {gwas_path}/results
    # !mkdir {gwas_path}/phenotypes
    # !cp /cs/labs/michall/roeizucker/10krun/runs/0:11/GWAS_delete_me/covariates.txt {gwas_path}/covariates.txt
    # !cd {gwas_path}
    dataset = pd.read_csv(phen_path)
    for phenotype_col in phenotypes:
        print(phenotype_col)
        file_name = phenotype_col.lower().replace(' ', '_').replace('-', '_') + '.txt'
        # use eid as fid, because we take one representitive of each family
        values = dataset[['eid', 'eid', phenotype_col]].dropna()
        if SPLIT_TO_TRAIN_TEST:
            values_case = values[values[phenotype_col] == 1]
            values_control = values[values[phenotype_col]== 0] 
            values_case = values_case.sample(int(len(values_case) * TRAIN_RATIO))
            values_control = values_control.sample(int(len(values_control) * TRAIN_RATIO))
            values = pd.concat([values_case,values_control])
        values.to_csv(os.path.join(f"{gwas_path}/phenotypes", file_name), \
            header = False, index = False, sep = '\t')

        # An array is created with all the values needed for running GWAS.
# The array will be sorted in batches for better file accessing
def create_the_data_file(phenotype_cols,gwas_path,data_file_path):
    values = []
    last_counter = 0
    cur_phen_counter = 0
    counter = 0
    for phen in phenotype_cols:
        base_path =  gwas_path
        for j in range(1,23):
            if os.path.exists(os.path.join(base_path ,f"results/{phen.lower()}_chr{j}.PHENO1.glm.linear")) or \
            os.path.exists(os.path.join(base_path ,f"results/{phen.lower()}_chr{j}.PHENO1.glm.logistic")):
#                 print("a")
                continue
            
            # TODO: change location of plink files to be const
            values.append([counter,os.path.join(base_path, "phenotypes/"+ phen.lower() + ".txt"),
                           os.path.join(base_path, f"results/{phen.lower()}_chr{j}"),
                           f"/cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch{j}"
                           ,os.path.join(base_path ,"covariates.txt"),j])
            counter+=1
        cur_phen_counter+=1
        if cur_phen_counter%BATCH_LENGTH == 0:
            values[last_counter:counter] = sorted(values[last_counter:counter],key = lambda x:x[-1])
            last_counter = counter
    values[last_counter:counter] = sorted(values[last_counter:counter],key = lambda x:x[-1])
    df = pd.DataFrame(values, columns=["unsorted_counter","phenotype_path","output_path","partial_chromosome_file_path", "covariates","chr"])
    df.to_csv(data_file_path)


def write_mediator_script(mediator_script_path,data_file_path,gwas_path):
    with open(mediator_script_path, "w") as mediator_file:
        mediator_file.write(f'''import pandas as pd
import sys
import os
import os.path
butch_num = int(sys.argv[1]) 
curr_task = int(sys.argv[2])
BATCH_LENGTH = {BATCH_LENGTH}
SKIP_POINT = {MAX_JOBS_BEFORE_SUBMITTING_NEW_ARRAY}
PLINK_PATH = "/cs/usr/nadavb/third_party/plink2"

data_file_path = "{data_file_path}"
df = pd.read_csv(data_file_path)
print(df.loc[butch_num * BATCH_LENGTH + curr_task])
val = df.loc[butch_num * BATCH_LENGTH + curr_task]
location = butch_num * BATCH_LENGTH + curr_task
if curr_task == SKIP_POINT and location < 30500:
    new_batch  = butch_num + 1
    if not os.path.isfile("{gwas_path}_" + str(new_batch) + "_flag"):
        os.system("sbatch --array=0-"+str(BATCH_LENGTH - 1)+" --mem=12g -c10 --time=3-0 --killable --requeue --wrap=\\"{gwas_path}master.sh "+str(new_batch)+"\\"")
if location < 30500:
    print(PLINK_PATH + " --bed " + df.loc[location].partial_chromosome_file_path + ".bed --bim " + df.loc[location].partial_chromosome_file_path + ".bim --fam "+df.loc[location].partial_chromosome_file_path + ".fam --pheno " + df.loc[location].phenotype_path + " --covar " + df.loc[location].covariates + "  --out  " + df.loc[location].output_path + " --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000")
    os.system(PLINK_PATH + " --bed " + df.loc[location].partial_chromosome_file_path + ".bed --bim " + df.loc[location].partial_chromosome_file_path + ".bim --fam "+df.loc[location].partial_chromosome_file_path + ".fam --pheno " + df.loc[location].phenotype_path + " --covar " + df.loc[location].covariates + "  --out  " + df.loc[location].output_path + " --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000")
    print("done!")
''')

def write_master_script(master_script_path,mediator_script_path,gwas_path):
    with open(master_script_path, "w") as master_file:
        master_file.write(f'''
FILE={gwas_path}_$1_flag
if ! test "$FILE" 
then 
    touch {gwas_path}_$1_flag
fi
python {mediator_script_path} $1 $SLURM_ARRAY_TASK_ID
''')
    # !chmod 744 {master_script_path}

# set input 
# TODO: change so it is accepted as params
phen_path = PHEN_PATH
gwas_path = GWAS_PATH

# do stuff
phenotype_cols = list(pd.read_csv(PHEN_PATH))
phenotype_cols = phenotype_cols[2:phenotype_cols.index(VALUE_AT_END_OF_PHENOTYPES)]
if len (PHENOTYPES) > 0:
    phenotype_cols = PHENOTYPES
# TODO: chnage so names are consts
data_file_path = os.path.join(gwas_path, "data_file.csv")
mediator_script_path = os.path.join(gwas_path , "mediator.py")
master_script_path = os.path.join(gwas_path , "master.sh")

create_files(gwas_path,phen_path,phenotype_cols)
create_the_data_file(phenotype_cols,gwas_path,data_file_path)
write_mediator_script(mediator_script_path,data_file_path,gwas_path)
write_master_script(master_script_path,mediator_script_path,gwas_path)

# TODO: add output folder
print(f'''how to run:
sbatch --array=0-263 --mem=12g -c10 --time=3-0 --requeue --killable --wrap="{master_script_path} 0"''')
# Out:
# mkdir: cannot create directory ‘/cs/labs/michall/roeizucker/Miki’: File exists
# mkdir: cannot create directory ‘/cs/labs/michall/roeizucker/Miki/results’: File exists
# mkdir: cannot create directory ‘/cs/labs/michall/roeizucker/Miki/phenotypes’: File exists
# K760
# how to run:
# sbatch --array=0-263 --mem=12g -c10 --time=3-0 --requeue --killable --wrap="/cs/labs/michall/roeizucker/Miki/master.sh 0"

# %%
# master_script_path = priority_gwas_dir + "master.sh"

# (mediator_script_path,data_file_path,gwas_path)
master_script_path
# Out:
# '/sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/master.sh'

# %%
pd.read_csv(data_file_path)
# Out:
#      Unnamed: 0  unsorted_counter  \
# 0             0                 0
# 1             1                22
# 2             2                44
# 3             3                66
# 4             4                88
# ..          ...               ...
# 325         325               241
# 326         326               263
# 327         327               285
# 328         328               307
# 329         329               329
#
#                                         phenotype_path  \
# 0    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 1    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 2    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 3    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 4    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# ..                                                 ...
# 325  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 326  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 327  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 328  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 329  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
#
#                                            output_path  \
# 0    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 1    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 2    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 3    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 4    /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# ..                                                 ...
# 325  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 326  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 327  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 328  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
# 329  /sci/nosnap/michall/roeizucker/Hypothyroidism_...
#
#                           partial_chromosome_file_path  \
# 0    /cs/labs/michall/roeizucker/plink_results/redu...
# 1    /cs/labs/michall/roeizucker/plink_results/redu...
# 2    /cs/labs/michall/roeizucker/plink_results/redu...
# 3    /cs/labs/michall/roeizucker/plink_results/redu...
# 4    /cs/labs/michall/roeizucker/plink_results/redu...
# ..                                                 ...
# 325  /cs/labs/michall/roeizucker/plink_results/redu...
# 326  /cs/labs/michall/roeizucker/plink_results/redu...
# 327  /cs/labs/michall/roeizucker/plink_results/redu...
# 328  /cs/labs/michall/roeizucker/plink_results/redu...
# 329  /cs/labs/michall/roeizucker/plink_results/redu...
#
#                                             covariates  chr
# 0    /sci/nosnap/michall/roeizucker/Hypothyroidism_...    1
# 1    /sci/nosnap/michall/roeizucker/Hypothyroidism_...    1
# 2    /sci/nosnap/michall/roeizucker/Hypothyroidism_...    1
# 3    /sci/nosnap/michall/roeizucker/Hypothyroidism_...    1
# 4    /sci/nosnap/michall/roeizucker/Hypothyroidism_...    1
# ..                                                 ...  ...
# 325  /sci/nosnap/michall/roeizucker/Hypothyroidism_...   22
# 326  /sci/nosnap/michall/roeizucker/Hypothyroidism_...   22
# 327  /sci/nosnap/michall/roeizucker/Hypothyroidism_...   22
# 328  /sci/nosnap/michall/roeizucker/Hypothyroidism_...   22
# 329  /sci/nosnap/michall/roeizucker/Hypothyroidism_...   22
#
# [330 rows x 7 columns]

# %%
print(f'''how to run:
sbatch --array=0-263 --mem=12g -c10 --time=3-0 --requeue --killable --wrap="{master_script_path} 0"''')
# Out:
# how to run:
# sbatch --array=0-263 --mem=12g -c10 --time=3-0 --requeue --killable --wrap="/sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/master.sh 0"

# %% [markdown]
# ## combines GWAS results

# %%
import glob, os
# path = "/cs/labs/michall/roeizucker/10krun/runs/48:59/GWAS/results"
# os.chdir(path)
path = os.path.join(GWAS_PATH,"results")
# files = []
# for file in glob.glob("*.glm.*"):
#     files.append(file)
phens = PHENOTYPES
for phen in phens:
    dataframes = []
    for j in range(1,23):
#         change so logistic/liner is detrmined generically
        file_name = os.path.join(path,f"{phen.lower()}_chr{j}.{RESULT_SUFFIX}")
        try:
            df = pd.read_csv(file_name,sep="\t")
            dataframes.append(df)
        except pd.errors.EmptyDataError:
            print(file_name)
            continue
        except FileNotFoundError:
            print(file_name)
            continue
        print(df.head())
    if len(dataframes) == 0:
        continue
    master_df = pd.concat(dataframes)
    master_df.to_csv(f"{os.path.join(path,phen)}.csv",index=False)
    print(f"{os.path.join(path,phen)}.csv")
# Out:
#    #CHROM    POS           ID REF ALT A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0       1  69428  rs140739101   G   T  G  ADD   50618  1.44765    0.295806
# 1       1  69487  rs568226429   A   G  A  ADD   58594      NaN         NaN
# 2       1  69496  rs150690004   A   G  A  ADD   58590      NaN         NaN
# 3       1  69521  rs553724620   A   T  A  ADD   58536      NaN         NaN
# 4       1  69569    rs2531267   C   T  C  ADD   58584      NaN         NaN
#
#     Z_STAT         P
# 0  1.25061  0.211076
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN
#    #CHROM    POS           ID REF ALT A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0       2  41620  rs570524274   G   T  G  ADD   58590      NaN         NaN
# 1       2  45611  rs200415885   T   C  T  ADD   58592      NaN         NaN
# 2       2  45802  rs544168020   G   C  G  ADD   58583  45.6946      1.1613
# 3       2  45806  rs369700068   A   G  A  ADD   58568      NaN         NaN
# 4       2  45820  rs577281919   A   G  A  ADD   58483      NaN         NaN
#
#     Z_STAT         P
# 0      NaN       NaN
# 1      NaN       NaN
# 2  3.29113  0.000998
# 3      NaN       NaN
# 4      NaN       NaN
#    #CHROM     POS           ID REF ALT A1 TEST  OBS_CT        OR  LOG(OR)_SE  \
# 0       3  361493  rs142251617   A   G  A  ADD   58187  1.177430    0.272123
# 1       3  361508    rs2272522   T   C  T  ADD   58594  0.925727    0.076763
# 2       3  361547  rs116261368   G   T  G  ADD   58590       NaN         NaN
# 3       3  367645  rs144884920   G   A  G  ADD   58568       NaN         NaN
# 4       3  367705  rs144055818   G   A  G  ADD   58594  1.531960    0.509267
#
#      Z_STAT         P
# 0  0.600211  0.548365
# 1 -1.005380  0.314712
# 2       NaN       NaN
# 3       NaN       NaN
# 4  0.837577  0.402268
#    #CHROM     POS           ID REF ALT A1 TEST  OBS_CT        OR  LOG(OR)_SE  \
# 0       4  264941   rs11731285   G   A  G  ADD   58503  0.976777    0.079036
# 1       4  265024  rs200663767   T   C  T  ADD   58594  1.904630    1.015570
# 2       4  265139  rs566267637   A   C  A  ADD   58556       NaN         NaN
# 3       4  265154  rs142565151   T   C  T  ADD   58594       NaN         NaN
# 4       4  265195  rs201614981   C   A  C  ADD   58560       NaN         NaN
#
#      Z_STAT         P
# 0 -0.297301  0.766237
# 1  0.634414  0.525810
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#    #CHROM     POS           ID REF ALT A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0       5  140474  rs114197024   A   G  A  ADD   58588      NaN         NaN
# 1       5  140515  rs114802314   A   C  A  ADD   58593      NaN         NaN
# 2       5  140532   rs12516846   C   T  C  ADD   58590  1.04474    0.090643
# 3       5  140591  rs143062800   G   A  G  ADD   58558      NaN         NaN
# 4       5  140603  rs372952064   A   G  A  ADD   58594      NaN         NaN
#
#      Z_STAT        P
# 0       NaN      NaN
# 1       NaN      NaN
# 2  0.482868  0.62919
# 3       NaN      NaN
# 4       NaN      NaN
#    #CHROM     POS           ID REF ALT A1 TEST  OBS_CT  OR  LOG(OR)_SE  \
# 0       6  304637  rs151205644   A   G  A  ADD   58591 NaN         NaN
# 1       6  311892  rs147959810   T   C  T  ADD   58574 NaN         NaN
# 2       6  335156  rs201346671   T   C  T  ADD   58594 NaN         NaN
# 3       6  345896  rs137855591   G   C  G  ADD   58485 NaN         NaN
# 4       6  345898  rs377115548   A   G  A  ADD   58588 NaN         NaN
#
#    Z_STAT   P
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
#    #CHROM     POS           ID REF ALT A1 TEST  OBS_CT  OR  LOG(OR)_SE  \
# 0       7  193222   rs73251052   A   G  A  ADD   58593 NaN         NaN
# 1       7  193245  rs150401144   T   G  T  ADD   58592 NaN         NaN
# 2       7  193399  rs538469200   A   C  A  ADD   58575 NaN         NaN
# 3       7  193451  rs190382829   A   C  A  ADD   58594 NaN         NaN
# 4       7  193503  rs767408183   A   C  A  ADD   58580 NaN         NaN
#
#    Z_STAT   P
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
#    #CHROM     POS           ID REF ALT  A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0       8  116662  rs536301109   C   G   C  ADD   58577      NaN         NaN
# 1       8  116725  rs572221151   G   T   G  ADD   58386      NaN         NaN
# 2       8  116995  rs563787219  AG   A  AG  ADD   58280  5.91533    0.741211
# 3       8  192947   rs76280424   A   G   A  ADD   58594      NaN         NaN
# 4       8  192990  rs559788525   G   A   G  ADD   58571      NaN         NaN
#
#     Z_STAT         P
# 0      NaN       NaN
# 1      NaN       NaN
# 2  2.39817  0.016477
# 3      NaN       NaN
# 4      NaN       NaN
#    #CHROM     POS           ID REF ALT  A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0       9  116837  rs528874495   A   G   A  ADD   58536      NaN         NaN
# 1       9  116841  rs550119004   A   G   A  ADD   58592      NaN         NaN
# 2       9  116848  rs532235124  TA   T  TA  ADD   58423  13.5845      1.1113
# 3       9  116861  rs143746049   A   G   A  ADD   58587      NaN         NaN
# 4       9  116897  rs559143484   T   G   T  ADD   58592      NaN         NaN
#
#     Z_STAT         P
# 0      NaN       NaN
# 1      NaN       NaN
# 2  2.34763  0.018893
# 3      NaN       NaN
# 4      NaN       NaN
#    #CHROM     POS              ID REF ALT A1 TEST  OBS_CT  OR  LOG(OR)_SE  \
# 0      10  225960     rs370081585   A   G  A  ADD   58558 NaN         NaN
# 1      10  283619  10:283619_TA_T   T  TA  T  ADD   58585 NaN         NaN
# 2      10  285450     rs570036246   A   G  A  ADD   58594 NaN         NaN
# 3      10  294432     rs537691769   A   G  A  ADD   58586 NaN         NaN
# 4      10  323369     rs150381065   T   C  T  ADD   58532 NaN         NaN
#
#    Z_STAT   P
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
#    #CHROM     POS           ID REF ALT A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0      11  193112    rs7951297   T   C  T  ADD   32488  1.03800    0.095659
# 1      11  193113  rs200059999   A   G  A  ADD   58590      NaN         NaN
# 2      11  193146   rs61736219   A   G  A  ADD   19055  1.32448    0.246453
# 3      11  193724  rs541237660   A   G  A  ADD   58561      NaN         NaN
# 4      11  193797  rs199816295   C   G  C  ADD   58594  0.80996    0.263700
#
#      Z_STAT         P
# 0  0.389836  0.696658
# 1       NaN       NaN
# 2  1.140250  0.254183
# 3       NaN       NaN
# 4 -0.799282  0.424127
#    #CHROM     POS           ID REF ALT A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0      12  176139   rs17852242   T   A  T  ADD   40072  1.09418    0.100011
# 1      12  176487  rs528750416   A   G  A  ADD   58504      NaN         NaN
# 2      12  176491  rs547014567   A   T  A  ADD   58564      NaN         NaN
# 3      12  234821  rs374789572   A   G  A  ADD   58554      NaN         NaN
# 4      12  234855  rs372632887   T   C  T  ADD   58586  5.36460    1.043090
#
#      Z_STAT         P
# 0  0.899913  0.368167
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4  1.610430  0.107304
#    #CHROM       POS           ID REF ALT A1 TEST  OBS_CT        OR  \
# 0      13  19748038    rs1803092   T   C  T  ADD   58594  1.119850
# 1      13  19748241  rs202081515   C   T  C  ADD   58336  1.772630
# 2      13  19751083  rs556420373   A   C  A  ADD   52734  0.975598
# 3      13  19751149  rs572405672   A   G  A  ADD   58588       NaN
# 4      13  19751245   rs36216107   C   T  C  ADD   58594  1.001000
#
#    LOG(OR)_SE    Z_STAT         P
# 0    0.117528  0.963124  0.335486
# 1    1.017140  0.562820  0.573557
# 2    0.293295 -0.084232  0.932872
# 3         NaN       NaN       NaN
# 4    0.254775  0.003936  0.996859
#    #CHROM       POS           ID REF ALT A1 TEST  OBS_CT  OR  LOG(OR)_SE  \
# 0      14  19377614  rs200891589   T   G  T  ADD   58574 NaN         NaN
# 1      14  19377672   rs78043369   C   T  C  ADD   58591 NaN         NaN
# 2      14  19377745  rs147859978   A   C  A  ADD   58593 NaN         NaN
# 3      14  19377781  rs140389230   C   T  C  ADD   58197 NaN         NaN
# 4      14  19377798  rs145196589   T   C  T  ADD   58585 NaN         NaN
#
#    Z_STAT   P
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
#    #CHROM       POS           ID REF ALT A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0      15  21071460  rs546964009   T   C  T  ADD   18234  2.05340     3.18030
# 1      15  21071492  rs200987510   T   G  T  ADD   17074  1.08839     4.05818
# 2      15  22062362  rs564498861   A   G  A  ADD   58525      NaN         NaN
# 3      15  22382683  rs374791399   A   G  A  ADD   58587      NaN         NaN
# 4      15  22382731  rs551561517   A   T  A  ADD   58546      NaN         NaN
#
#      Z_STAT         P
# 0  0.226235  0.821019
# 1  0.020871  0.983349
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#    #CHROM    POS              ID REF  ALT A1 TEST  OBS_CT        OR  \
# 0      16  64451  16:64451_GAC_G   G  GAC  G  ADD   58593       NaN
# 1      16  64458      rs12444477   A    G  G  ADD   23431  1.027830
# 2      16  64494       rs4350573   A    G  A  ADD   57422  0.436658
# 3      16  65550     rs570055986   T    C  T  ADD   58415       NaN
# 4      16  65561     rs201668686   C    G  G  ADD   23773  1.005990
#
#    LOG(OR)_SE    Z_STAT         P
# 0         NaN       NaN       NaN
# 1    0.103393  0.265499  0.790625
# 2    1.004830 -0.824622  0.409586
# 3         NaN       NaN       NaN
# 4    0.101956  0.058536  0.953322
#    #CHROM    POS           ID REF ALT A1 TEST  OBS_CT        OR  LOG(OR)_SE  \
# 0      17  63678  rs112843928   T   C  T  ADD   58588       NaN         NaN
# 1      17  63683  rs117190076   A   G  A  ADD   57404  0.893118    0.127936
# 2      17  65456  rs200217063   A   G  A  ADD   58563       NaN         NaN
# 3      17  65471  rs201204475   A   G  A  ADD   58513       NaN         NaN
# 4      17  65551  rs144890975   A   G  A  ADD   58583       NaN         NaN
#
#      Z_STAT         P
# 0       NaN       NaN
# 1 -0.883544  0.376942
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#    #CHROM    POS           ID REF ALT A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0      18  47397  rs543847261   G   A  G  ADD   58488      NaN         NaN
# 1      18  47400  rs562842438   A   T  A  ADD   58488      NaN         NaN
# 2      18  47434   rs11081070   T   C  T  ADD   56243  1.48975    0.307901
# 3      18  47437  rs367958683   T   C  T  ADD   58594      NaN         NaN
# 4      18  47439  rs546717223   A   G  A  ADD   58551      NaN         NaN
#
#    Z_STAT         P
# 0     NaN       NaN
# 1     NaN       NaN
# 2  1.2946  0.195457
# 3     NaN       NaN
# 4     NaN       NaN
#    #CHROM     POS           ID REF ALT  A1 TEST  OBS_CT        OR  LOG(OR)_SE  \
# 0      19  110747  rs560302340  GT   G  GT  ADD   57322  0.495726     1.00530
# 1      19  110783  rs148836883   A   C   A  ADD   58094  0.559679     1.00618
# 2      19  281405   rs34392164   A   G   A  ADD   58592       NaN         NaN
# 3      19  281468   rs34708574   A   G   A  ADD   58187  0.770697     1.00699
# 4      19  281507  rs766336703   A   G   A  ADD   58527       NaN         NaN
#
#      Z_STAT         P
# 0 -0.698032  0.485157
# 1 -0.576828  0.564055
# 2       NaN       NaN
# 3 -0.258653  0.795903
# 4       NaN       NaN
#    #CHROM    POS           ID REF ALT A1 TEST  OBS_CT       OR  LOG(OR)_SE  \
# 0      20  68363  rs200192457   T   A  T  ADD   58590      NaN         NaN
# 1      20  68396  rs138777928   T   C  T  ADD   58594  0.64278    0.712454
# 2      20  76771   rs41276376   T   C  T  ADD   58594  0.97327    0.714632
# 3      20  76886  rs558280500   A   T  A  ADD   58234      NaN         NaN
# 4      20  76920  rs139068554   A   G  A  ADD   58594      NaN         NaN
#
#      Z_STAT         P
# 0       NaN       NaN
# 1 -0.620325  0.535044
# 2 -0.037913  0.969757
# 3       NaN       NaN
# 4       NaN       NaN
#    #CHROM       POS           ID REF ALT A1 TEST  OBS_CT        OR  \
# 0      21  14982614  rs568484124   A   G  A  ADD   58557       NaN
# 1      21  14982721  rs200814491   G   A  G  ADD   57111  0.767343
# 2      21  14982943  rs537419636   G   A  G  ADD   58554       NaN
# 3      21  14987484  rs202239184   A   G  A  ADD   53034  1.349130
# 4      21  15003380  rs568367816   G   A  G  ADD   58497       NaN
#
#    LOG(OR)_SE   Z_STAT         P
# 0         NaN      NaN       NaN
# 1    0.247798 -1.06870  0.285206
# 2         NaN      NaN       NaN
# 3    0.229771  1.30331  0.192470
# 4         NaN      NaN       NaN
#    #CHROM       POS                  ID REF   ALT A1 TEST  OBS_CT        OR  \
# 0      22  16258211         rs556077431   G     A  G  ADD   57866       NaN
# 1      22  16258290  22:16258290_CATT_C   C  CATT  C  ADD   57629       NaN
# 2      22  16258294         rs200891952   G     T  G  ADD   55849  0.455889
# 3      22  16279276         rs552437939   G     C  G  ADD   58432       NaN
# 4      22  16287331         rs578233906   T     C  T  ADD   58554       NaN
#
#    LOG(OR)_SE    Z_STAT         P
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2     1.00548 -0.781224  0.434671
# 3         NaN       NaN       NaN
# 4         NaN       NaN       NaN
# /cs/labs/michall/roeizucker/Miki/results/K760.csv

# %%
os.path.join(path,phen)
# Out:
# '/sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton/GWAS_FOR_PRS/results/E07_M_reduced'
