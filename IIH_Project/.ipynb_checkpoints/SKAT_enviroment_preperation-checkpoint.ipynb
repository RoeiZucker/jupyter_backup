# %% [markdown]
# # SKAT Enviroment Preperation

# %% [markdown]
# ## Descpreription
# this notebook prepares the neccesary files and scripts to run the SKAT analysis for a given phenotype (in csv file) and plink format genetic files

# %%
import pandas as pd
import pandas_plink as pdp
from ipywidgets import IntProgress
from IPython import display

# %%
PROJECT_PATH = "/cs/labs/michall/roeizucker/SKAT_experiments/SetID"
FILE_CONTAINING_PARTICIPANTS = PROJECT_PATH + "/data_participant.csv"
OLD_PHENOTYPE_FILE = '/cs/labs/michall/roeizucker/10krun/runs/48:59/ukbb_dataset.csv'
PHENOTYPE_FILE_NAME = PROJECT_PATH + "/phens.csv"
SET_ID_FILE_MAX_LENGTH = 5000
GENE_FILE_PATH = '/cs/labs/michall/roeizucker/virt_env_install_test/genes_hg19.csv'
# temp covar /cs/labs/michall/roeizucker/phewas_run/runs1/1000:1009/GWAS/covariates.txt

# %% [markdown]
# ## create basic SetID file
# the SKAT program uses a SetID file that defines which gene contains which variant.

# %%
GENES_FILE_PATH = "/cs/usr/roeizucker/my_storage/virt_env_install_test/genes_hg19.csv"

# %% [markdown]
# ### load genes file
# this file is part of the PWAS pipeline, it defines the location and size of each gene

# %%
gene_file_dataframe = pd.read_csv(GENES_FILE_PATH)[["uniprot_id","chr","cds_start","cds_end"]]

# %% [markdown]
# ### load PLINK format genetic files

# %%
PLINK_FILE_BASE_PATH = "/cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch"

# %%
plink_results = []
for i in range(1,23):
    df = pdp.read_plink(PLINK_FILE_BASE_PATH + str(i),verbose=False)[0][["snp","pos"]]
    result = [(x, y) for x, y in zip(df['snp'], df['pos'])]
    plink_results.append((i,result))

# %%
print(len(plink_results))
# Out:
# 22

# %%
print("chr is:",i)
val = pdp.read_plink(PLINK_FILE_BASE_PATH + str(i),verbose=False)
# Out:
# chr is: 22

# %%
res = val[2]
res
# Out:
# dask.array<transpose, shape=(15002, 487409), dtype=float32, chunksize=(1024, 1024), chunktype=numpy.ndarray>

# %% [markdown]
# ### create gene-variant associations

# %%
gene_association_result = []

for (chrom, vals) in plink_results:
    reduced_gene_dataframe = gene_file_dataframe[gene_file_dataframe["chr"] == str(chrom)]
    display.clear_output()
    print(chrom)
    counter = 0
    for val in vals:
        pos = val[1]
        name= val[0]
        genes = list(reduced_gene_dataframe[(reduced_gene_dataframe["cds_start"] <= pos) & (reduced_gene_dataframe["cds_end"] >= pos)]["uniprot_id"])
        for gene in genes:
            gene_association_result.append((name,gene))
        counter +=1
        if counter %3000 == 0:
            display.clear_output()
            print(chrom)
            print(counter/len(vals) * 100)
gene_association_result = sorted(gene_association_result,key= lambda x:x[1])
# Out:
# 22
# 99.98666844420744

# %%
print(len(gene_association_result))
# Out:
# 651400

# %% [markdown]
# ### write variant-gene associations to SetID file

# %%
set_id_file_path = PROJECT_PATH + "/" + "genes.SetID"
counter = 0
lines_seen = set()
counter = 0
with open(set_id_file_path,"w") as file:
    for (variant,gene) in gene_association_result[0:len(gene_association_result) // 2]:
        if counter %10000 == 0:
            display.clear_output()
            print(counter/len(gene_association_result) * 100)
        if f"{gene} {variant}" not in lines_seen:
            file.write(f"{gene} {variant}\n")
            lines_seen.add(f"{gene} {variant}")  
        counter +=1
# Out:
# 49.12496162112374

# %%
PROJECT_PATH
# Out:
# '/cs/labs/michall/roeizucker/SKAT_experiments/SetID'

# %% [markdown]
# ### write variant-gene associations to multiple SetID files

# %%
def get_variants_for_genes(counter,gene_association_result):
    new_counter = counter
    curr_gene = gene_association_result[new_counter][1]    
    gene_vars = []
    while new_counter < len(gene_association_result) and gene_association_result[new_counter][1] == curr_gene:
        gene_vars.append(gene_association_result[new_counter])
        new_counter+=1
        if new_counter %10000 == 0:
            display.clear_output()
            print(new_counter/len(gene_association_result) * 100)
    return gene_vars,new_counter


set_id_file_path = PROJECT_PATH + "/" + "genes.SetID"
counter = 0
lines_seen = set()
counter = 0
curr_file = 0
add_to_curr_file = []
while counter < len(gene_association_result):
    curr_gene = gene_association_result[counter][1]
    add_to_curr_file,counter = get_variants_for_genes(counter,gene_association_result)
    new_counter = counter
    gene_vars = []
    while len(add_to_curr_file) + len(gene_vars) < SET_ID_FILE_MAX_LENGTH and new_counter < len(gene_association_result):
        
        add_to_curr_file.extend(gene_vars)
        counter = new_counter
        if new_counter >= len(gene_association_result):
            print("aaaa")
        gene_vars,new_counter = get_variants_for_genes(counter,gene_association_result)
        
#     set_id_file_path = PROJECT_PATH + "/" + "genes.SetID"
    set_id_file_path = f"{PROJECT_PATH}/genes_{curr_file}.SetID"
    with open(set_id_file_path,"w") as file:
        for (variant,gene) in add_to_curr_file:
            if f"{gene} {variant}" not in lines_seen:
                file.write(f"{gene} {variant}\n")
                lines_seen.add(f"{gene} {variant}")  
    
    curr_file+=1
# Out:
# 99.78507829290758

# %% [markdown]
# ### create slurm scripts for generating SSD from setID

# %%
# only for a single chromosome:
CHROM = 4
SET_ID_PATH = "/cs/labs/michall/roeizucker/SKAT_experiments/SetID"
R_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{CHROM}.R"
PYTHON_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{CHROM}.py"
CSV_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{CHROM}.csv"
BASH_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{CHROM}.sh"
BASE_PATH = "/cs/labs/michall/roeizucker/IIH"
CURR_BED = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{CHROM}.bed"
CURR_BIM = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{CHROM}.bim"
CURR_FAM = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{CHROM}.fam"
with open(R_FILE,"w") as file:
    file.write('''require(SKAT)
args = commandArgs(trailingOnly=TRUE)
File.Bed<-args[1]
File.Bim<-args[2]
File.Fam<-args[3]
File.SetID<-args[4]
File.SSD<-args[5]
File.Info<-args[6]
Generate_SSD_SetID(File.Bed, File.Bim, File.Fam, File.SetID, File.SSD, File.Info)
print("Done")
''')

# %%
with open(CSV_FILE,"w") as file:
    file.write("bed,bim,fam,SetID,SSD,info\n")
    for i in range(curr_file):
        file.write(f"{CURR_BED},{CURR_BIM},{CURR_FAM},{SET_ID_PATH}/genes_{i}.SetID,{BASE_PATH}/genes_{CHROM}_{i}.SSD,{BASE_PATH}/genes_{CHROM}_{i}.SSD.info\n")

# %%
import pandas as pd
import sys
import os
df = pd.read_csv(CSV_FILE)
line = df.iloc[int(sys.argv[1]),]
# line = df.iloc[3,]
os.system('/cs/cbio/netanel/lib/R4/bin/Rscript ' + R_FILE + ' ' + line.bed + ' ' + line.bim + ' ' + line.fam + ' ' + line.SetID + ' ' + line.SSD + ' ' + line.info)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-205-c9b690287048> in <module>
#       3 import os
#       4 df = pd.read_csv(CSV_FILE)
# ----> 5 line = df.iloc[int(sys.argv[1]),]
#       6 # line = df.iloc[3,]
#       7 os.system('/cs/cbio/netanel/lib/R4/bin/Rscript ' + R_FILE + ' ' + line.bed + ' ' + line.bim + ' ' + line.fam + ' ' + line.SetID + ' ' + line.SSD + ' ' + line.info)
#
# ValueError: invalid literal for int() with base 10: '-f'

# %%
with open(PYTHON_FILE,"w") as file:
    file.write("import pandas as pd\n")
    file.write("import sys\n")
    file.write("import os\n")
    file.write("df = pd.read_csv('"+CSV_FILE+"')\n")
    file.write("line = df.iloc[int(sys.argv[1]),]\n")
    file.write("os.system('/cs/cbio/netanel/lib/R4/bin/Rscript " + R_FILE + " ' + line.bed + ' ' + line.bim + ' ' + line.fam + ' ' + line.SetID + ' ' + line.SSD + ' ' + line.info)\n")
    file.write("\n")

# %%
with open(BASH_FILE,"w") as file:
    file.write(f"python {PYTHON_FILE} $SLURM_ARRAY_TASK_ID\n")

# %%
# !chmod 744 {BASH_FILE}

# %%
# !echo {BASH_FILE}
# Out:
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_4.sh

# %% [markdown]
# ### create SETId files for multiple chromosomes

# %%
for chrom in range(0,23):
    SET_ID_PATH = "/cs/labs/michall/roeizucker/SKAT_experiments/SetID"
    R_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{chrom}.R"
    PYTHON_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{chrom}.py"
    CSV_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{chrom}.csv"
    BASH_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{chrom}.sh"
    BASE_PATH = "/cs/labs/michall/roeizucker/IIH"
    CURR_BED = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{chrom}.bed"
    CURR_BIM = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{chrom}.bim"
    CURR_FAM = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{chrom}.fam"
    with open(R_FILE,"w") as file:
        file.write('''require(SKAT)
    args = commandArgs(trailingOnly=TRUE)
    File.Bed<-args[1]
    File.Bim<-args[2]
    File.Fam<-args[3]
    File.SetID<-args[4]
    File.SSD<-args[5]
    File.Info<-args[6]
    Generate_SSD_SetID(File.Bed, File.Bim, File.Fam, File.SetID, File.SSD, File.Info)
    print("abcd")
    ''')
    with open(CSV_FILE,"w") as file:
        file.write("bed,bim,fam,SetID,SSD,info\n")
        for i in range(curr_file):
            file.write(f"{CURR_BED},{CURR_BIM},{CURR_FAM},{SET_ID_PATH}/genes_{i}.SetID,{BASE_PATH}/genes_{chrom}_{i}.SSD,{BASE_PATH}/genes_{chrom}_{i}.SSD.info\n")
    with open(PYTHON_FILE,"w") as file:
        file.write("import pandas as pd\n")
        file.write("import sys\n")
        file.write("import os\n")
        file.write("df = pd.read_csv('"+CSV_FILE+"')\n")
        file.write("line = df.iloc[int(sys.argv[1]),]\n")
        file.write("os.system('/cs/cbio/netanel/lib/R4/bin/Rscript " + R_FILE + " ' + line.bed + ' ' + line.bim + ' ' + line.fam + ' ' + line.SetID + ' ' + line.SSD + ' ' + line.info)\n")
        file.write("\n")
    
    with open(BASH_FILE,"w") as file:
        file.write(f"python {PYTHON_FILE} $SLURM_ARRAY_TASK_ID\n")

    # !chmod 744 {BASH_FILE}
    # !echo {BASH_FILE}
# Out:
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_0.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_1.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_2.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_3.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_4.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_5.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_6.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_7.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_8.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_9.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_10.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_11.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_12.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_13.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_14.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_15.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_16.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_17.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_18.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_19.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_20.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_21.sh
# /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_22.sh

# %%
for chrom in range(0,5):
    BASH_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{chrom}.sh"
    print(f'sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="{BASH_FILE}"')
    print("sleep 1m")
    print(f"echo {BASH_FILE} running")
#     print("sleep 24m")
# Out:
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_0.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_0.sh running
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_1.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_1.sh running
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_2.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_2.sh running
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_3.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_3.sh running
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_4.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/IIH/scripts/create_SSD_4.sh running

# %% [markdown]
# ### create output files from SSD for all chromosomes

# %%
for chrom in range(1,23):
    SET_ID_PATH = "/cs/labs/michall/roeizucker/IIH"
    CSV_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{chrom}.csv"
    BASE_PATH = "/cs/labs/michall/roeizucker/IIH"
    CURR_BED = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{chrom}.bed"
    CURR_BIM = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{chrom}.bim"
    CURR_FAM = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{chrom}.fam"
    
    R_FILE = f"/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_{chrom}.R"
    PYTHON_FILE = f"/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_{chrom}.py"
    # CSV_FILE = "/cs/usr/roeizucker/Desktop/temp/SKAT_delete_me/scripts/create_SSD.csv"
    BASH_FILE = f"/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_{chrom}.sh"
    with open(R_FILE,"w") as file:
        file.write('''require(SKAT)
args = commandArgs(trailingOnly=TRUE)
File.Bed<-args[1]
File.Bim<-args[2]
File.Fam<-args[3]
File.SetID<-args[4]
File.SSD<-args[5]
File.Info<-args[6]
File.Cov<-"/cs/labs/michall/roeizucker/phewas_run/runs1/1000:1009/GWAS/covariates.txt"

FAM_Cov<-Read_Plink_FAM_Cov(File.Fam, File.Cov, Is.binary=FALSE, cov_header=FALSE)

X2 = FAM_Cov$Sex
X1 = FAM_Cov$COV1

SSD.INFO<-Open_SSD(File.SSD, File.Info)

test_phenotypes = read.csv(file = "/cs/usr/roeizucker/Desktop/temp/SKAT_delete_me/phens.csv")
obj<-SKAT_Null_Model(test_phenotypes$IIH_mod ~ data.matrix(FAM_Cov[,7:14]), out_type="C")

SSD.INFO<-Open_SSD(File.SSD, File.Info)
out<-SKAT.SSD.All(SSD.INFO, obj)

write.table(out$results,args[7])
''')
    with open(PYTHON_FILE,"w") as file:
        file.write("import pandas as pd\n")
        file.write("import sys\n")
        file.write("import os\n")
        file.write("df = pd.read_csv('"+CSV_FILE+"')\n")
        file.write("out_file = '" + BASE_PATH + "/out_'+  str(sys.argv[1]) +'_"+str(chrom)+".csv'\n")
        file.write("line = df.iloc[int(sys.argv[1]),]\n")
        file.write("os.system('/cs/cbio/netanel/lib/R4/bin/Rscript " + R_FILE + " ' + line.bed + ' ' + line.bim + ' ' + line.fam + ' ' + line.SetID + ' ' + line.SSD + ' ' + line.info+ ' ' + out_file)\n")
        file.write("\n")
    with open(BASH_FILE,"w") as file:
        file.write(f"python {PYTHON_FILE} $SLURM_ARRAY_TASK_ID\n")
    # !chmod 744 {BASH_FILE}
    # !echo {BASH_FILE}
# Out:
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_0.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_1.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_2.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_3.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_4.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_5.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_6.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_7.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_8.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_9.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_10.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_11.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_12.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_13.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_14.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_15.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_16.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_17.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_18.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_19.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_20.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_21.sh
# /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_22.sh

# %%
for chrom in range(0,23):
    BASH_FILE = f"/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_{chrom}.sh"
    print(f'sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="{BASH_FILE}"')
    print("sleep 1m")
    print(f"echo {BASH_FILE} running")
    print("sleep 5m")
# Out:
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_0.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_0.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_1.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_1.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_2.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_2.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_3.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_3.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_4.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_4.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_5.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_5.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_6.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_6.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_7.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_7.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_8.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_8.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_9.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_9.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_10.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_10.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_11.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_11.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_12.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_12.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_13.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_13.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_14.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_14.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_15.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_15.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_16.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_16.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_17.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_17.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_18.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_18.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_19.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_19.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_20.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_20.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_21.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_21.sh running
# sleep 5m
# sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_22.sh"
# sleep 1m
# echo /cs/labs/michall/roeizucker/hackton_meno/scripts/create_out_22.sh running
# sleep 5m

# %% [markdown]
# ### create output files from SSD

# %%
CHROM = 2
# SET_ID_PATH = "/cs/usr/roeizucker/Desktop/temp/SKAT_delete_me"
CSV_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_SSD_{CHROM}.csv"
BASE_PATH = "/cs/labs/michall/roeizucker/IIH"
CURR_BED = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{CHROM}.bed"
CURR_BIM = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{CHROM}.bim"
CURR_FAM = f"/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{CHROM}.fam"

R_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_out_{CHROM}.R"
PYTHON_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_out_{CHROM}.py"
# CSV_FILE = "/cs/usr/roeizucker/Desktop/temp/SKAT_delete_me/scripts/create_SSD.csv"
BASH_FILE = f"/cs/labs/michall/roeizucker/IIH/scripts/create_out_{CHROM}.sh"
with open(R_FILE,"w") as file:
    file.write('''require(SKAT)
args = commandArgs(trailingOnly=TRUE)
File.Bed<-args[1]
File.Bim<-args[2]
File.Fam<-args[3]
File.SetID<-args[4]
File.SSD<-args[5]
File.Info<-args[6]

SSD.INFO<-Open_SSD(File.SSD, File.Info)

test_phenotypes = read.csv(file = "/cs/usr/roeizucker/Desktop/temp/SKAT_delete_me/phens.csv")
obj<-SKAT_Null_Model(test_phenotypes$IIH_mod ~ 1, out_type="C")
SSD.INFO<-Open_SSD(File.SSD, File.Info)
out<-SKAT.SSD.All(SSD.INFO, obj)
print(args[7])
write.table(out$results,args[7])
''')

# %%
with open(PYTHON_FILE,"w") as file:
    file.write("import pandas as pd\n")
    file.write("import sys\n")
    file.write("import os\n")
    file.write("df = pd.read_csv('"+CSV_FILE+"')\n")
    file.write("out_file = '" + BASE_PATH + "/out_'+  str(sys.argv[1]) +'_"+str(CHROM)+".csv'\n")
    file.write("line = df.iloc[int(sys.argv[1]),]\n")
    file.write("os.system('/cs/cbio/netanel/lib/R4/bin/Rscript " + R_FILE + " ' + line.bed + ' ' + line.bim + ' ' + line.fam + ' ' + line.SetID + ' ' + line.SSD + ' ' + line.info+ ' ' + out_file)\n")
    file.write("\n")

# %%
with open(BASH_FILE,"w") as file:
    file.write(f"python {PYTHON_FILE} $SLURM_ARRAY_TASK_ID\n")

# %%
# !chmod 744 {BASH_FILE}

# %%
# !ls "/cs/labs/michall/roeizucker/IIH/scripts/create_out_2.sh"
# Out:
# /cs/labs/michall/roeizucker/IIH/scripts/create_out_2.sh

# %%
# !ls /cs/usr/roeizucker/Desktop/temp/SKAT_delete_me/scripts/
# Out:
# create_out_2.py  create_out.py	create_SSD_2.csv  create_SSD.py  test.R
# create_out_2.R	 create_out.R	create_SSD_3.R	  create_SSD.R
# create_out_2.sh  create_out.sh	create_SSD.csv	  create_SSD.sh

# %%
print(counter)
# Out:
# 64948

# %% [markdown]
# ## create new phenotype file

# %%
participants_dataframe = pd.read_csv(FILE_CONTAINING_PARTICIPANTS)
participants_dataframe
participants_dataframe["IIH_mod"] = 1
participants_dataframe["eid2"] = participants_dataframe["eid"]
participants_dataframe.set_index("eid2",inplace=True)
participants_dataframe
# print(len(old_phenotype_dataframe))
# old_phenotype_dataframe = pd.read_csv(OLD_PHENOTYPE_FILE)
# old_phenotype_dataframe["eid2"] = old_phenotype_dataframe["eid"]
# old_phenotype_dataframe.set_index("eid2",inplace=True)
# old_phenotype_dataframe["IIH_mod"] = participants_dataframe["IIH_mod"]
# old_phenotype_dataframe["IIH_mod"] = old_phenotype_dataframe["IIH_mod"].fillna(0)
# print(len(old_phenotype_dataframe))
# Out:
#              eid     p31  p21001_i0  p36_i0  p4080_i0_a0  p4080_i0_a1  \
# eid2
# 3830686  3830686  Female    32.8933  1039.0        150.0        145.0
# 5450636  5450636  Female    53.5396  3158.0        123.0        128.0
# 5021098  5021098  Female    22.6718  1049.0        152.0        127.0
# 2401715  2401715    Male    25.7589  2815.0        123.0        118.0
# 4181381  4181381    Male    32.6190  1053.0        183.0        181.0
# ...          ...     ...        ...     ...          ...          ...
# 3827597  3827597  Female    27.5597  1046.0        153.0        149.0
# 4122899  4122899  Female    23.5102   156.0        130.0        125.0
# 4407910  4407910    Male    33.2713   162.0        146.0        139.0
# 5281791  5281791  Female    23.6336  1053.0        127.0        119.0
# 4360102  4360102  Female    29.9556  1046.0        141.0        134.0
#
#         p2443_i0  p21022  p30890_i0     p21762_i2  ...  p21662_i3  p5326_i0  \
# eid2                                               ...
# 3830686       No      54        NaN           NaN  ...        NaN       NaN
# 5450636       No      56        NaN           NaN  ...        NaN       NaN
# 5021098       No      64       27.2  Staff 158935  ...     2334.0       NaN
# 2401715       No      58        NaN           NaN  ...        NaN       NaN
# 4181381       No      61       56.9           NaN  ...        NaN       NaN
# ...          ...     ...        ...           ...  ...        ...       ...
# 3827597       No      68       72.4           NaN  ...        NaN       NaN
# 4122899       No      42       55.2           NaN  ...        NaN       NaN
# 4407910       No      46       63.1           NaN  ...        NaN       NaN
# 5281791       No      50       48.5           NaN  ...        NaN       NaN
# 4360102       No      65       23.0           NaN  ...        NaN       NaN
#
#         p5327_i0 p5327_i1 p5326_i1  \
# eid2
# 3830686      NaN      NaN      NaN
# 5450636      NaN      NaN      NaN
# 5021098      NaN      NaN      NaN
# 2401715      NaN      NaN      NaN
# 4181381      NaN      NaN      NaN
# ...          ...      ...      ...
# 3827597      NaN      NaN      NaN
# 4122899      NaN      NaN      NaN
# 4407910      NaN      NaN      NaN
# 5281791      NaN      NaN      NaN
# 4360102      NaN      NaN      NaN
#
#                                                  p20004_i0  \
# eid2
# 3830686  hysterectomy|bilateral oophorectomy|ovarian cy...
# 5450636  reduction or fixation of bone fracture|dilatat...
# 5021098                                                NaN
# 2401715                                                NaN
# 4181381                                          vasectomy
# ...                                                    ...
# 3827597      bunion/hallus valgus surgery|shoulder surgery
# 4122899                         tonsillectomy +/- adenoids
# 4407910                                  male circumcision
# 5281791                   heart surgery|upper limb surgery
# 4360102  hysterectomy|bunion/hallus valgus surgery|musc...
#
#                                                     p41270   p41280_a0   p34  \
# eid2
# 3830686  A09.9 Gastroenteritis and colitis of unspecifi...  2014-10-17  1955
# 5450636  E03.9 Hypothyroidism, unspecified|E66.8 Other ...  2011-06-13  1953
# 5021098  D12.8 Rectum|H47.1 Papilloedema, unspecified|I...  2004-09-27  1944
# 2401715  E03.9 Hypothyroidism, unspecified|H47.1 Papill...  2020-11-05  1951
# 4181381  A09.9 Gastroenteritis and colitis of unspecifi...  2013-04-10  1948
# ...                                                    ...         ...   ...
# 3827597  A49.0 Staphylococcal infection, unspecified|B9...  2015-10-11  1940
# 4122899  F32.9 Depressive episode, unspecified|G93.2 Be...  2014-02-17  1967
# 4407910  D12.8 Rectum|D50.9 Iron deficiency anaemia, un...  2015-01-12  1962
# 5281791  E03.9 Hypothyroidism, unspecified|G43.9 Migrai...  2007-02-27  1957
# 4360102  B96.8 Other specified bacterial agents as the ...  2008-03-05  1943
#
#          IIH_mod
# eid2
# 3830686        1
# 5450636        1
# 5021098        1
# 2401715        1
# 4181381        1
# ...          ...
# 3827597        1
# 4122899        1
# 4407910        1
# 5281791        1
# 4360102        1
#
# [267 rows x 21 columns]

# %%
old_phenotype_dataframe[(old_phenotype_dataframe["IIH_mod"] == 1) & (old_phenotype_dataframe["sex"] == 1)]
# Out:
#          sample_index      eid  F329  F329_F  F329_M  H26  H26_F  H26_M  H269  \
# eid2
# 1609417          3593  1609417   NaN     NaN     NaN  NaN    NaN    NaN   NaN
# 3463715          7575  3463715   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 4555602         18424  4555602   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 3900040         24792  3900040   NaN     NaN     NaN  NaN    NaN    NaN   NaN
# 1219769         27479  1219769   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# ...               ...      ...   ...     ...     ...  ...    ...    ...   ...
# 1000071        473788  1000071   0.0     NaN     0.0  1.0    NaN    1.0   1.0
# 3075338        478422  3075338   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 2308410        495843  2308410   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 2454182        497210  2454182   0.0     NaN     0.0  1.0    NaN    1.0   1.0
# 5862881        497506  5862881   0.0     NaN     0.0  0.0    NaN    0.0   0.0
#
#          H269_F  ...  batch_UKBiLEVEAX_b10  batch_UKBiLEVEAX_b11  \
# eid2             ...
# 1609417     NaN  ...                     0                     0
# 3463715     NaN  ...                     0                     0
# 4555602     NaN  ...                     0                     0
# 3900040     NaN  ...                     0                     0
# 1219769     NaN  ...                     0                     0
# ...         ...  ...                   ...                   ...
# 1000071     NaN  ...                     0                     1
# 3075338     NaN  ...                     0                     0
# 2308410     NaN  ...                     0                     0
# 2454182     NaN  ...                     0                     0
# 5862881     NaN  ...                     0                     0
#
#          batch_UKBiLEVEAX_b3  batch_UKBiLEVEAX_b4  batch_UKBiLEVEAX_b5  \
# eid2
# 1609417                    0                    0                    0
# 3463715                    0                    0                    0
# 4555602                    0                    0                    0
# 3900040                    0                    0                    0
# 1219769                    0                    0                    0
# ...                      ...                  ...                  ...
# 1000071                    0                    0                    0
# 3075338                    0                    0                    0
# 2308410                    0                    0                    0
# 2454182                    0                    0                    0
# 5862881                    0                    0                    0
#
#          batch_UKBiLEVEAX_b6  batch_UKBiLEVEAX_b7  batch_UKBiLEVEAX_b8  \
# eid2
# 1609417                    0                    0                    0
# 3463715                    0                    0                    0
# 4555602                    0                    0                    0
# 3900040                    0                    0                    0
# 1219769                    0                    0                    1
# ...                      ...                  ...                  ...
# 1000071                    0                    0                    0
# 3075338                    0                    0                    0
# 2308410                    0                    0                    0
# 2454182                    0                    0                    0
# 5862881                    0                    0                    0
#
#          batch_UKBiLEVEAX_b9  IIH_mod
# eid2
# 1609417                    0      1.0
# 3463715                    0      1.0
# 4555602                    0      1.0
# 3900040                    0      1.0
# 1219769                    0      1.0
# ...                      ...      ...
# 1000071                    0      1.0
# 3075338                    0      1.0
# 2308410                    0      1.0
# 2454182                    0      1.0
# 5862881                    0      1.0
#
# [70 rows x 188 columns]

# %% [markdown]
# ### sort new dataframe - change, only for presentation

# %%
TEST_BIM_PATH = "/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered.bim"
TEST_BED_PATH = "/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered.bed"
TEST_FAM_PATH = "/cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered.fam"
PLINK_PATH = "/cs/usr/nadavb/third_party/plink2"

# %%
a = pdp.read_plink1_bin(TEST_BED_PATH,TEST_BIM_PATH,TEST_FAM_PATH,verbose=False)

# %%
eid_vals_in_files =  list(a['iid'].values)
eid_vals_in_files_set = set(eid_vals_in_files)

# %%
old_phenotype_dataframe = old_phenotype_dataframe[old_phenotype_dataframe['eid'].isin(eid_vals_in_files)]

# %%
print(len(old_phenotype_dataframe))
print(len(eid_vals_in_files))
# Out:
# 274215
# 274215

# %%
old_phenotype_dataframe['sort_key'] = old_phenotype_dataframe['eid'].astype("str").apply(lambda x: eid_vals_in_files.index(x) if x in eid_vals_in_files_set else float('inf'))
# Out:
# /cs/usr/roeizucker/my_python/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
old_phenotype_dataframe = old_phenotype_dataframe.sort_values(by='sort_key')

# %%
old_phenotype_dataframe[["eid","IIH_mod"]].to_csv(PHENOTYPE_FILE_NAME)

# %%
print(PHENOTYPE_FILE_NAME)
# Out:
# /cs/usr/roeizucker/Desktop/temp/SKAT_delete_me/phens.csv

# %%
old_phenotype_dataframe
# Out:
#          sample_index      eid  F329  F329_F  F329_M  H26  H26_F  H26_M  H269  \
# eid2
# 1688461        411779  1688461   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 5444187        352393  5444187   NaN     NaN     NaN  NaN    NaN    NaN   NaN
# 2676900        258733  2676900   0.0     0.0     NaN  0.0    0.0    NaN   0.0
# 3709342        150866  3709342   0.0     0.0     NaN  0.0    0.0    NaN   0.0
# 3769417        270220  3769417   0.0     0.0     NaN  0.0    0.0    NaN   0.0
# ...               ...      ...   ...     ...     ...  ...    ...    ...   ...
# 1176921        320265  1176921   0.0     0.0     NaN  1.0    1.0    NaN   1.0
# 1339882        263982  1339882   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 1470962        330791  1470962   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 1193917        233981  1193917   0.0     0.0     NaN  1.0    1.0    NaN   1.0
# 1196108        129496  1196108   0.0     0.0     NaN  0.0    0.0    NaN   0.0
#
#          H269_F  ...  batch_UKBiLEVEAX_b11  batch_UKBiLEVEAX_b3  \
# eid2             ...
# 1688461     NaN  ...                     0                    0
# 5444187     NaN  ...                     0                    0
# 2676900     0.0  ...                     0                    0
# 3709342     0.0  ...                     0                    0
# 3769417     0.0  ...                     0                    0
# ...         ...  ...                   ...                  ...
# 1176921     1.0  ...                     1                    0
# 1339882     NaN  ...                     1                    0
# 1470962     NaN  ...                     1                    0
# 1193917     1.0  ...                     1                    0
# 1196108     0.0  ...                     1                    0
#
#          batch_UKBiLEVEAX_b4  batch_UKBiLEVEAX_b5  batch_UKBiLEVEAX_b6  \
# eid2
# 1688461                    0                    0                    0
# 5444187                    0                    0                    0
# 2676900                    0                    0                    0
# 3709342                    0                    0                    0
# 3769417                    0                    0                    0
# ...                      ...                  ...                  ...
# 1176921                    0                    0                    0
# 1339882                    0                    0                    0
# 1470962                    0                    0                    0
# 1193917                    0                    0                    0
# 1196108                    0                    0                    0
#
#          batch_UKBiLEVEAX_b7  batch_UKBiLEVEAX_b8  batch_UKBiLEVEAX_b9  \
# eid2
# 1688461                    0                    0                    0
# 5444187                    0                    0                    0
# 2676900                    0                    0                    0
# 3709342                    0                    0                    0
# 3769417                    0                    0                    0
# ...                      ...                  ...                  ...
# 1176921                    0                    0                    0
# 1339882                    0                    0                    0
# 1470962                    0                    0                    0
# 1193917                    0                    0                    0
# 1196108                    0                    0                    0
#
#          IIH_mod  sort_key
# eid2
# 1688461      0.0         0
# 5444187      0.0         1
# 2676900      0.0         2
# 3709342      0.0         3
# 3769417      0.0         4
# ...          ...       ...
# 1176921      0.0    487364
# 1339882      0.0    487365
# 1470962      0.0    487366
# 1193917      0.0    487381
# 1196108      0.0    487388
#
# [332689 rows x 189 columns]

# %% [markdown]
# ## create compatible Plink and phenotype files
# for SKAT to work the phenotype and genotype files need to be the same length, and have the same order. Participants that appear in only one dataset need to be removed.

# %%
BASE_PLINK_FORMAT_PATH = "/cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch"
PLINK_PATH = "/cs/usr/nadavb/third_party/plink2"

# %%
for i in range(1,2):
    bim_path = BASE_PLINK_FORMAT_PATH + str(i) + ".bim"
    fam_path = BASE_PLINK_FORMAT_PATH + str(i) + ".fam"
    bed_path = BASE_PLINK_FORMAT_PATH + str(i) + ".bed"
    ! {PLINK_PATH} --bim {bim_path} --fam {fam_path} --bed {bed_path} --keep-fam /cs/labs/michall/roeizucker/SKAT_experiments/I10_eid_notNA.txt --make-bed --out /cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{i}
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_1.log.
# Options in effect:
#   --keep-fam /cs/labs/michall/roeizucker/SKAT_experiments/I10_eid_notNA.txt
#   --make-bed
#   --out /cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_1
#   --pgen /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.bed
#   --psam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.fam
#   --pvar /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.bim
#
# Start time: Wed Feb  1 22:31:12 2023
# 128748 MiB RAM detected; reserving 64374 MiB for main workspace.
# Using up to 8 compute threads.
# 487409 samples (264362 females, 223033 males, 14 ambiguous; 487409 founders)
# loaded from
# /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.fam.
# 64451 variants loaded from
# /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.bim.
# Note: No phenotype data present.
# --keep-fam: 274215 samples remaining.
# 274215 samples (148870 females, 125345 males; 274215 founders) remaining after
# main filters.
# Writing /cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_1.fam ...
# done.
# Writing /cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_1.bim ...
# done.
# Writing /cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_1.bed ...
# 0%

# %%
! {PLINK_PATH} --bim {TEST_BIM_PATH} --fam {TEST_FAM_PATH} --bed {TEST_BED_PATH} --keep-fam /cs/labs/michall/roeizucker/SKAT_experiments/I10_eid_notNA.txt --make-bed --out /cs/labs/michall/roeizucker/SKAT_experiments/mydata_filtered_{i}

# %% [markdown]
# ## Create phenotype files
# Phenotype files must be the same order and lenght as the genotype files

# %%
BASIC_PHENOTYPE_FILE = "/cs/usr/roeizucker/Desktop/temp/SKAT_delete_me/phens.csv"

# %%
basic_phenotype_df = pd.read_csv(BASIC_PHENOTYPE_FILE) # we will use this DF to determine order and length of phenotypes
other_phenotype_df = pd.read_csv("/cs/labs/michall/roeizucker/ukb_files/menapause_with_outcomes.csv")
# Out:
# /cs/usr/roeizucker/my_python/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,254,256) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
other_phenotype_df["eid"] = other_phenotype_df["Participant ID"]

# %%
other_phenotype_df["eid2"] = other_phenotype_df["eid"]
other_phenotype_df = other_phenotype_df[other_phenotype_df['eid2'].isin(list(basic_phenotype_df["eid2"]))]

# %%
len(basic_phenotype_df)
# Out:
# 274215

# %%
basic_phenotype_df.set_index(['eid2'], inplace=True)
other_phenotype_df.set_index(['eid2'], inplace=True)

# %%
other_phenotype_df["osteoporosis"] = other_phenotype_df["M81.9 Osteoporosis, unspecified_Label"]
other_phenotype_df["fatty_liver"] = other_phenotype_df["K76.0 Fatty (change of) liver, not elsewhere classified_Label"]
basic_phenotype_df["osteoporosis"] = other_phenotype_df["osteoporosis"]
basic_phenotype_df["fatty_liver"] = other_phenotype_df["fatty_liver"]

# %%
basic_phenotype_df[basic_phenotype_df["fatty_liver"] == -1] = 0
basic_phenotype_df[basic_phenotype_df["osteoporosis"] == -1] = 0

# %%
basic_phenotype_df["osteoporosis"] = basic_phenotype_df["osteoporosis"].fillna(0)
basic_phenotype_df["fatty_liver"] = basic_phenotype_df["fatty_liver"].fillna(0)

# %%
basic_phenotype_df.to_csv("/cs/labs/michall/roeizucker/hackton_meno/labels_1.csv",index=False)

# %%
print(PROJECT_PATH)
# Out:
# /cs/labs/michall/roeizucker/SKAT_experiments/SetID

# %%
# find files for a specific gene
import os, glob
path = "/cs/labs/michall/roeizucker/IIH"
for filename in glob.glob(os.path.join(path, '*.SetID')):
    with open(os.path.join(os.getcwd(), filename), 'r') as f: # open in readonly mode
        val = f.read()
        if "Q9UNW9" in val:
            print(filename)
#             print(val)

# %%
# find files for a specific gene
import os, glob
path = "~"
for filename in glob.glob(os.path.join(path, '*.csv')):
    with open(os.path.join(os.getcwd(), filename), 'r') as f: # open in readonly mode
        if "Q9UN" in f.read():
            print(filename)

# %%
# create GWAS phenotype file:
# f'sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="{BASH_FILE}"')
for i in range(1,23):
    inner_command = (f"/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch{i}.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch{i}.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch{i}.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr{i} --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000")
    print(f'sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="{inner_command}"')
# Out:
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr1 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch2.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch2.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch2.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr2 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch3.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch3.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch3.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr3 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch4.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch4.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch4.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr4 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch5.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch5.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch5.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr5 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch6.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch6.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch6.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr6 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch7.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch7.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch7.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr7 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch8.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch8.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch8.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr8 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch9.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch9.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch9.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr9 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch10.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch10.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch10.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr10 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch11.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch11.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch11.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr11 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch12.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch12.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch12.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr12 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch13.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch13.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch13.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr13 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch14.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch14.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch14.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr14 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch15.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch15.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch15.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr15 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch16.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch16.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch16.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr16 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch17.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch17.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch17.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr17 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch18.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch18.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch18.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr18 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch19.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch19.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch19.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr19 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch20.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch20.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch20.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr20 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch21.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch21.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch21.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr21 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch22.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch22.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch22.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/amos/continuous_run/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr22 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"

# %%
# small covariates /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt 
# create GWAS phenotype file:
# f'sbatch --array=0-150 --mem=15g -c1 --time=1-0 --killable --requeue --wrap="{BASH_FILE}"')
for i in range(1,23):
    inner_command = (f"/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch{i}.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch{i}.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch{i}.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr{i} --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000")
    print(f'sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="{inner_command}"')
# Out:
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch1.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr1 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch2.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch2.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch2.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr2 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch3.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch3.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch3.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr3 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch4.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch4.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch4.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr4 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch5.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch5.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch5.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr5 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch6.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch6.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch6.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr6 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch7.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch7.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch7.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr7 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch8.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch8.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch8.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr8 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch9.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch9.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch9.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr9 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch10.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch10.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch10.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr10 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch11.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch11.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch11.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr11 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch12.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch12.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch12.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr12 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch13.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch13.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch13.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr13 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch14.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch14.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch14.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr14 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch15.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch15.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch15.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr15 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch16.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch16.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch16.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr16 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch17.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch17.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch17.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr17 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch18.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch18.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch18.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr18 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch19.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch19.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch19.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr19 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch20.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch20.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch20.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr20 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch21.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch21.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch21.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr21 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"
# sbatch --mem=15g -c1 --time=1-0 --killable --requeue --wrap="/cs/usr/nadavb/third_party/plink2 --bed /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch22.bed --bim /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch22.bim --fam /cs/labs/michall/roeizucker/plink_results/reduced_snps2/small_ch22.fam --pheno /cs/labs/michall/roeizucker/IIH/GWAS/phenotypes/iih_mod.txt --covar /cs/labs/michall/roeizucker/IIH/GWAS/covariates.txt  --out  /cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr22 --1 --glm hide-covar --mac 20 --covar-variance-standardize --freq --threads 10 --memory 10000"

# %%
# create smaller covariats file:
path = '/cs/labs/michall/roeizucker/10krun/runs/0:11'
PHEN_PATH = path + "/ukbb_dataset.csv"
GWAS_PATH = "/cs/labs/michall/roeizucker/IIH/GWAS"
cancer_dataset = pd.read_csv(PHEN_PATH)
# FAM_Cov[,7:14]

covariate_cols = list(cancer_dataset)[15:22]
covariate_values = cancer_dataset[['eid', 'eid'] + [covariate_col for covariate_col in covariate_cols if \
        covariate_col != 'const']].dropna()
covariate_values.to_csv(f"{GWAS_PATH}/covariates.txt", header = False, index = False, sep = '\t')
print('Done.')
# Out:
# Done.

# %%
# combine plink results
all_dfs = []
for i in range(1,23):
    df = pd.read_csv(f"/cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_chr{i}.PHENO1.glm.logistic", sep="\t")
    all_dfs.append(df)

# %%
# combine small covariates plink results
all_small_covar_dfs = []
for i in range(1,23):
    df = pd.read_csv(f"/cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_small_cov_chr{i}.PHENO1.glm.logistic", sep="\t")
    all_dfs.append(df)

# save file
small_cover_result = pd.concat(all_dfs)
small_cover_result = small_cover_result.reset_index()

# %%
result = pd.concat(all_dfs)
result = result.reset_index()

# %%
result
# Out:
#         index  #CHROM       POS           ID REF ALT A1 TEST    OBS_CT  \
# 0           0       1     69428  rs140739101   G   T  G  ADD  185796.0
# 1           1       1     69487  rs568226429   A   G  A  ADD  215183.0
# 2           2       1     69496  rs150690004   A   G  A  ADD  215172.0
# 3           3       1     69521  rs553724620   A   T  A  ADD  214929.0
# 4           4       1     69569    rs2531267   C   T  C  ADD  215160.0
# ...       ...     ...       ...          ...  ..  .. ..  ...       ...
# 571731   6852      22  51183430  rs547756808   G   C  G  ADD  274214.0
# 571732   6853      22  51183575  rs531270968   A   C  A  ADD  274101.0
# 571733   6854      22  51183576  rs201653264   A   G  A  ADD  273408.0
# 571734   6855      22  51183608  rs571073375   C   G  C  ADD  274206.0
# 571735   6856      22  51216386   rs75855559   G   T  G  ADD  274175.0
#
#               OR  LOG(OR)_SE    Z_STAT         P  GENE
# 0       0.810917    0.711121 -0.294731  0.768199  None
# 1            NaN         NaN       NaN       NaN  None
# 2            NaN         NaN       NaN       NaN  None
# 3            NaN         NaN       NaN       NaN  None
# 4            NaN         NaN       NaN       NaN  None
# ...          ...         ...       ...       ...   ...
# 571731       NaN         NaN       NaN       NaN  None
# 571732       NaN         NaN       NaN       NaN  None
# 571733       NaN         NaN       NaN       NaN  None
# 571734       NaN         NaN       NaN       NaN  None
# 571735       NaN         NaN       NaN       NaN  None
#
# [571736 rows x 14 columns]

# %%
# add gene to result:
def add_genes_for_snps(df,genes_csv):
    sig_genes = set()
    for i in range(len(df)):
        if i % 10000 == 0:
            print(i/len(df) * 100)
        row = df.loc[i]
        curr = (genes_csv.query("chr == '" + str(row["#CHROM"]) + "' and cds_start <= " + str(row["POS"]) + "and cds_end >= " + str(row["POS"])))
        if len(list(curr["uniprot_id"]))> 0:
            df.loc[i,"GENE"] = list(curr["uniprot_id"])[0]
#         row["GENE"] = list(curr["uniprot_id"])[0]
#         sig_genes.add(list(curr["uniprot_id"])[0])
    return sig_genes
genes_csv = pd.read_csv(GENE_FILE_PATH)
small_cover_result["GENE"] = None
# add_genes_for_snps(result,genes_csv)
add_genes_for_snps(small_cover_result,genes_csv)

# result.loc[3,"GENE"] = "bob" small_cover_result
# print(result.loc[3])
# Out:
# 0.0
# 0.8679229562150228
# 1.7358459124300456
# 2.603768868645068
# 3.471691824860091
# 4.339614781075114
# 5.207537737290136
# 6.075460693505159
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-909b50f2edbc> in <module>
#      15 small_cover_result["GENE"] = None
#      16 # add_genes_for_snps(result,genes_csv)
# ---> 17 add_genes_for_snps(small_cover_result,genes_csv)
#      18
#      19 # result.loc[3,"GENE"] = "bob" small_cover_result
#
# <ipython-input-66-909b50f2edbc> in add_genes_for_snps(df, genes_csv)
#       8         curr = (genes_csv.query("chr == '" + str(row["#CHROM"]) + "' and cds_start <= " + str(row["POS"]) + "and cds_end >= " + str(row["POS"])))
#       9         if len(list(curr["uniprot_id"]))> 0:
# ---> 10             df.loc[i,"GENE"] = list(curr["uniprot_id"])[0]
#      11 #         row["GENE"] = list(curr["uniprot_id"])[0]
#      12 #         sig_genes.add(list(curr["uniprot_id"])[0])
#
# ~/my_python/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~/my_python/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1761                 # scalar value
#    1762                 for loc in ilocs:
# -> 1763                     isetter(loc, value)
#    1764
#    1765         else:
#
# ~/my_python/lib/python3.7/site-packages/pandas/core/indexing.py in isetter(loc, v)
#    1691
#    1692                 # reset the sliced object if unique
# -> 1693                 self.obj._iset_item(loc, ser)
#    1694
#    1695             # we need an iterable, with a ndim of at least 1
#
# ~/my_python/lib/python3.7/site-packages/pandas/core/frame.py in _iset_item(self, loc, value)
#    3099         #  but the behavior is the same as long as we pass broadcast=False
#    3100         value = self._sanitize_column(loc, value, broadcast=False)
# -> 3101         NDFrame._iset_item(self, loc, value)
#    3102
#    3103         # check if we are modifying a copy
#
# ~/my_python/lib/python3.7/site-packages/pandas/core/generic.py in _iset_item(self, loc, value)
#    3567
#    3568     def _iset_item(self, loc: int, value) -> None:
# -> 3569         self._mgr.iset(loc, value)
#    3570         self._clear_item_cache()
#    3571
#
# ~/my_python/lib/python3.7/site-packages/pandas/core/internals/managers.py in iset(self, loc, value)
#    1094             blk_locs = blklocs[val_locs.indexer]
#    1095             if blk.should_store(value):
# -> 1096                 blk.set(blk_locs, value_getitem(val_locs))
#    1097             else:
#    1098                 unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# ~/my_python/lib/python3.7/site-packages/pandas/core/internals/blocks.py in set(self, locs, values)
#     329         create a new array and always creates a new Block.
#     330         """
# --> 331         self.values[locs] = values
#     332
#     333     def delete(self, loc) -> None:
#
# KeyboardInterrupt:

# %%
result.to_csv("/cs/labs/michall/roeizucker/IIH/GWAS/results/iih_mod_gwas.csv")

# %%
small_cover_result

# %%
result
# Out:
#         index  #CHROM       POS           ID REF ALT A1 TEST    OBS_CT  \
# 0           0       1     69428  rs140739101   G   T  G  ADD  185796.0
# 1           1       1     69487  rs568226429   A   G  A  ADD  215183.0
# 2           2       1     69496  rs150690004   A   G  A  ADD  215172.0
# 3           3       1     69521  rs553724620   A   T  A  ADD  214929.0
# 4           4       1     69569    rs2531267   C   T  C  ADD  215160.0
# ...       ...     ...       ...          ...  ..  .. ..  ...       ...
# 571731   6852      22  51183430  rs547756808   G   C  G  ADD  274214.0
# 571732   6853      22  51183575  rs531270968   A   C  A  ADD  274101.0
# 571733   6854      22  51183576  rs201653264   A   G  A  ADD  273408.0
# 571734   6855      22  51183608  rs571073375   C   G  C  ADD  274206.0
# 571735   6856      22  51216386   rs75855559   G   T  G  ADD  274175.0
#
#               OR  LOG(OR)_SE    Z_STAT         P  GENE  CHR        BP  \
# 0       0.810917    0.711121 -0.294731  0.768199  None    1     69428
# 1            NaN         NaN       NaN       NaN  None    1     69487
# 2            NaN         NaN       NaN       NaN  None    1     69496
# 3            NaN         NaN       NaN       NaN  None    1     69521
# 4            NaN         NaN       NaN       NaN  None    1     69569
# ...          ...         ...       ...       ...   ...  ...       ...
# 571731       NaN         NaN       NaN       NaN  None   22  51183430
# 571732       NaN         NaN       NaN       NaN  None   22  51183575
# 571733       NaN         NaN       NaN       NaN  None   22  51183576
# 571734       NaN         NaN       NaN       NaN  None   22  51183608
# 571735       NaN         NaN       NaN       NaN  None   22  51216386
#
#                 SNP
# 0       rs140739101
# 1       rs568226429
# 2       rs150690004
# 3       rs553724620
# 4         rs2531267
# ...             ...
# 571731  rs547756808
# 571732  rs531270968
# 571733  rs201653264
# 571734  rs571073375
# 571735   rs75855559
#
# [571736 rows x 17 columns]

# %%
import pandas as pd
import dash_bio

# df = pd.read_csv('https://raw.githubusercontent.com/plotly/dash-bio-docs-files/master/manhattan_data.csv')

result["CHR"] = result["#CHROM"]
result["BP"] = result["POS"]
result["SNP"] = result["ID"]

dash_bio.ManhattanPlot(
    dataframe=result,
)
