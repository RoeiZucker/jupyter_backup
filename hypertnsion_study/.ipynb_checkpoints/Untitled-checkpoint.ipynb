# %%
import os
import os.path
import glob
import pandas as pd

# %%
DOWNSAMPLE_DIR = '/cs/labs/michall/roeizucker/hypertension_study/downsampled'
RESULTS_DIR = DOWNSAMPLE_DIR + "/results"
THREASHOLD = 0.05

# %%
# directory = "/cs/labs/michall/roeizucker/phewas_run/runs1"
# for a in [x[0] for x in os.walk(directory)]:
#     print(a)
for i in range(2,100):
#     print(i)
    result_file = f"{RESULTS_DIR}/E03_F_{i}.csv"
    if not os.path.exists(result_file):
        print(f"echo {i}")
        print(f"combine_pwas_results --genes-file=~/my_storage/virt_env_install_test/genes_hg19.csv --per-gene-pwas-results-dir={DOWNSAMPLE_DIR}/E03_F_{i} --results-file={result_file}")
#     !mkdir /cs/labs/michall/roeizucker/hypertension_study/downsampled/E03_F_{i}
#     f = open(f"/cs/labs/michall/roeizucker/hypertension_study/downsampled/E03_F_{i}.sh", "a")
#     f.write("source ~/my_python/bin/activate\n")
#     f.write(f"pwas_test_genes --resolve-quasi-complete-covariate-separation --remove-multicollinear-covariate --dataset-file=/cs/labs/michall/roeizucker/hypertension_study/downsampled/ukbb_dataset_E03_{i}.csv --gene-effect-scores-dir=/cs/labs/michall/roeizucker/virt_env_install_test/ukbb_imputation_gene_effect_scores/ --per-gene-pwas-results-dir=/cs/labs/michall/roeizucker/hypertension_study/downsampled/E03_F_{i} --sample-id-col=eid --phenotype-col='E03_F' --covariate-cols-json-file=/cs/labs/michall/roeizucker/hypertension_study/ukbb_covariate_columns.json --task-index-env-variable=SLURM_ARRAY_TASK_ID --total-tasks-env-variable=SLURM_ARRAY_TASK_COUNT\n")
#     f.close()
#     !chmod 744 /cs/labs/michall/roeizucker/hypertension_study/downsampled/E03_F_{i}.sh
# Out:
# echo 38
# combine_pwas_results --genes-file=~/my_storage/virt_env_install_test/genes_hg19.csv --per-gene-pwas-results-dir=/cs/labs/michall/roeizucker/hypertension_study/downsampled/E03_F_38 --results-file=/cs/labs/michall/roeizucker/hypertension_study/downsampled/results/E03_F_38.csv
# echo 50
# combine_pwas_results --genes-file=~/my_storage/virt_env_install_test/genes_hg19.csv --per-gene-pwas-results-dir=/cs/labs/michall/roeizucker/hypertension_study/downsampled/E03_F_50 --results-file=/cs/labs/michall/roeizucker/hypertension_study/downsampled/results/E03_F_50.csv

# %%
os.chdir(RESULTS_DIR)
sig_genes = []
for file in glob.glob("E03_F*.csv"):
    df = pd.read_csv(f"{RESULTS_DIR}/{file}")
#     filtered_df = df[df["fdr_significance"]]
    filtered_df = df[df["fdr_qval"] < THREASHOLD]
    sig_genes.append([list(filtered_df["uniprot_id"]),list(filtered_df["symbol"]),list(filtered_df["name"])])
#     print(file)

# %%
appreances_dict = {}
for genes_list in sig_genes:
    for i,gene in enumerate(genes_list[0]):
        if gene not in appreances_dict:
#             print(len(genes_list))
            appreances_dict[gene] = [0,genes_list[0][i],genes_list[1][i],genes_list[2][i]]
        appreances_dict[gene][0]+=1

# %%
print(len(appreances_dict))
print(appreances_dict)
male_df = pd.read_csv(f"{RESULTS_DIR}/E03_M_2.csv")
# male_sig_genes = list(male_df[male_df["fdr_significance"]]["uniprot_id"])
male_sig_genes = list(male_df[male_df["fdr_qval"] < THREASHOLD]["uniprot_id"])
print("male_sig_genes:")
for gene in male_sig_genes:
    if gene in appreances_dict:
        print(gene,appreances_dict[gene])
    else:
        print(gene,0)
# Out:
# 63
# {'P16410': [63, 'P16410', 'CTLA4', 'cytotoxic T-lymphocyte associated protein 4'], 'Q6UXA7': [84, 'Q6UXA7', 'C6orf15', 'chromosome 6 open reading frame 15'], 'Q15109': [28, 'Q15109', 'AGER', 'advanced glycosylation end-product specific receptor'], 'Q9UQQ2': [85, 'Q9UQQ2', 'SH2B3', 'SH2B adaptor protein 3'], 'Q9H816': [57, 'Q9H816', 'DCLRE1B', 'DNA cross-link repair 1B'], 'Q9UIG5': [15, 'Q9UIG5', 'PSORS1C1', 'psoriasis susceptibility 1 candidate 1'], 'O95873': [38, 'O95873', 'C6orf47', 'chromosome 6 open reading frame 47'], 'Q9UIG4': [15, 'Q9UIG4', 'PSORS1C2', 'psoriasis susceptibility 1 candidate 2'], 'Q9Y242': [31, 'Q9Y242', 'TCF19', 'transcription factor 19'], 'O00453': [26, 'O00453', 'LST1', 'leukocyte specific transcript 1'], 'Q6NYC8': [4, 'Q6NYC8', 'PPP1R18', 'protein phosphatase 1 regulatory subunit 18'], 'P01906': [1, 'P01906', 'HLA-DQA2', 'major histocompatibility complex, class II, DQ alpha 2'], 'Q9UMR5': [3, 'Q9UMR5', 'PPT2', 'palmitoyl-protein thioesterase 2'], 'Q96KR7': [1, 'Q96KR7', 'PHACTR3', 'phosphatase and actin regulator 3'], 'Q5SSG8': [3, 'Q5SSG8', 'MUC21', 'mucin 21, cell surface associated'], 'Q5SSQ6': [1, 'Q5SSQ6', 'SAPCD1', 'suppressor APC domain containing 1'], 'Q9Y6B7': [1, 'Q9Y6B7', 'AP4B1', 'adaptor related protein complex 4 subunit beta 1'], 'P0C0L4': [5, 'P0C0L4', 'C4A', 'complement C4A (Rodgers blood group)'], 'P34931': [17, 'P34931', 'HSPA1L', 'heat shock protein family A (Hsp70) member 1 like'], 'Q8IZS7': [2, 'Q8IZS7', 'CLECL1', 'C-type lectin like 1'], 'Q5SRN2': [2, 'Q5SRN2', 'TSBP1', 'testis expressed basic protein 1'], 'Q99880': [2, 'Q99880', 'H2BC13', 'H2B clustered histone 13'], 'Q6U7Q0': [1, 'Q6U7Q0', 'ZNF322', 'zinc finger protein 322'], 'Q6J9G0': [1, 'Q6J9G0', 'STYK1', 'serine/threonine/tyrosine kinase 1'], 'Q86YN6': [1, 'Q86YN6', 'PPARGC1B', 'PPARG coactivator 1 beta'], 'Q969F9': [1, 'Q969F9', 'HPS3', 'HPS3 biogenesis of lysosomal organelles complex 2 subunit 1'], 'Q99496': [1, 'Q99496', 'RNF2', 'ring finger protein 2'], 'Q96KQ7': [1, 'Q96KQ7', 'EHMT2', 'euchromatic histone lysine methyltransferase 2'], 'O95395': [1, 'O95395', 'GCNT3', 'glucosaminyl (N-acetyl) transferase 3, mucin type'], 'Q7L1V2': [1, 'Q7L1V2', 'MON1B', 'MON1 homolog B, secretory trafficking associated'], 'Q14653': [2, 'Q14653', 'IRF3', 'interferon regulatory factor 3'], 'Q8NGJ8': [1, 'Q8NGJ8', 'OR51S1', 'olfactory receptor family 51 subfamily S member 1'], 'Q9UGF7': [1, 'Q9UGF7', 'OR12D3', 'olfactory receptor family 12 subfamily D member 3'], 'Q4VX62': [1, 'Q4VX62', 'LINC02901', 'long intergenic non-protein coding RNA 2901'], 'Q9NP31': [3, 'Q9NP31', 'SH2D2A', 'SH2 domain containing 2A'], 'Q6ZT07': [1, 'Q6ZT07', 'TBC1D9', 'TBC1 domain family member 9'], 'Q5JTZ5': [1, 'Q5JTZ5', 'C9orf152', 'chromosome 9 open reading frame 152'], 'O75182': [1, 'O75182', 'SIN3B', 'SIN3 transcription regulator family member B'], 'Q8TF44': [1, 'Q8TF44', 'C2CD4C', 'C2 calcium dependent domain containing 4C'], 'Q9Y4D2': [1, 'Q9Y4D2', 'DAGLA', 'diacylglycerol lipase alpha'], 'Q96CS3': [1, 'Q96CS3', 'FAF2', 'Fas associated factor family member 2'], 'Q99466': [1, 'Q99466', 'NOTCH4', 'notch receptor 4'], 'P43119': [2, 'P43119', 'PTGIR', 'prostaglandin I2 receptor'], 'Q86X55': [1, 'Q86X55', 'CARM1', 'coactivator associated arginine methyltransferase 1'], 'P04440': [2, 'P04440', 'HLA-DPB1', 'major histocompatibility complex, class II, DP beta 1'], 'Q96S38': [1, 'Q96S38', 'RPS6KC1', 'ribosomal protein S6 kinase C1'], 'P05106': [1, 'P05106', 'ITGB3', 'integrin subunit beta 3'], 'P19875': [1, 'P19875', 'CXCL2', 'C-X-C motif chemokine ligand 2'], 'Q9NVL1': [1, 'Q9NVL1', 'FAM86C1P', 'family with sequence similarity 86 member C1, pseudogene'], 'Q8IWB1': [1, 'Q8IWB1', 'ITPRIP', 'inositol 1,4,5-trisphosphate receptor interacting protein'], 'P20036': [2, 'P20036', 'HLA-DPA1', 'major histocompatibility complex, class II, DP alpha 1'], 'Q8NEM2': [2, 'Q8NEM2', 'SHCBP1', 'SHC binding and spindle associated 1'], 'Q8NGR1': [1, 'Q8NGR1', 'OR13A1', 'olfactory recep ...
# male_sig_genes:
# P16410 [63, 'P16410', 'CTLA4', 'cytotoxic T-lymphocyte associated protein 4']
# Q9H816 [57, 'Q9H816', 'DCLRE1B', 'DNA cross-link repair 1B']
# Q6UXA7 [84, 'Q6UXA7', 'C6orf15', 'chromosome 6 open reading frame 15']
# Q9UQQ2 [85, 'Q9UQQ2', 'SH2B3', 'SH2B adaptor protein 3']
# Q9Y242 [31, 'Q9Y242', 'TCF19', 'transcription factor 19']
# P78330 0
# Q9BU70 0

# %%
appreances_list = []
for key in appreances_dict:
    appreances_list.append([key,appreances_dict[key]])
appreances_list.sort(key=lambda x:x[1][0],reverse=True)
print(appreances_list)
# Out:
# [['Q9UQQ2', [95, 'Q9UQQ2', 'SH2B3', 'SH2B adaptor protein 3']], ['Q6UXA7', [91, 'Q6UXA7', 'C6orf15', 'chromosome 6 open reading frame 15']], ['P16410', [88, 'P16410', 'CTLA4', 'cytotoxic T-lymphocyte associated protein 4']], ['Q9H816', [80, 'Q9H816', 'DCLRE1B', 'DNA cross-link repair 1B']], ['O95873', [63, 'O95873', 'C6orf47', 'chromosome 6 open reading frame 47']], ['Q9Y242', [58, 'Q9Y242', 'TCF19', 'transcription factor 19']], ['Q15109', [51, 'Q15109', 'AGER', 'advanced glycosylation end-product specific receptor']], ['Q9UIG5', [46, 'Q9UIG5', 'PSORS1C1', 'psoriasis susceptibility 1 candidate 1']], ['O00453', [45, 'O00453', 'LST1', 'leukocyte specific transcript 1']], ['P34931', [42, 'P34931', 'HSPA1L', 'heat shock protein family A (Hsp70) member 1 like']], ['Q9UIG4', [39, 'Q9UIG4', 'PSORS1C2', 'psoriasis susceptibility 1 candidate 2']], ['Q6NYC8', [17, 'Q6NYC8', 'PPP1R18', 'protein phosphatase 1 regulatory subunit 18']], ['Q5SSG8', [16, 'Q5SSG8', 'MUC21', 'mucin 21, cell surface associated']], ['Q9UMR5', [15, 'Q9UMR5', 'PPT2', 'palmitoyl-protein thioesterase 2']], ['Q9NP31', [14, 'Q9NP31', 'SH2D2A', 'SH2 domain containing 2A']], ['P01906', [13, 'P01906', 'HLA-DQA2', 'major histocompatibility complex, class II, DQ alpha 2']], ['Q6UW10', [12, 'Q6UW10', 'SFTA2', 'surfactant associated 2']], ['Q8IZS7', [11, 'Q8IZS7', 'CLECL1', 'C-type lectin like 1']], ['P0C0L4', [10, 'P0C0L4', 'C4A', 'complement C4A (Rodgers blood group)']], ['P04440', [9, 'P04440', 'HLA-DPB1', 'major histocompatibility complex, class II, DP beta 1']], ['P20036', [9, 'P20036', 'HLA-DPA1', 'major histocompatibility complex, class II, DP alpha 1']], ['Q9H3S4', [8, 'Q9H3S4', 'TPK1', 'thiamin pyrophosphokinase 1']], ['Q9H633', [7, 'Q9H633', 'RPP21', 'ribonuclease P/MRP subunit p21']], ['Q99880', [7, 'Q99880', 'H2BC13', 'H2B clustered histone 13']], ['P08397', [7, 'P08397', 'HMBS', 'hydroxymethylbilane synthase']], ['Q5SRN2', [7, 'Q5SRN2', 'TSBP1', 'testis expressed basic protein 1']], ['P43119', [6, 'P43119', 'PTGIR', 'prostaglandin I2 receptor']], ['Q969F9', [6, 'Q969F9', 'HPS3', 'HPS3 biogenesis of lysosomal organelles complex 2 subunit 1']], ['Q30154', [6, 'Q30154', 'HLA-DRB5', 'major histocompatibility complex, class II, DR beta 5']], ['Q8NGR1', [6, 'Q8NGR1', 'OR13A1', 'olfactory receptor family 13 subfamily A member 1']], ['Q99466', [6, 'Q99466', 'NOTCH4', 'notch receptor 4']], ['Q96S38', [6, 'Q96S38', 'RPS6KC1', 'ribosomal protein S6 kinase C1']], ['Q99496', [5, 'Q99496', 'RNF2', 'ring finger protein 2']], ['P19875', [5, 'P19875', 'CXCL2', 'C-X-C motif chemokine ligand 2']], ['Q96KR7', [5, 'Q96KR7', 'PHACTR3', 'phosphatase and actin regulator 3']], ['Q9Y6B7', [5, 'Q9Y6B7', 'AP4B1', 'adaptor related protein complex 4 subunit beta 1']], ['Q8NEM2', [5, 'Q8NEM2', 'SHCBP1', 'SHC binding and spindle associated 1']], ['Q9UGF7', [5, 'Q9UGF7', 'OR12D3', 'olfactory receptor family 12 subfamily D member 3']], ['Q9BU70', [5, 'Q9BU70', 'TRMO', 'tRNA methyltransferase O']], ['Q9NX08', [4, 'Q9NX08', 'COMMD8', 'COMM domain containing 8']], ['Q32P44', [4, 'Q32P44', 'EML3', 'EMAP like 3']], ['Q7L1V2', [4, 'Q7L1V2', 'MON1B', 'MON1 homolog B, secretory trafficking associated']], ['P01903', [4, 'P01903', 'HLA-DRA', 'major histocompatibility complex, class II, DR alpha']], ['Q01860', [4, 'Q01860', 'POU5F1', 'POU class 5 homeobox 1']], ['Q5SSQ6', [4, 'Q5SSQ6', 'SAPCD1', 'suppressor APC domain containing 1']], ['Q07817', [4, 'Q07817', 'BCL2L1', 'BCL2 like 1']], ['Q7Z6I8', [4, 'Q7Z6I8', 'C5orf24', 'chromosome 5 open reading frame 24']], ['Q8IUC0', [4, 'Q8IUC0', 'KRTAP13-1', 'keratin associated protein 13-1']], ['Q14CX7', [3, 'Q14CX7', 'NAA25', 'N-alpha-acetyltransferase 25, NatB auxiliary subunit']], ['P62837', [3, 'P62837', 'UBE2D2', 'ubiquitin conjugating enzyme E2 D2']], ['Q9UK53', [3, 'Q9UK53', 'ING1', 'inhibitor of growth family member 1']], ['Q9BXC1', [3, 'Q9BXC1', 'GPR174', 'G protein-coupled receptor 174']], ['P05106', [3, 'P05106', 'ITGB3', 'integrin subunit beta 3']], ['Q92 ...
