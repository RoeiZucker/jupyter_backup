# %%
# !ls
# Out:
#  41588_2016_BFng3654_MOESM74_ESM.csv
#  Diastolic_blood_pressure.csv
#  Diastolic_blood_pressure_F.csv
#  Diastolic_blood_pressure_M.csv
#  E03_M_10
#  E03_M_11
#  E03_M_12
#  E03_M_13
#  E03_M_14
#  E03_M_15
#  E03_M_16
#  E03_M_17
#  E03_M_18
#  E03_M_19
#  E03_M_2
#  E03_M_20
#  E03_M_21
#  E03_M_22
#  E03_M_23
#  E03_M_24
#  E03_M_25
#  E03_M_26
#  E03_M_27
#  E03_M_28
#  E03_M_29
#  E03_M_3
#  E03_M_30
#  E03_M_31
#  E03_M_32
#  E03_M_33
#  E03_M_34
#  E03_M_35
#  E03_M_36
#  E03_M_37
#  E03_M_38
#  E03_M_39
#  E03_M_4
#  E03_M_40
#  E03_M_41
#  E03_M_42
#  E03_M_43
#  E03_M_44
#  E03_M_45
#  E03_M_46
#  E03_M_47
#  E03_M_48
#  E03_M_49
#  E03_M_5
#  E03_M_50
#  E03_M_51
#  E03_M_52
#  E03_M_53
#  E03_M_54
#  E03_M_55
#  E03_M_56
#  E03_M_57
#  E03_M_58
#  E03_M_59
#  E03_M_6
#  E03_M_60
#  E03_M_61
#  E03_M_62
#  E03_M_63
#  E03_M_64
#  E03_M_65
#  E03_M_66
#  E03_M_67
#  E03_M_68
#  E03_M_69
#  E03_M_7
#  E03_M_70
#  E03_M_71
#  E03_M_72
#  E03_M_73
#  E03_M_74
#  E03_M_75
#  E03_M_76
#  E03_M_77
#  E03_M_78
#  E03_M_79
#  E03_M_8
#  E03_M_80
#  E03_M_81
#  E03_M_82
#  E03_M_83
#  E03_M_84
#  E03_M_85
#  E03_M_86
#  E03_M_87
#  E03_M_88
#  E03_M_89
#  E03_M_9
#  E03_M_90
#  E03_M_91
#  E03_M_92
#  E03_M_93
#  E03_M_94
#  E03_M_95
#  E03_M_96
#  E03_M_97
#  E03_M_98
#  E03_M_99
#  finngen_R5_I9_HYPTENS_lead.tsv
#  finngen_R6_I9_HYPTENS_autorep.tsv
#  finngen_R7_I9_HYPTENS_autorep.tsv
# 'hypertnsion validation.ipynb'
#  I10_1.csv
#  I10_F_1.csv
#  I10_M_1.csv
#  NIHMS80726-supplement-Supplementary_tables_1-25.csv
#  non_caucasian_validation.ipynb
#  Systolic_blood_pressure.csv
#  Systolic_blood_pressure_F.csv
#  Systolic_blood_pressure_M.csv
#  Untitled.ipynb

# %%
import pandas as pd
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles, venn3_unweighted
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
finn = pd.read_csv("./finngen_R5_I9_HYPTENS_lead.tsv", sep='\t')
finn = pd.read_csv("./finngen_R7_I9_HYPTENS_autorep.tsv", sep='\t')

I10_reg = pd.read_csv("./I10_1.csv")
I10_M = pd.read_csv("I10_M_1.csv")
I10_F = pd.read_csv("I10_F_1.csv")

a = pd.read_csv("./NIHMS80726-supplement-Supplementary_tables_1-25.csv")
b= pd.read_csv("./41588_2016_BFng3654_MOESM74_ESM.csv")


# b["Genes at locus (r2>0.4 of lead SNV)"]
Diastolic_blood_pressure = pd.read_csv("Diastolic_blood_pressure.csv")
Diastolic_blood_pressure_M = pd.read_csv("Diastolic_blood_pressure_M.csv")
Diastolic_blood_pressure_F = pd.read_csv("Diastolic_blood_pressure_F.csv")

Systolic_blood_pressure = pd.read_csv("Systolic_blood_pressure.csv")
Systolic_blood_pressure_M = pd.read_csv("Systolic_blood_pressure_M.csv")
Systolic_blood_pressure_F = pd.read_csv("Systolic_blood_pressure_F.csv")

# %% [markdown]
# # validation from other studies

# %%
set(a["Gene / Locus"])
# Out:
# {'2q36.3',
#  '7p15.2',
#  '7q32.1',
#  'ABHD17C',
#  'ABLIM3,SH3TC2',
#  'ABO',
#  'AC016735.1',
#  'ACE',
#  'ACOX1',
#  'ADAMTS7',
#  'ADAMTS7[105439]-MORF4L1[33098]',
#  'ADAMTS8',
#  'ADAMTS9',
#  'ADCY3',
#  'ADM',
#  'ADO',
#  'ADRB1',
#  'AFAP1',
#  'AGT',
#  'AKT2',
#  'AMH',
#  'ARHGAP12',
#  'ARHGAP24',
#  'ARNTL',
#  'ARVCF',
#  'ATP2B1',
#  'BAT2-BAT5',
#  'BDNF',
#  'BLK-GATA4',
#  'C10orf107',
#  'C17orf82,TBX2',
#  'C2CD4B[352803]-MGC15885[128841]',
#  'C2orf43',
#  'C3orf38[539149]-EPHA3[711454]',
#  'C5orf56',
#  'CACNA1D',
#  'CACNA2D2',
#  'CACNB2',
#  'CAMKV-ACTBP13',
#  'CASC15',
#  'CASZ1',
#  'CCDC141',
#  'CCDC41',
#  'CCNE1',
#  'CD34',
#  'CDC25A',
#  'CDC42BPA',
#  'CDH13',
#  'CDH17',
#  'CDK6',
#  'CELA2A',
#  'CEP164',
#  'CEP68',
#  'CERS5',
#  'CFDP1',
#  'CHIC2',
#  'CHST12-LFNG',
#  'CMIP',
#  'COL21A1',
#  'CPEB4',
#  'CPLX3[6695]-ULK3[9907]',
#  'CR1L[101291]-CD46[49113]',
#  'CRACR2B',
#  'CREB5',
#  'CRIP3',
#  'CRK',
#  'CRYAA-SIK1',
#  'CSNK1G3',
#  'CTNNA3',
#  'CXCL12[400570]-TMEM72[157563]',
#  'CYP11B2[68981]-LOC100133669[38852]',
#  'CYP17A1',
#  'CYP17A1-NT5C2',
#  'CYP1A1-ULK3',
#  'CYP2C19',
#  'CYP46A1[74390]-EML1[183251]',
#  'DBH',
#  'DNM3',
#  'DOT1L',
#  'DPEP1',
#  'EBF1',
#  'EBF2',
#  'EHBP1L1',
#  'ELAVL3',
#  'ENPEP',
#  'ESR1',
#  'EVX1-HOXA',
#  'EVX1[54883]-HIBADH[365574]',
#  'EXOC6B[707909]-SPR[4937]',
#  'FAF1',
#  'FAM108C1',
#  'FAM176C',
#  'FAM186B',
#  'FAM208A',
#  'FBLN5',
#  'FBN1',
#  'FBN2',
#  'FBXL19',
#  'FER1L5',
#  'FERMT2',
#  'FGD5',
#  'FGF5',
#  'FGGY',
#  'FIGN-GRB14',
#  'FLJ32810-TMEM133',
#  'FN1',
#  'FNDC1',
#  'FOSL2',
#  'FRMD3',
#  'FURIN-FES',
#  'FUT9[421561]-UFL1[117746]',
#  'GATA2',
#  'GDF7[12397]-C2orf43[144007]',
#  'GJA1',
#  'GOSR2',
#  'GPAT2-FAHD2CP',
#  'GPATCH2',
#  'GPR20',
#  'GPR98[709523]-ARRDC3[115010]',
#  'GS-EDN3',
#  'GTF2B',
#  'GUCY1A3-GUCY1B3',
#  'GYPA[241499]-HHIP-AS1[295217]',
#  'H19',
#  'HAAO[84530]-ZFP36L2[374987]',
#  'HDAC9',
#  'HFE',
#  'HIPK2',
#  'HIVEP3',
#  'HLA-DQB1',
#  'HM13-AS1[14164]-ID1[24644]',
#  'HNF4G[139678]-ZFHX4-AS1[1003630]',
#  'HOXA3',
#  'HOXB7',
#  'HOXC4',
#  'HRCT1',
#  'HRH1-ATG7',
#  'HSD52[65734]-MIR4711[535627]',
#  'HSPB7',
#  'IGFBP1-IGFBP3',
#  'IGFBP3',
#  'INSR',
#  'In “Locus” set of columns, the “Locus/Gene” column refers to the published locus name. All positions are NCBI build 37 (hg19). In the “Known SNP” set of columns, the “PMID” column provides the reference for the corresponding publication. The “Known SNP results” columns provides results for the exact SNP; the “Rsq08-BestSNP” columns provides results for the SNP with minimum p-value across all BP traits, amongst all proxy SNPs in Linkage Disequilibrium (r2 ≥ 0.8); the “Rsq01-Locus-BestSNP” columns provides results for the SNP with minimum p-value across all BP traits amongst all SNPs within the locus ±500kb from the known SNP and in Linkage Disequilibrium (r2 ≥ 0.1). All association results are from the GWAS discovery meta-analysis. “Trait” corresponds to the BP trait with minimum p-value (“P_min”). The TRUE/FALSE columns for “GWsig”, “Bonf”, “sig01” indicate whether the corresponding SNP reaches P < 5×10-8, P < 0.05/274, or P < 0.01, respectively. If the known SNP itself is not available within the MAF≥1% HRC-imputed data, “n/a” is indicated. If subsequent columns would correspond to the same best SNP from the previous set of columns, the cells are left blank. The "Coverage" column provides extra information for the 28 SNPs which were not covered exactly within the MAF≥1% HRC-imputed data; SBP: systolic blood pressure; DBP: diastolic blood pressure; PP: pulse pressure',
#  'JAG1',
#  'JPH2',
#  'KANSL1',
#  'KCNH4-HSD17B1',
#  'KCNJ11',
#  'KCNK3',
#  'KIAA1462',
#  'LHFPL2',
#  'LLPH/TMBIM4',
#  'LMO1',
#  'LNX1-AS2[343183]-RPL21P44[51144]',
#  'LOC144486[29127]-MIR5700[72730]',
#  'LOC283335',
#  'LRP12/ZFPM2',
#  'LRRC10B',
#  'LSP1-TNNT3',
#  'MAP4',
#  'MAPK4',
#  'MAPK4[197466]-MRO[62485]',
#  'MCF2L',
#  'MCTP2[412908]-LOC400456[558258];chr15mb95',
#  'MDM4',
#  'MECOM',
#  'METTL21A-AC079767.3',
#  'MIR1263',
#  'MKLN1',
#  'MRAS',
#  'MRC2',
#  'MSH5-SAPCD1',
#  'MTAP',
#  'MTF1',
#  'MTHFR-NPPB',
#  'MYEOV',
#  'MYH6',
#  'NADK-CPSF3L',
#  'NFAT5',
#  'NFKBIA',
#  'NME7',
#  'NOS3',
#  'NOTCH3',
#  'NOV',
#  'NOX4',
#  'NPNT[95146]-TBCK[325681]',
#  'NPR1',
#  'NPR3-C5orf23',
#  'NUCB2',
#  'OBFC1',
#  'OR4A47[413412]-TRIM51GP[79491]',
#  'OR5B12',
#  'OSR1',
#  'PABPC4',
#  'PALLD',
#  'PAX2',
#  'PDE10A',
#  'PDE1A',
#  'PDE3A',
#  'PDE5A',
#  'PDP1[174382]-CDH17[116442]',
#  'PHACTR1',
#  'PHF19',
#  'PHIP',
#  'PIK3CG',
#  'PITPNM3[119246]-KIAA0753[70419]',
#  'PKHD1',
#  'PLCB1',
#  'PLCD3',
#  'PLCE1',
#  'PLEKHA7',
#  'PLEKHG1',
#  'PNPT1',
#  'POC5',
#  'POC5[68695]-SV2C[582698]',
#  'PPAP2B',
#  'PPL',
#  'PPP2R5E',
#  'PPP6C',
#  'PRDM11',
#  'PRDM16',
#  'PRDM6',
#  'PRDM8[65685]-FGF5[27830]',
#  'PREX1',
#  'PRKAG1',
#  'PRKAG2',
#  'PRKCE',
#  'PRKD3',
#  'PRKRIR[64327]-C11orf30[137259]',
#  'PROCR',
#  'PSMD5',
#  'PTPMT1',
#  'PYY',
#  'RABGAP1',
#  'RAPSN, PSMC3, SLC39A13',
#  'RBM47',
#  'RGL3',
#  'RNF207',
#  'RP11-321F6.1',
#  'RP11-439C8.2',
#  'RP11-61O1.1',
#  'RP4-710M16.1-PPAP2B',
#  'RPL6-ALDH1',
#  'RRAS',
#  'RRP1B',
#  'RSPO3',
#  'RYK',
#  'SARNP',
#  'SBNO1',
#  'SCAI',
#  'SCARNA7[137466]-ARL14[26075]',
#  'SDCCAG8',
#  'SENP2',
#  'SETBP1',
#  'SF3A3',
#  'SH2B3',
#  'SIPA1',
#  'SLC14A2',
#  'SLC20A2',
#  'SLC22A7',
#  'SLC24A3',
#  'SLC35F1',
#  'SLC39A8',
#  'SLC4A1AP',
#  'SLC4A7',
#  'SLC7A1',
#  'SLC8A1',
#  'SMOC2[745273]-THBS2[67034]',
#  'SNORD32B',
#  'SNX31',
#  'SOX6',
#  'SPSB1[89009]-SLC25A33[200882];chr1mb9',
#  'SSPN',
#  'ST7L-CAPZA1-MOV10',
#  'STAB1',
#  'STK39',
#  'SUGCT',
#  'SULT1C3',
#  'SVEP1',
#  'S_E_Pt9',
#  'TARID',
#  'TBC1D1-FLJ13197',
#  'TBX2',
#  'TBX3[1090283]-MIR620[388118]',
#  'TBX5-TBX3',
#  'TCF7L1',
#  'TCF7L2',
#  'TEX41',
#  'TFAP2D',
#  'TM6SF1',
#  'TMEM161B',
#  'TMEM194B',
#  'TMEM194B[122793]-NAB1[63081]',
#  'TNRC6A',
#  'TNRC6B',
#  'TNS1',
#  'TNXB',
#  'TP53;TP53-SLC2A4',
#  'TRAPPC9',
#  'TRIM36',
#  'TSHZ3[161697]-THEG5[156398]',
#  'TTBK1,SLC22A7,ZNF318',
#  'ULK4',
#  'UMOD',
#  'VAC14',
#  'VCL',
#  'VMP1',
#  'WNT3A',
#  'XRCC6',
#  'ZBTB38',
#  'ZC3HC1',
#  'ZFAT',
#  'ZNF101',
#  'ZNF438[278997]-ZEB1-AS1[195463]',
#  'ZNF638',
#  'ZNF652',
#  'ZNF652[73899]-PHB[51776]',
#  'ZNRF3',
#  'c10orf107',
#  'c5orf56',
#  'chr1mb25',
#  'chr4mb174',
#  nan}

# %%
print(len(set(finn["lead_most_severe_gene"]).intersection(set(I10_reg.query("fdr_significance")["symbol"]))))
# print(len(set(finn["nearest_genes"]).intersection(set(I10_reg.query("fdr_significance")["symbol"]))))
print("finngen: ", set(finn["lead_most_severe_gene"]).intersection(set(I10_reg.query("fdr_significance")["symbol"])))
# Out:
# 7
# finngen:  {'LSP1', 'HRCT1', 'DBH', 'NOS3', 'PLCE1', 'REXO1', 'SH2B3'}

# %%
print(len(set(a["Gene / Locus"]).intersection(set(I10_reg.query("fdr_significance")["symbol"]))))
print("one million", set(a["Gene / Locus"]).intersection(set(I10_reg.query("fdr_significance")["symbol"])))
# Out:
# 15
# one million {'SLC4A7', 'TNXB', 'SLC39A8', 'HRCT1', 'AGT', 'SIPA1', 'HFE', 'OR5B12', 'DBH', 'NOS3', 'RRP1B', 'PLCE1', 'CERS5', 'ZC3HC1', 'SH2B3'}

# %%
print(len(set(b["Genes at locus (r2>0.4 of lead SNV)"]).intersection(set(I10_reg.query("fdr_significance")["symbol"]))))
print("Trans-ancestry meta-analyses", set(b["Genes at locus (r2>0.4 of lead SNV)"]).intersection(set(I10_reg.query("fdr_significance")["symbol"])))
# Out:
# 4
# Trans-ancestry meta-analyses {'RRP1B', 'OR5B12', 'CERS5', 'SLC22A4'}

# %% [markdown]
# # validation using Blood pressure mesurments:

# %% [markdown]
# ### alpha of 0.05

# %%
reg_set_Diastolic = set(Diastolic_blood_pressure.query("fdr_significance")["symbol"]).intersection(set(I10_reg.query("fdr_significance")["symbol"]))
M_set_Diastolic = set(Diastolic_blood_pressure_M.query("fdr_significance")["symbol"]).intersection(set(I10_M.query("fdr_significance")["symbol"]))
F_set_Diastolic = set(Diastolic_blood_pressure_F.query("fdr_significance")["symbol"]).intersection(set(I10_F.query("fdr_significance")["symbol"]))
# print(len(the_set))
print(f"Diastolic_blood_pressure all sexs: ({len(reg_set_Diastolic)}), {reg_set_Diastolic}")
print(f"Diastolic_blood_pressure (M): ({len(M_set_Diastolic)}), {M_set_Diastolic}")
print(f"Diastolic_blood_pressure (F): ({len(F_set_Diastolic)}), {F_set_Diastolic}")

reg_set_Systolic = set(Systolic_blood_pressure.query("fdr_significance")["symbol"]).intersection(set(I10_reg.query("fdr_significance")["symbol"]))
M_set_Systolic = set(Systolic_blood_pressure_M.query("fdr_significance")["symbol"]).intersection(set(I10_M.query("fdr_significance")["symbol"]))
F_set_Systolic = set(Systolic_blood_pressure_F.query("fdr_significance")["symbol"]).intersection(set(I10_F.query("fdr_significance")["symbol"]))
# print(len(the_set))
print(f"Systolic_blood_pressure all sexs: ({len(reg_set_Systolic)}), {reg_set_Systolic}")
print(f"Systolic_blood_pressure (M): ({len(M_set_Systolic)}), {M_set_Systolic}")
print(f"Systolic_blood_pressure (F): ({len(F_set_Systolic)}), {F_set_Systolic}")
# Out:
# Diastolic_blood_pressure all sexs: (30), {'TNXB', 'AGT', 'SIPA1', 'OR4X2', 'SH2B3', 'SLC39A8', 'HFE', 'ZNF100', 'PLCE1', 'CERS5', 'SLC44A4', 'GIP', 'LINC02875', 'FUT2', 'FNBP4', 'DBH', 'NUP160', 'ST7L', 'SWAP70', 'PHETA1', 'AP5B1', 'RASIP1', 'BAG6', 'PTPRJ', 'CPA4', 'CYP11B2', 'SLC16A1', 'USP36', 'SPINK8', 'ARHGEF3'}
# Diastolic_blood_pressure (M): (1), {'SH2B3'}
# Diastolic_blood_pressure (F): (8), {'SWAP70', 'AGT', 'FUT2', 'SIPA1', 'HFE', 'SHISA4', 'CERS5', 'SH2B3'}
# Systolic_blood_pressure all sexs: (36), {'LSP1', 'TNXB', 'RAPSN', 'CENPW', 'AGT', 'SIPA1', 'OR4X2', 'SH2B3', 'SLC39A8', 'TBCK', 'HFE', 'PLCE1', 'CERS5', 'FGF21', 'REXO1', 'OR4B1', 'SLC44A4', 'LINC02875', 'OR5B12', 'FUT2', 'FNBP4', 'DBH', 'NUP160', 'SWAP70', 'PHETA1', 'RASIP1', 'BAG6', 'PTPRJ', 'ARHGEF3', 'CYP11B2', 'WNT9B', 'SLC16A1', 'USP36', 'SPINK8', 'INPP5A', 'IMMT'}
# Systolic_blood_pressure (M): (0), set()
# Systolic_blood_pressure (F): (13), {'SWAP70', 'LSP1', 'RASIP1', 'AGT', 'SIPA1', 'FUT2', 'HFE', 'CERS5', 'CYP11B2', 'REXO1', 'OR4X2', 'SH2B3', 'INPP5A'}

# %%
sys_dis = set(Diastolic_blood_pressure.query("fdr_significance")["symbol"]).intersection(set(Systolic_blood_pressure.query("fdr_significance")["symbol"]))
len(Systolic_blood_pressure.query("fdr_significance")["symbol"])
# Out:
# 220

# %%
Diastolic_blood_pressure[Diastolic_blood_pressure["symbol"].isin(I10_reg.query("fdr_significance")["symbol"])].head(40)
# Out:
#      gene_index uniprot_id     symbol  \
# 0         17503     Q9UQQ2      SH2B3
# 2          7680     Q30201        HFE
# 4         14902     Q9C0K1    SLC39A8
# 5         11009     Q8N4B1     PHETA1
# 6         11064     Q8N5B7      CERS5
# 10         3009     P09172        DBH
# 16         4833     P46379       BAG6
# 18         3094     P0C7L1     SPINK8
# 26        16635     Q9P212      PLCE1
# 27         3743     P19099    CYP11B2
# 33         3915     P22105       TNXB
# 35         5342     P53985    SLC16A1
# 37        16916     Q9UH65     SWAP70
# 50        16656     Q9P275      USP36
# 51         7960     Q53GD3    SLC44A4
# 62         6484     Q10981       FUT2
# 63         6493     Q12769     NUP160
# 68        10979     Q8N3X1      FNBP4
# 71        13225     Q96FS4      SIPA1
# 77         2508     P01019        AGT
# 83        10689     Q8IYN0     ZNF100
# 95        11716     Q8NGF9      OR4X2
# 107        6547     Q12913      PTPRJ
# 132        7666     Q2VPB7      AP5B1
# 140        3045     P09681        GIP
# 146       15966     Q9NR81    ARHGEF3
# 155       12163     Q8TDW4       ST7L
# 177       17002     Q9UI42       CPA4
# 197        8513     Q5U651     RASIP1
# 198       10281     Q86X59  LINC02875
# 210       10235     Q86WB0     ZC3HC1
# 237       10874     Q8N1G1      REXO1
# 238       14979     Q9H015    SLC22A4
# 252        7026     Q14642     INPP5A
# 270        5630     P59942      MCCD1
# 283        4232     P29474       NOS3
# 317        7541     Q16891       IMMT
# 371       12196     Q8TEA7       TBCK
# 389        4405     P33241       LSP1
# 556       18087     Q9Y6M7     SLC4A7
#
#                                                   name        refseq_ids chr  \
# 0                               SH2B adaptor protein 3     ['NM_005475']  12
# 2                           homeostatic iron regulator     ['NM_000410']   6
# 4                    solute carrier family 39 member 8     ['NM_022154']   4
# 5    PH domain containing endocytic trafficking ada...     ['NM_144671']  12
# 6                                  ceramide synthase 5     ['NM_147190']  12
# 10                           dopamine beta-hydroxylase     ['NM_000787']   9
# 16                                   BAG cochaperone 6     ['NM_080703']   6
# 18   serine peptidase inhibitor Kazal type 8 (putat...  ['NM_001080525']   3
# 26                           phospholipase C epsilon 1     ['NM_016341']  10
# 27      cytochrome P450 family 11 subfamily B member 2     ['NM_000498']   8
# 33                                         tenascin XB     ['NM_019105']   6
# 35                   solute carrier family 16 member 1     ['NM_003051']   1
# 37             switching B cell complex subunit SWAP70     ['NM_015055']  11
# 50                     ubiquitin specific peptidase 36     ['NM_025090']  17
# 51                   solute carrier family 44 member 4  ['NM_001178044']   6
# 62                                fucosyltransferase 2     ['NM_000511']  19
# 63                                     nucleoporin 160     ['NM_015231']  11
# 68                            formin binding protein 4  ['NM_001318339']  11
# 71           signal-induced proliferation-associated 1     ['NM_006747']  11
# 77                                     angiotensinogen     ['NM_000029']   1
# 83                             zinc finger protein 100     ['NM_173531']  19
# 95    olfactory receptor family 4 subfamily X member 2  ['NM_001004727']  11
# 107       protein tyrosine phosphatase receptor type J  ['NM_001098503']  11
# 132   adaptor related protein complex 5 subunit beta 1     ['NM_138368']  11
# 140                     gastric inhibitory polypeptide     ['NM_004123']  17
# 146           Rho guanine nucleotide exchange factor 3     ['NM_019555']   3
# 155               suppression of tumorigenicity 7 like  ['NM_001308264']   1
# 177                                carboxypeptidase A4     ['NM_016352']   7
# 197                          Ras interacting protein 1     ['NM_017805']  19
# 198        long intergenic non-protein coding RNA 2875     ['NR_160788']  17
# 210                 zinc finger C3HC-type containing 1     ['NM_016478']   7
# 237                          RNA exonuclease 1 homolog     ['NM_020695']  19
# 238                  solute carrier family 22 member 4     ['NM_003059']   5
# 252             inositol polyphosphate-5-phosphatase A     ['NM_005539']  10
# 270                 mitochondrial coiled-coil domain 1  ['NM_001011700']   6
# 283                            nitric oxide synthase 3     ['NM_000603']   7
# 317               inner membrane mitochondrial protein     ['NM_006839']   2
# 371                      TBC1 domain containing kinase     ['NM_033115']   4
# 389                      lymphocyte specific protein 1     ['NM_002339']  11
# 556                   solute carrier family 4 member 7     ['NM_003615']   3
#
#      cds_start    cds_end  dominant_std_score  dominant_r  dominant_pval  \
# 0    111855950  111886103            0.403549    0.023121   1.816953e-40
# 2     26087669   26094451            0.450621   -0.015388   8.813270e-19
# 4    103184204  103265819            0.236414    0.013352   1.669664e-17
# 5    111800485  111801231            0.473939    0.015154   6.752586e-17
# 6     50524331   50561080            0.304460    0.011262   1.317460e-10
# 10   136501494  136523566            0.301040    0.013537   1.938175e-13
# 16    31606911   31619540            0.088173   -0.011004   2.083531e-09
# 18    48348485   48369831            0.392611    0.010061   8.098230e-08
# 26    95790804   96084834            0.142327    0.010161   2.281849e-08
# 27   143993399  143999256            0.226884    0.008314   2.280777e-06
# 33    32009129   32065975            0.109002   -0.009272   8.910675e-09
# 35   113456516  113471930            0.054085   -0.007753   2.444610e-05
# 37     9685727    9771514            0.091528   -0.007636   7.492896e-06
# 50    76794505   76832445            0.377645    0.007137   1.028168e-04
# 51    31831407   31846757            0.323700   -0.008592   3.078360e-06
# 62    49206214   49207242            0.398676   -0.002263   2.050262e-01
# 63    47800660   47869972            0.182956   -0.006692   6.150474e-05
# 68    47738977   47788840            0.440332   -0.006254   7.535248e-05
# 71    65408393   65418183            0.070964    0.008506   1.269107e-06
# 77   230838890  230846596            0.385312   -0.007289   6.353365e-05
# 83    21909488   21950231            0.215448   -0.006017   6.679134e-04
# 95    48266656   48267564            0.443830    0.008175   6.219004e-06
# 107   48002465   48188911            0.201896   -0.006296   3.334089e-04
# 132   65545330   65548062            0.278965    0.007202   2.488551e-05
# 140   47036072   47044594            0.116092   -0.006334   2.507040e-04
# 146   56763301   56835826            0.202985    0.006526   2.441544e-04
# 155  113068638  113161735            0.321528    0.006856   2.486506e-04
# 177  129933021  129962513            0.461356    0.006211   8.064078e-04
# 197   49224058   49243539            0.293698   -0.002381   2.200956e-01
# 198   59489337   59490089            0.104901   -0.002490   8.641559e-02
# 210  129658507  129691206            0.224031    0.002480   1.755679e-01
# 237    1816068    1848357            0.337356    0.006596   2.336475e-04
# 238  131630310  131679525            0.306147    0.004377   6.071989e-03
# 252  134351601  134595442            0.257723   -0.005665   4.567802e-04
# 270   31496792   31497709            0.103408   -0.006414   3.263624e-04
# 283  150690892  150711254            0.140147    0.005406   2.750408e-03
# 317   86371394   86422505            0.057253    0.005806   5.366444e-04
# 371  106967730  107230117            0.362510   -0.003618   1.265301e-02
# 389    1874375    1908790            0.062495   -0.004077   2.572317e-02
# 556   27418258   27498174            0.124153   -0.005058   1.820190e-03
#
#      recessive_avg_score  recessive_std_score  recessive_r  recessive_pval  \
# 0               0.747980             0.416041     0.019985    4.633502e-29
# 2               0.975841             0.144684    -0.008246    5.194075e-06
# 4               0.997263             0.038375     0.006366    8.182936e-05
# 5               0.960989             0.191523     0.008495    4.908741e-06
# 6               0.675223             0.403443     0.011535    1.140716e-11
# 10              0.994065             0.059995     0.005545    1.590147e-03
# 16              0.973959             0.048837    -0.008549    1.142921e-06
# 18              0.930805             0.209361     0.009510    6.249494e-08
# 26              1.007787             0.033824     0.000796    5.904404e-01
# 27              0.928696             0.173356     0.007092    1.423306e-04
# 33              1.006235             0.033211     0.001778    1.828813e-01
# 35              0.977805             0.032933    -0.009323    8.688556e-07
# 37              0.926836             0.086772    -0.008323    2.113320e-06
# 50              0.735350             0.430067     0.008770    1.254258e-06
# 51              0.833516             0.281222    -0.007462    5.071385e-05
# 62              0.391732             0.367694    -0.006193    5.212373e-04
# 63              0.956429             0.096459    -0.006930    1.109495e-04
# 68              0.801435             0.390078    -0.007428    1.960602e-05
# 71              0.998637             0.011352     0.003561    4.050675e-02
# 77              0.893402             0.250133    -0.006963    1.837027e-04
# 83              0.846853             0.216224    -0.007211    2.655068e-05
# 95              0.976902             0.147970     0.003286    7.211240e-02
# 107             0.925398             0.116022    -0.003745    4.524845e-02
# 132             0.983995             0.079117     0.002511    1.206494e-01
# 140             0.950336             0.079733    -0.005936    1.570077e-03
# 146             0.969947             0.087810     0.004710    2.629434e-03
# 155             0.970374             0.118335     0.004349    7.812849e-03
# 177             0.852859             0.349877     0.005277    2.227127e-03
# 197             0.824631             0.277970    -0.006869    1.054036e-04
# 198             0.764912             0.201335    -0.005404    1.385183e-03
# 210             0.867163             0.199837     0.006580    1.379433e-04
# 237             0.947460             0.156683     0.000784    7.468619e-01
# 238             0.678227             0.395916     0.005378    1.195030e-03
# 252             0.980272             0.087043    -0.002843    5.250459e-02
# 270             0.966913             0.049155     0.002998    1.134123e-01
# 283             0.877352             0.144130     0.004465    8.663831e-03
# 317             0.993887             0.017557     0.001244    3.950463e-01
# 371             0.776928             0.235419    -0.005263    8.884952e-04
# 389             0.993206             0.018980    -0.004790    1.211494e-02
# 556             0.993523             0.030201    -0.000941    7.871479e-01
#
#      combined_pval  fdr_significance      fdr_qval
# 0     2.017051e-50              True  3.607295e-46
# 2     1.243907e-19              True  7.415342e-16
# 4     5.352189e-18              True  1.914371e-14
# 5     4.333019e-17              True  1.291529e-13
# 6     4.229515e-15              True  1.080581e-11
# 10    1.680174e-13              True  2.717272e-10
# 16    1.092436e-10              True  1.149243e-07
# 18    2.417323e-10              True  2.275337e-07
# 26    1.740329e-08              True  1.152743e-05
# 27    1.827180e-08              True  1.167046e-05
# 33    6.493301e-08              True  3.413676e-05
# 35    7.384714e-08              True  3.668562e-05
# 37    9.730842e-08              True  4.401719e-05
# 50    4.305629e-07              True  1.509841e-04
# 51    4.604161e-07              True  1.583477e-04
# 62    1.364003e-06              True  3.872036e-04
# 63    1.768994e-06              True  4.943234e-04
# 68    2.948892e-06              True  7.643187e-04
# 71    3.499306e-06              True  8.691887e-04
# 77    1.140787e-05              True  2.615620e-03
# 83    1.335393e-05              True  2.843115e-03
# 95    2.938792e-05              True  5.469408e-03
# 107   6.246128e-05              True  1.034312e-02
# 132   1.047892e-04              True  1.409060e-02
# 140   1.428932e-04              True  1.812413e-02
# 146   1.665094e-04              True  2.025751e-02
# 155   2.072970e-04              True  2.376474e-02
# 177   3.636545e-04              True  3.623569e-02
# 197   5.424886e-04              True  4.883661e-02
# 198   5.434179e-04              True  4.883661e-02
# 210   6.808468e-04             False  5.770741e-02
# 237   1.078820e-03             False  8.106563e-02
# 238   1.092990e-03             False  8.178674e-02
# 252   1.300265e-03             False  9.191280e-02
# 270   1.569847e-03             False  1.033648e-01
# 283   1.843167e-03             False  1.158969e-01
# 317   2.498283e-03             False  1.405009e-01
# 371   3.623448e-03             False  1.737492e-01
# 389   3.887607e-03             False  1.780801e-01
# 556   7.723684e-03             False  2.475857e-01

# %% [markdown]
# ### alpha of 0.1

# %%
reg_set_Diastolic = set(Diastolic_blood_pressure.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_reg.query("fdr_qval < 0.1")["symbol"]))
M_set_Diastolic = set(Diastolic_blood_pressure_M.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_M.query("fdr_qval < 0.1")["symbol"]))
F_set_Diastolic = set(Diastolic_blood_pressure_F.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_F.query("fdr_qval < 0.1")["symbol"]))
# print(len(the_set))
print(f"Diastolic_blood_pressure all sexs: ({len(reg_set_Diastolic)}), {reg_set_Diastolic}")
print(f"Diastolic_blood_pressure (M): ({len(M_set_Diastolic)}), {M_set_Diastolic}")
print(f"Diastolic_blood_pressure (F): ({len(F_set_Diastolic)}), {F_set_Diastolic}")

reg_set_Systolic = set(Systolic_blood_pressure.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_reg.query("fdr_qval < 0.1")["symbol"]))
M_set_Systolic = set(Systolic_blood_pressure_M.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_M.query("fdr_qval < 0.1")["symbol"]))
F_set_Systolic = set(Systolic_blood_pressure_F.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_F.query("fdr_qval < 0.1")["symbol"]))
# print(len(the_set))
print(f"Systolic_blood_pressure all sexs: ({len(reg_set_Systolic)}), {reg_set_Systolic}")
print(f"Systolic_blood_pressure (M): ({len(M_set_Systolic)}), {M_set_Systolic}")
print(f"Systolic_blood_pressure (F): ({len(F_set_Systolic)}), {F_set_Systolic}")
# Out:
# Diastolic_blood_pressure all sexs: (46), {'TNXB', 'LMAN1L', 'REPIN1', 'AGT', 'SIPA1', 'SMC6', 'SH2B3', 'OR4X2', 'SDCCAG8', 'SLC39A8', 'USP36', 'ZNF100', 'PLCE1', 'ATXN2', 'CERS5', 'ZC3HC1', 'REXO1', 'ULK3', 'SLC44A4', 'GIP', 'LINC02875', 'FUT2', 'FNBP4', 'TMEM116', 'NACA', 'SLC22A4', 'DBH', 'NUP160', 'ST7L', 'SWAP70', 'COL21A1', 'PHETA1', 'AP5B1', 'RASIP1', 'XRCC3', 'BAG6', 'PTPRJ', 'SHISA4', 'CPA4', 'CYP11B2', 'TNRC6A', 'SLC16A1', 'HFE', 'SPINK8', 'INPP5A', 'ARHGEF3'}
# Diastolic_blood_pressure (M): (2), {'SH2B3', 'DBH'}
# Diastolic_blood_pressure (F): (9), {'SWAP70', 'AGT', 'FUT2', 'SIPA1', 'HFE', 'SHISA4', 'SLC22A4', 'CERS5', 'SH2B3'}
# Systolic_blood_pressure all sexs: (62), {'LSP1', 'TNXB', 'CENPW', 'LMAN1L', 'AKAP13', 'RAPSN', 'REPIN1', 'AGT', 'SIPA1', 'ZNF408', 'SH2B3', 'OR4X2', 'PSORS1C2', 'OSER1', 'SLC39A8', 'USP36', 'TBCK', 'ZNF100', 'TRIM49B', 'UPF3A', 'WNT9B', 'PLCE1', 'ATXN2', 'CERS5', 'FGF21', 'SLC16A1', 'REXO1', 'ULK3', 'CLCN2', 'OR4B1', 'SLC44A4', 'GIP', 'LINC02875', 'OR5B12', 'FUT2', 'FNBP4', 'TMEM116', 'TRAF3IP3', 'NOS3', 'OR5M11', 'DBH', 'IMMT', 'IZUMO1', 'NUP160', 'SWAP70', 'COL21A1', 'PHETA1', 'AP5B1', 'RASIP1', 'MCL1', 'BAG6', 'PTPRJ', 'RRAS', 'F2', 'CYP11B2', 'EHMT2', 'TNRC6A', 'CLDN7', 'HFE', 'SPINK8', 'INPP5A', 'ARHGEF3'}
# Systolic_blood_pressure (M): (1), {'SH2B3'}
# Systolic_blood_pressure (F): (13), {'SWAP70', 'LSP1', 'RASIP1', 'AGT', 'SIPA1', 'FUT2', 'HFE', 'CERS5', 'CYP11B2', 'REXO1', 'OR4X2', 'SH2B3', 'INPP5A'}

# %%
reg_set_Diastolic = set(Diastolic_blood_pressure.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_reg.query("fdr_significance")["symbol"]))
M_set_Diastolic = set(Diastolic_blood_pressure_M.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_M.query("fdr_significance")["symbol"]))
F_set_Diastolic = set(Diastolic_blood_pressure_F.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_F.query("fdr_significance")["symbol"]))
# print(len(the_set))
print(f"Diastolic_blood_pressure all sexs: ({len(reg_set_Diastolic)}), {reg_set_Diastolic}")
print(f"Diastolic_blood_pressure (M): ({len(M_set_Diastolic)}), {M_set_Diastolic}")
print(f"Diastolic_blood_pressure (F): ({len(F_set_Diastolic)}), {F_set_Diastolic}")

reg_set_Systolic = set(Systolic_blood_pressure.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_reg.query("fdr_significance")["symbol"]))
M_set_Systolic = set(Systolic_blood_pressure_M.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_M.query("fdr_significance")["symbol"]))
F_set_Systolic = set(Systolic_blood_pressure_F.query("fdr_qval < 0.1")["symbol"]).intersection(set(I10_F.query("fdr_significance")["symbol"]))
# print(len(the_set))
print(f"Systolic_blood_pressure all sexs: ({len(reg_set_Systolic)}), {reg_set_Systolic}")
print(f"Systolic_blood_pressure (M): ({len(M_set_Systolic)}), {M_set_Systolic}")
print(f"Systolic_blood_pressure (F): ({len(F_set_Systolic)}), {F_set_Systolic}")
# Out:
# Diastolic_blood_pressure all sexs: (34), {'TNXB', 'AGT', 'SIPA1', 'OR4X2', 'SH2B3', 'SLC39A8', 'HFE', 'ZNF100', 'PLCE1', 'CERS5', 'ZC3HC1', 'REXO1', 'SLC44A4', 'GIP', 'LINC02875', 'FUT2', 'FNBP4', 'DBH', 'SLC22A4', 'ST7L', 'NUP160', 'SWAP70', 'PHETA1', 'AP5B1', 'RASIP1', 'BAG6', 'PTPRJ', 'CPA4', 'CYP11B2', 'SLC16A1', 'USP36', 'SPINK8', 'INPP5A', 'ARHGEF3'}
# Diastolic_blood_pressure (M): (1), {'SH2B3'}
# Diastolic_blood_pressure (F): (9), {'SWAP70', 'AGT', 'FUT2', 'SIPA1', 'HFE', 'SHISA4', 'SLC22A4', 'CERS5', 'SH2B3'}
# Systolic_blood_pressure all sexs: (43), {'LSP1', 'TNXB', 'RAPSN', 'CENPW', 'AGT', 'SIPA1', 'ZNF408', 'OR4X2', 'SH2B3', 'SLC39A8', 'TBCK', 'HFE', 'ZNF100', 'PLCE1', 'CERS5', 'FGF21', 'CLCN2', 'REXO1', 'OR4B1', 'SLC44A4', 'GIP', 'LINC02875', 'OR5B12', 'FUT2', 'FNBP4', 'DBH', 'NOS3', 'OR5M11', 'NUP160', 'SWAP70', 'PHETA1', 'AP5B1', 'RASIP1', 'BAG6', 'PTPRJ', 'ARHGEF3', 'CYP11B2', 'WNT9B', 'SLC16A1', 'USP36', 'SPINK8', 'INPP5A', 'IMMT'}
# Systolic_blood_pressure (M): (1), {'SH2B3'}
# Systolic_blood_pressure (F): (13), {'SWAP70', 'LSP1', 'RASIP1', 'AGT', 'SIPA1', 'FUT2', 'HFE', 'CERS5', 'CYP11B2', 'REXO1', 'OR4X2', 'SH2B3', 'INPP5A'}

# %%
# def create_intersection_groups_for_venn(reg_sig_genes,female_sig_genes,male_sig_genes):
#     combined_only = reg_sig_genes.difference(female_sig_genes).difference(male_sig_genes)
#     female_only = female_sig_genes.difference(reg_sig_genes).difference(male_sig_genes)
#     male_only = female_sig_genes.difference(reg_sig_genes).difference(female_sig_genes)
#     female_combined = female_sig_genes.intersection(reg_sig_genes).difference(male_sig_genes)
#     male_combined = male_sig_genes.intersection(reg_sig_genes).difference(female_sig_genes)
#     male_female = male_sig_genes.intersection(female_sig_genes).difference(reg_sig_genes)
#     male_female_combined = male_sig_genes.intersection(female_sig_genes).intersection(reg_sig_genes)
#     lables = ["combined only", "female only", "male only", "female-combined",
#               "male-combined","male-female","male-female-combined"]
#     values = [len(combined_only), len(female_only),len(female_combined),len(male_only),
#              len(male_combined),len(male_female),len(male_female_combined)]
#     return  values

def blood_pressure_diagram(both_BP, male_BP, female_BP):
    both  = set(both_BP.query("fdr_qval < 0.05")["symbol"])
    male = set(male_BP.query("fdr_qval < 0.05")["symbol"])
    female = set(female_BP.query("fdr_qval < 0.05")["symbol"])
    combined_only = (both - male) - female
    male_only = (male-both) - female
    female_only = (female-both) - male
    male_female = male.intersection(female) - both
    male_combined = male.intersection(both) - female
    female_combined = female.intersection(both) - male
    male_female_combined = both.intersection( male.intersection(female))
    # len(female_only)
    values = [len(combined_only), len(female_only),len(female_combined),len(male_only),
             len(male_combined),len(male_female),len(male_female_combined)]

    out = venn3_unweighted(subsets = values, set_labels = ('Combined', 'Female', 'Male'), alpha = 0.5);
    for text in out.subset_labels:
        text.set_fontsize(12)
    for text in out.set_labels:
        text.set_fontsize(12)
    #     venn3(subsets = (1,2,3,4,5,6,7), set_labels = ('Group A', 'Group B', 'Group C'), alpha = 0.5);

    #     plt.pie(values,labels=labels,autopct=lambda pct: pie_formater(pct, values))
    #     print(values)
    #     plt.title("GWAS gene distribution of relevant genes by sex, alpha=" + str(alpha))
    plt.title(f"Unique PWAS systolic\ngenes intersection",rotation='vertical',x=-0.1,y=0.2,fontsize=14)
    plt.show()

# %%
blood_pressure_diagram(Systolic_blood_pressure, Systolic_blood_pressure_M, Systolic_blood_pressure_F)
