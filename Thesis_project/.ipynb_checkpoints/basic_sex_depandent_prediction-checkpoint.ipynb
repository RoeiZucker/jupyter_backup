# %%
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import math

# %%
DISCRIPTION_FILE_PATH = "/cs/labs/michall/roeizucker/phewas_run/discription10.csv"

# %%
discription_df = pd.read_csv(DISCRIPTION_FILE_PATH)

# %%
# discription_df.sort_values(by=["icd_codes","name"])[discription_df.sort_values(by=["name"])["name"].str.contains( "D649")]
# names = set(filter(lambda x: x[-2:]!="_M" and x[-2:] != "_F"  ,discription_df["name"].unique()))
# for name in names:
#     print(len(discription_df.sort_values(by=["icd_codes","name"])[discription_df.sort_values(by=["name"])["name"].str.contains( name)]))

baddies = {"Phecode_681.5","Phecode_981.0","Phecode_681.3","Z864","Z867","Z87"}

# %%
sorted_df = discription_df.sort_values(by=["icd_codes","name"])

# %%
sorted_df[sorted_df["name"].str.contains("Phecode_913.0")]
# Out:
#       Unnamed: 0             name  num_of_cases  num_of_controls  \
# 4727        4502    Phecode_913.0           109           274715
# 4731        4506  Phecode_913.0_F            46           149137
# 4726        4501  Phecode_913.0_M            63           125578
#
#       num_relevant_genes  num_relevant_genes_0.1 result_file_path sex  \
# 4727                  -1                      -1              NaN   B
# 4731                  -1                      -1              NaN   F
# 4726                  -1                      -1              NaN   M
#
#                                             description  \
# 4727   Superficial injury without mention of infection
# 4731  Superficial injury without mention of infectio...
# 4726  Superficial injury without mention of infectio...
#
#                                               icd_codes data_type  source  \
# 4727  ['T631'; 'T638'; 'T632'; 'T636'; 'T634'; 'T633...    Binary  10krun
# 4731  ['T631'; 'T638'; 'T632'; 'T636'; 'T634'; 'T633...    Binary  10krun
# 4726  ['T631'; 'T638'; 'T632'; 'T636'; 'T634'; 'T633...    Binary  10krun
#
#                                            dataset_path  dataset_column  \
# 4727  /cs/labs/michall/roeizucker/phewas_run/runs1/4...               3
# 4731  /cs/labs/michall/roeizucker/phewas_run/runs1/4...               4
# 4726  /cs/labs/michall/roeizucker/phewas_run/runs1/4...               5
#
#       overall_number  prevalence  MF_prevalence_ratio  FM_prevalence_ratio  \
# 4727             NaN    0.000397             1.626188             0.614935
# 4731             NaN    0.000308             1.626188             0.614935
# 4726             NaN    0.000501             1.626188             0.614935
#
#       overall_number_of_participants
# 4727                          274824
# 4731                          149183
# 4726                          125641

# %%
discription_df[discription_df["name"].str.contains("Z87")]
# Out:
#      Unnamed: 0   name  num_of_cases  num_of_controls  num_relevant_genes  \
# 253         253  Z87_F         12919           136264                   0
# 257         257  Z87_M         12601           113040                   0
#
#      num_relevant_genes_0.1  \
# 253                       0
# 257                       0
#
#                                       result_file_path sex  \
# 253  /cs/labs/michall/roeizucker/10krun/results/Z87...   F
# 257  /cs/labs/michall/roeizucker/10krun/results/Z87...   M
#
#                                            description icd_codes data_type  \
# 253  Z87 Personal history of other diseases and con...   ['Z87']    Binary
# 257  Z87 Personal history of other diseases and con...   ['Z87']    Binary
#
#      source                                       dataset_path  \
# 253  10krun  /cs/labs/michall/roeizucker/10krun/runs/252:26...
# 257  10krun  /cs/labs/michall/roeizucker/10krun/runs/252:26...
#
#      dataset_column  overall_number  prevalence  MF_prevalence_ratio  \
# 253              13        149183.0    0.086598             1.158148
# 257              14        125641.0    0.100294             1.158148
#
#      FM_prevalence_ratio  overall_number_of_participants
# 253             0.863447                          149183
# 257             0.863447                          125641

# %%
# for trio in extra_trios:
#     if trio[0][0][-2] == "_":
#         print(trio)

# %%
# discription_df.head()
curr = 0
for row in discription_df.sort_values(by=["icd_codes","name"]).iterrows():
#     if "Phecode_681.3" in row[1]["name"]:
#         continue
    cont = False
    for bad in baddies:
        if bad in row[1]["name"]:
            cont = True
    if cont:
        continue
    if curr == 0 and row[1]["name"][-2] == "_":
#         print(row[1]["name"])
        print("***")
    if curr == 1 and row[1]["name"][-1] != "F":
        print("***")
        
#         print(row[1]["name"])
    if curr == 2 and row[1]["name"][-1] != "M":
        print("***")
        
#         print(row[1]["name"])
    curr +=1
    if curr == 3:
        curr = 0
#     print(row[1]["name"])

# %%
# Create basic table
curr_lst = []
trios = []

counter = 0
add = True
for row in discription_df.sort_values(by=["icd_codes","name"]).iterrows():
    cont = False
    for bad in baddies:
        if bad in row[1]["name"]:
            cont = True
    if cont:
        continue

    if "Phecode_681.3" in row[1]["name"]:
#         print("a")
        continue
    counter+=1
    val = row[1]["result_file_path"]
    if isinstance(val,str) and "10krun" in row[1]["result_file_path"] and "_" not in row[1]["result_file_path"]:
        row[1]["result_file_path"] = row[1]["result_file_path"].replace(".csv","_1.csv")
    curr_lst.append([row[1]["name"],row[1]["num_relevant_genes_0.1"],row[1]["result_file_path"],row[1]["num_of_cases"],row[1]["num_of_controls"]])
    if counter%3 == 0:
        trios.append(curr_lst)
        curr_lst = []
len(trios)
# Out:
# 1763

# %%
# extra_trios

# %%
# discription_df[(discription_df["num_relevant_genes"] > 10) & (discription_df["sex"] == "B")]

# %%
# unique_counts_female

# %%
def get_unique_counts_dicts(trios,res_type = "uniprot_id"):
    unique_counts_female = {}
    counter = 0
    unique_counts_male = {}
    overall_count = {}
    extra_trios = []
    for trio in trios:
        curr = sorted(trio,key=lambda x:x[0])
        if curr[0][1] == -1 or curr[1][1] == -1 or curr[2][1] == -1:
            continue
        
        counter+=1
        both_df = pd.read_csv(curr[0][2],nrows=int(curr[0][1]))
        both_df.dropna(subset=[res_type],inplace=True)
        both_set = set(both_df[both_df["fdr_significance"] == True][res_type])
        female_df = pd.read_csv(curr[1][2],nrows=int(curr[1][1]))
        female_df.dropna(subset=[res_type],inplace=True)
        female_set = set(female_df[female_df["fdr_significance"] == True][res_type])
        male_df = pd.read_csv(curr[2][2],nrows=int(curr[2][1]))
        male_df.dropna(subset=[res_type],inplace=True)
        male_set = set(male_df[male_df["fdr_significance"] == True][res_type])
#         if len((female_set - (both_set.union(male_set)))) > 10:
#             print(curr[0][2])
        for female_u in (female_set - (both_set.union(male_set))):
            if female_u not in unique_counts_female:
                unique_counts_female[female_u]=0
            unique_counts_female[female_u]+=1
        for male_u in (male_set - (both_set.union(female_set))):
            if male_u not in unique_counts_male:
                unique_counts_male[male_u]=0
            unique_counts_male[male_u]+=1
        for gene in female_set.union(male_set).union(both_set):
            if gene not in overall_count:
                overall_count[gene]=0
            overall_count[gene]+=1
        val = curr[:]
        val.append(len(female_set - (both_set.union(male_set))))
        val.append(len(male_set - (both_set.union(female_set))))
        val.append(len((both_set.union(female_set)).union(male_set)))
        extra_trios.append(val)
    print(counter)
    return unique_counts_female,unique_counts_male,overall_count,extra_trios
unique_counts_female,unique_counts_male,overall_count,extra_trios = get_unique_counts_dicts(trios,"symbol")

#     print(both_df)
# Out:
# 730

# %%
def get_female_male_intersection(trios,res_type = "uniprot_id"):
    unique_counts_female = {}
    counter = 0
    unique_counts_male = {}
    overall_count = {}
    extra_trios = []
    for trio in trios:
        curr = sorted(trio,key=lambda x:x[0])
        if curr[0][1] == -1 or curr[1][1] == -1 or curr[2][1] == -1:
            continue
        
        counter+=1
        female_df = pd.read_csv(curr[1][2],nrows=int(curr[1][1]))
        female_df.dropna(subset=[res_type],inplace=True)
        female_set = set(female_df[female_df["fdr_significance"] == True][res_type])
        male_df = pd.read_csv(curr[2][2],nrows=int(curr[2][1]))
        male_df.dropna(subset=[res_type],inplace=True)
        male_set = set(male_df[male_df["fdr_significance"] == True][res_type])
#         if len((female_set - (both_set.union(male_set)))) > 10:
#             print(curr[0][2])
        intersection_count = len(female_set.intersection(male_set))
        union_count = len(female_set.union(male_set))
        val = curr[:]
        val.append(intersection_count)
        val.append(union_count)
        extra_trios.append(val)
    print(counter)
    return extra_trios
female_male_extra_trios = get_female_male_intersection(trios,"symbol")
# Out:
# 730

# %%
fm_int = list(map(lambda x: (x[-2],x[-1],x[0][0]),female_male_extra_trios))

# %%
new_lst = []
for var in fm_int:
    if var[1] == 0:
        continue
    new_lst.append(var[0]/var[1])

# %%
sorted(fm_int)
# Out:
# [(0, 0, 'D64'),
#  (0, 0, 'D649'),
#  (0, 0, 'F17'),
#  (0, 0, 'F171'),
#  (0, 0, 'F32'),
#  (0, 0, 'F329'),
#  (0, 0, 'H26'),
#  (0, 0, 'H269'),
#  (0, 0, 'I84'),
#  (0, 0, 'I849'),
#  (0, 0, 'ICD10_M15'),
#  (0, 0, 'ICD10_M159'),
#  (0, 0, 'ICD10_Z90'),
#  (0, 0, 'J18'),
#  (0, 0, 'K21'),
#  (0, 0, 'K219'),
#  (0, 0, 'K29'),
#  (0, 0, 'K30'),
#  (0, 0, 'K44'),
#  (0, 0, 'K449'),
#  (0, 0, 'K52'),
#  (0, 0, 'K57'),
#  (0, 0, 'K573'),
#  (0, 0, 'K59'),
#  (0, 0, 'K590'),
#  (0, 0, 'K63'),
#  (0, 0, 'K635'),
#  (0, 0, 'M13'),
#  (0, 0, 'M139'),
#  (0, 0, 'M179'),
#  (0, 0, 'M54'),
#  (0, 0, 'M79'),
#  (0, 0, 'N39'),
#  (0, 0, 'N390'),
#  (0, 0, 'Phecode_1010.0'),
#  (0, 0, 'Phecode_1019.0'),
#  (0, 0, 'Phecode_159.0'),
#  (0, 0, 'Phecode_165.1'),
#  (0, 0, 'Phecode_195.1'),
#  (0, 0, 'Phecode_197.0'),
#  (0, 0, 'Phecode_198.1'),
#  (0, 0, 'Phecode_199.0'),
#  (0, 0, 'Phecode_211.0'),
#  (0, 0, 'Phecode_280.1'),
#  (0, 0, 'Phecode_285.0'),
#  (0, 0, 'Phecode_318.0'),
#  (0, 0, 'Phecode_339.0'),
#  (0, 0, 'Phecode_345.0'),
#  (0, 0, 'Phecode_345.3'),
#  (0, 0, 'Phecode_351.0'),
#  (0, 0, 'Phecode_362.0'),
#  (0, 0, 'Phecode_365.0'),
#  (0, 0, 'Phecode_366.0'),
#  (0, 0, 'Phecode_374.0'),
#  (0, 0, 'Phecode_38.0'),
#  (0, 0, 'Phecode_396.0'),
#  (0, 0, 'Phecode_411.1'),
#  (0, 0, 'Phecode_418.0'),
#  (0, 0, 'Phecode_428.2'),
#  (0, 0, 'Phecode_455.0'),
#  (0, 0, 'Phecode_458.9'),
#  (0, 0, 'Phecode_470.0'),
#  (0, 0, 'Phecode_480.0'),
#  (0, 0, 'Phecode_480.11'),
#  (0, 0, 'Phecode_508.0'),
#  (0, 0, 'Phecode_512.7'),
#  (0, 0, 'Phecode_513.0'),
#  (0, 0, 'Phecode_519.8'),
#  (0, 0, 'Phecode_525.0'),
#  (0, 0, 'Phecode_530.11'),
#  (0, 0, 'Phecode_530.12'),
#  (0, 0, 'Phecode_530.14'),
#  (0, 0, 'Phecode_532.0'),
#  (0, 0, 'Phecode_535.0'),
#  (0, 0, 'Phecode_535.6'),
#  (0, 0, 'Phecode_535.8'),
#  (0, 0, 'Phecode_550.2'),
#  (0, 0, 'Phecode_560.4'),
#  (0, 0, 'Phecode_561.0'),
#  (0, 0, 'Phecode_562.1'),
#  (0, 0, 'Phecode_564.0'),
#  (0, 0, 'Phecode_565.0'),
#  (0, 0, 'Phecode_568.0'),
#  (0, 0, 'Phecode_568.1'),
#  (0, 0, 'Phecode_569.0'),
#  (0, 0, 'Phecode_573.7'),
#  (0, 0, 'Phecode_579.8'),
#  (0, 0, 'Phecode_596.0'),
#  (0, 0, 'Phecode_597.1'),
#  (0, 0, 'Phecode_599.0'),
#  (0, 0, 'Phecode_599.5'),
#  (0, 0, 'Phecode_689.0'),
#  (0, 0, 'Phecode_721.0'),
#  (0, 0, 'Phecode_721.1'),
#  (0, 0, 'Phecode_726.0'),
#  (0, 0, 'Phecode_726.1'),
#  (0, 0, 'Phecode_727.1'),
#  (0, 0, 'Phecode_729.0'),
#  (0, 0, 'Phecode_733.0'),
#  (0, 0, 'Phecode_740.11'),
#  (0, 0, 'Phecode_745.0'),
#  (0, 0, 'Phecode_760.0'),
#  (0, 0, 'Phecode_766.0'),
#  (0, 0, 'Phecode_771.1'),
#  (0, 0, 'Phecode_773.0'),
#  (0, 0, 'Phecode_783.0'),
#  (0, 0, 'Phecode_785.0'),
#  (0, 0, 'Phecode_819.0'),
#  (0, 0, 'Phecode_850.0'),
#  (0, 0, 'Phecode_851.0'),
#  (0, 0, 'Phecode_915.0'),
#  (0, 0, 'Phecode_960.2'),
#  (0, 0, 'R07'),
#  (0, 0, 'R074'),
#  (0, 0, 'R10'),
#  (0, 0, 'R104'),
#  (0, 0, 'R11'),
#  (0, 0, 'R194'),
#  (0, 0, 'R69'),
#  (0, 2, 'Phecode_112.0'),
#  (0, 2, 'Phecode_189.11'),
#  (0, 2, 'Phecode_229.0'),
#  (0, 2, 'Phecode_276.5'),
#  (0, 2, 'Phecode_287.0'),
#  (0, 2, 'Phecode_316.0'),
#  (0, 2, 'Phecode_327.3'),
#  (0, 2, 'Phecode_361.1'),
#  (0, 2, 'Phecode_374.3'),
#  (0, 2, 'Phecode_386.9'),
#  (0, 2, 'Phecode_394.2'),
#  (0, 2, 'Phecode_395.2'),
#  (0, 2, 'Phecode_41.4'),
#  (0, 2, 'Phecode_426.91'),
#  (0, 2, 'Phecode_428.1'),
#  (0, 2, 'Phecode_433.2'),
#  (0, 2, 'Phecode_509.1'),
#  (0, 2, 'Phecode_512.0'),
#  (0, 2, 'Phecode_521.1'),
#  (0, 2, 'Phecode_530.2'),
#  (0, 2, 'Phecode_531.3'),
#  (0, 2, 'Phecode_555.2'),
#  (0, 2, 'Phecode_573.0'),
#  (0, 2, 'Phecode_575.8'),
#  (0, 2, 'Phecode_585.1'),
#  (0, 2, 'Phecode_592.1'),
#  (0, 2, 'Phecode_594.0'),
#  (0, 2, 'Phecode_595.0'),
#  (0, 2, 'Phecode_598.0'),
#  (0, 2, 'Phecode_687.1'),
#  (0, 2, 'Phecode_716.9'),
#  (0, 2, 'Phecode_741.0'),
#  (0, 2, 'Phecode_803.2'),
#  (0, 2, 'Phecode_858.0'),
#  (0, 3, 'I20'),
#  (0, 3, 'ICD10_Z720'),
#  (0, 3, 'K62'),
#  (0, 3, 'Phecode_1008.0'),
#  (0, 3, 'Phecode_1015.0'),
#  (0, 3, 'Phecode_153.2'),
#  (0, 3, 'Phecode_153.3'),
#  (0, 3, 'Phecode_198.6'),
#  (0, 3, 'Phecode_202.2'),
#  (0, 3, 'Phecode_228.0'),
#  (0, 3, 'Phecode_272.1'),
#  (0, 3, 'Phecode_288.11'),
#  (0, 3, 'Phecode_292.1'),
#  (0, 3, 'Phecode_365.11'),
#  (0, 3, 'Phecode_367.1'),
#  (0, 3, 'Phecode_395.1'),
#  (0, 3, 'Phecode_411.3'),
#  (0, 3, 'Phecode_433.21'),
#  (0, 3, 'Phecode_433.31'),
#  (0, 3, 'Phecode_477.0'),
#  (0, 3, 'Phecode_514.0'),
#  (0, 3, 'Phecode_516.1'),
#  (0, 3, 'Phecode_531.0'),
#  (0, 3, 'Phecode_540.11'),
#  (0, 3, 'Phecode_550.0'),
#  (0, 3, 'Phecode_550.5'),
#  (0, 3, 'Phecode_564.1'),
#  (0, 3, 'Phecode_564.8'),
#  (0, 3, 'Phecode_574.3'),
#  (0, 3, 'Phecode_578.1'),
#  (0, 3, 'Phecode_578.2'),
#  (0, 3, 'Phecode_594.1'),
#  (0, 3, 'Phecode_702.2'),
#  (0, 3, 'Phecode_720.0'),
#  (0, 3, 'Phecode_740.1'),
#  (0, 3, 'Phecode_741.4'),
#  (0, 3, 'Phecode_781.0'),
#  (0, 3, 'Phecode_788.0'),
#  (0, 3, 'Phecode_79.0'),
#  (0, 3, 'Phecode_798.0'),
#  (0, 3, 'Phecode_800.2'),
#  (0, 39, 'Phecode_577.3'),
#  (0, 39, 'Phecode_681.2'),
#  (0, 39, 'Phecode_731.0'),
#  (0, 39, 'Phecode_747.1'),
#  (0, 40, 'Phecode_275.3'),
#  (0, 40, 'Phecode_751.21'),
#  (0, 41, 'Phecode_368.4'),
#  (0, 41, 'Phecode_389.4'),
#  (0, 41, 'Phecode_540.1'),
#  (0, 42, 'Phecode_253.1'),
#  (0, 42, 'Phecode_697.0'),
#  (0, 44, 'Phecode_250.42'),
#  (0, 44, 'Phecode_448.0'),
#  (0, 44, 'Phecode_571.51'),
#  (0, 46, 'Phecode_293.1'),
#  (0, 46, 'Phecode_389.2'),
#  (0, 46, 'Phecode_531.4'),
#  (0, 48, 'Phecode_573.3'),
#  (0, 48, 'Phecode_579.2'),
#  (0, 49, 'Phecode_1004.0'),
#  (0, 49, 'Phecode_571.81'),
#  (0, 51, 'Phecode_360.0'),
#  (0, 53, 'ICD10_K746'),
#  (0, 53, 'Phecode_386.2'),
#  (0, 57, 'Phecode_528.11'),
#  (0, 59, 'Phecode_722.1'),
#  (0, 65, 'Phecode_338.1'),
#  (0, 67, 'Phecode_727.6'),
#  (0, 76, 'Phecode_722.7'),
#  (0, 76, 'Phecode_738.0'),
#  (0, 82, 'Phecode_723.0'),
#  (1, 1, 'Phecode_496.21'),
#  (1, 2, 'Phecode_172.3'),
#  (1, 2, 'Phecode_454.1'),
#  (1, 2, 'Phecode_496.0'),
#  (1, 4, 'Phecode_389.0'),
#  (1, 6, 'Phecode_555.1'),
#  (1, 6, 'Phecode_574.2'),
#  (1, 6, 'Phecode_716.2'),
#  (1, 7, 'Phecode_172.11'),
#  (1, 7, 'Phecode_574.12'),
#  (1, 9, 'Phecode_415.0'),
#  (1, 9, 'Phecode_415.11'),
#  (1, 9, 'Phecode_728.7'),
#  (1, 9, 'Phecode_938.2'),
#  (1, 12, 'Phecode_274.1'),
#  (1, 12, 'Phecode_290.1'),
#  (1, 12, 'Phecode_290.11'),
#  (1, 12, 'Phecode_702.1'),
#  (1, 17, 'I251'),
#  (1, 22, 'ICD10_Z73'),
#  (1, 23, 'I10'),
#  (1, 31, 'Phecode_728.71'),
#  (1, 40, 'Phecode_352.1'),
#  (1, 47, 'Phecode_292.6'),
#  (1, 50, 'Phecode_705.8'),
#  (2, 7, 'Phecode_706.2'),
#  (2, 8, 'M17'),
#  (2, 8, 'Phecode_704.0'),
#  (2, 49, 'Phecode_696.42'),
#  (3, 11, 'Phecode_250.2'),
#  (3, 12, 'E11'),
#  (3, 12, 'E119'),
#  (4, 39, 'Phecode_335.0'),
#  (4, 85, 'Phecode_250.13'),
#  (5, 13, 'J45'),
#  (5, 13, 'J459'),
#  (5, 13, 'Phecode_495.0'),
#  (5, 14, 'C44'),
#  (5, 14, 'E78'),
#  (5, 14, 'Phecode_172.2'),
#  (5, 15, 'K80'),
#  (5, 15, 'Phecode_574.1'),
#  (5, 17, 'E780'),
#  (7, 27, 'Phecode_593.0'),
#  (7, 27, 'R31'),
#  (7, 64, 'E039'),
#  (7, 65, 'E03'),
#  (9, 23, 'Phecode_714.1'),
#  (11, 39, 'Phecode_275.0'),
#  (14, 46, 'Phecode_696.41'),
#  (17, 56, 'Phecode_696.4'),
#  (17, 59, 'Phecode_250.1'),
#  (43, 147, 'Phecode_275.1'),
#  (74, 127, 'Phecode_557.0'),
#  (78, 155, 'Phecode_557.1')]

# %%
np.var(new_lst)
# Out:
# 0.0076751410485070785

# %%
max_unique = 0
max_unique_name = ""
metrics = []
verbous = False
for trio in extra_trios:
#     print(trio)    
    if trio[3] > max_unique or trio[4] > max_unique:
        max_unique = max(trio[3],trio[4])
        max_unique_name = trio[0][0]
    if verbous:
        print("name:",trio[0][0])
        print("name_F:",trio[1][0])
        print("female_sig:",trio[3])
        print("male_sig:",trio[4])
        print("female_cases:",trio[1][3])
        print("male_cases:",trio[2][3])
        print("female_control:",trio[1][4])
        print("male_control:",trio[2][4])
        print("#"*30)
    metrics.append({"name":trio[0][0],"female_sig":trio[3],"male_sig":trio[4],"all_genes":trio[5], "female_cases":trio[1][3],"male_cases":trio[2][3],"both_cases":trio[0][3],"female_control":trio[1][4],"male_control":trio[2][4],"both_control":trio[0][4]})
if verbous:
    print(max_unique_name,max_unique)

# %%
len(metrics)
# Out:
# 730

# %%
def prepare_df(metrics):
    df = pd.DataFrame(metrics)
    df = df[df["all_genes"] > 1]
    df["FM_ratio"] = df["female_cases"] / df["male_cases"]
    df["log_FM_ratio"] = np.log10(df["FM_ratio"])
    df["MF_ratio"] = df["male_cases"] / df["female_cases"]
    df["log_MF_ratio"] = np.log10(df["MF_ratio"])
    df["F_unique_genes_ratio"] = df["female_sig"] / df["all_genes"]
    df["M_unique_genes_ratio"] = df["male_sig"] / df["all_genes"]
#     df["B_unique_genes_ratio"] = df["male_sig"] / df["all_genes"]
    df["F_prevalence"] = df["female_cases"] / (df["female_cases"] + df["female_control"])
    df["M_prevalence"] = df["male_cases"] / (df["male_cases"] + df["male_control"])
    df["B_prevalence"] = df["both_cases"] / (df["both_cases"] + df["both_control"])
    df["log_F_prevalence"] = np.log(df["F_prevalence"])
    df["log_M_prevalence"] = np.log(df["M_prevalence"])
    df["log_B_prevalence"] = np.log(df["B_prevalence"])
    return df

def plot_scatter_plot(df,x,y,title,logx=False):
    df.plot.scatter(x=x, y=y,logx=logx)
    plt.title(title)
    plt.show()

def plot_hexplot(df,x,y,title,regression_line=False):
    ax = sns.jointplot(x=(df[x]), y=df[y], kind="hex", color="#4CB391")
    if regression_line:
        sns.regplot(x=(df[x]), y=df[y],scatter=False, line_kws={"color": "black"})
    ax1 = ax.fig.add_axes([1., .25, .05, .4])  # x, y, width, height
    plt.colorbar(cax=ax1)
    ax.fig.suptitle(title )
    plt.show()
    
def plot_histplot(df,x,bins):
    ax = sns.histplot(data=df, x=x,bins=bins)
    for i in ax.containers:
    #     if i > 0:
        ax.bar_label(i,)
        
    plt.show()

def plot_scatter_plot_wth_regression_line(df,x,y,title):
    pass
def plot_mean_group_bar_plot(df,x,y,bins,xlable,ylable,title):
    
    age_groups = pd.cut(df[x], bins=bins)

    # Group the data by age groups and calculate the mean income for each group
    grouped_df = df.groupby(age_groups)[y].mean()

    # Create a bar plot of the mean income for each age group
    grouped_df.plot(kind='bar')

    # Set the x-axis labels to be the age group categories
    plt.xticks(range(len(grouped_df.index)), grouped_df.index.categories)

    # Add labels to the x and y axes and a title to the plot
    plt.xlabel(xlable)
    plt.ylabel(ylable)
    plt.title(title)
#     plt.fi
    # Show the plot
    plt.show()

# %% [markdown]
# ## phenotype based view

# %%
df = prepare_df(metrics)

plot_scatter_plot(df,'FM_ratio','female_sig',"number of female only sig genes over F/M case ratio logarithmic scale",True)

plot_scatter_plot(df,'FM_ratio','F_unique_genes_ratio',"number of female only sig genes over F/M case ratio logarithmic scale",True)


plot_hexplot(df,"log_FM_ratio","female_sig","number of female only sig genes over F/M case ratio hex plot",True)

plot_hexplot(df,"log_FM_ratio","F_unique_genes_ratio","ratio of female only sig genes over F/M case ratio hex plot",True)

plot_hexplot(df,"log_F_prevalence","F_unique_genes_ratio","ratio of female only sig genes over F_prevalence hex plot",True)

plot_histplot(df,"log_FM_ratio",24)

plot_mean_group_bar_plot(df,'log_FM_ratio','female_sig',list(np.arange(-2,1,0.25)),'log of FM_ratio Group',
                        'Mean number of significant female genes',
                         'Mean number of significant female genes by log of F/M ratio Group')

plot_mean_group_bar_plot(df,'log_FM_ratio','F_unique_genes_ratio',list(np.arange(-2,1,0.25)),'log of FM_ratio Group',
                        'Mean F_unique_genes_ratio',
                         'Mean F_unique_genes_ratio by log of F/M ratio Group')

# TODO: add plot with other mesurments of genetic signal
# TODO: add by prevelance, both filtering and as x axis
# TODO: add ratio of sig female from overall

# %%
df
# Out:
#                name  female_sig  male_sig  all_genes  female_cases  \
# 0       Phecode_8.0           0         0          3          4072
# 1       Phecode_8.5           2         0         13           966
# 2      Phecode_8.52           7        18         27           335
# 3       Phecode_8.6           1        10         23           485
# 4      Phecode_38.2          12         3         25           191
# ..              ...         ...       ...        ...           ...
# 724   Phecode_960.0           0         4          5          2886
# 725   Phecode_965.1           0        14         16          1047
# 727  Phecode_426.91           2         0          3           745
# 728   Phecode_395.6           1         0          4           493
# 729   Phecode_367.0           0         1          3          1125
#
#      male_cases  both_cases  female_control  male_control  both_control  ...  \
# 0          3106        7178          145111        122535        267646  ...
# 1           800        1766          148217        124841        273058  ...
# 2           323         658          148848        125318        274166  ...
# 3           403         888          148698        125238        273936  ...
# 4           319         510          148992        125322        274314  ...
# ..          ...         ...             ...           ...           ...  ...
# 724         768        3654          146297        124873        271170  ...
# 725         327        1374          148136        125314        273450  ...
# 727        1733        2478          148438        123908        272346  ...
# 728        1035        1528          148690        124606        273296  ...
# 729         902        2027          148058        124739        272797  ...
#
#      MF_ratio  log_MF_ratio  F_unique_genes_ratio  M_unique_genes_ratio  \
# 0    0.762770     -0.117606              0.000000              0.000000
# 1    0.828157     -0.081887              0.153846              0.000000
# 2    0.964179     -0.015842              0.259259              0.666667
# 3    0.830928     -0.080437              0.043478              0.434783
# 4    1.670157      0.222757              0.480000              0.120000
# ..        ...           ...                   ...                   ...
# 724  0.266112     -0.574935              0.000000              0.800000
# 725  0.312321     -0.505399              0.000000              0.875000
# 727  2.326174      0.366642              0.666667              0.000000
# 728  2.099391      0.322093              0.250000              0.000000
# 729  0.801778     -0.095946              0.000000              0.333333
#
#      F_prevalence  M_prevalence  B_prevalence  log_F_prevalence  \
# 0        0.027295      0.024721      0.026119         -3.601039
# 1        0.006475      0.006367      0.006426         -5.039765
# 2        0.002246      0.002571      0.002394         -6.098798
# 3        0.003251      0.003208      0.003231         -5.728780
# 4        0.001280      0.002539      0.001856         -6.660656
# ..            ...           ...           ...               ...
# 724      0.019345      0.006113      0.013296         -3.945302
# 725      0.007018      0.002603      0.005000         -4.959245
# 727      0.004994      0.013793      0.009017         -5.299545
# 728      0.003305      0.008238      0.005560         -5.712420
# 729      0.007541      0.007179      0.007376         -4.887391
#
#      log_M_prevalence  log_B_prevalence
# 0           -3.700093         -3.645110
# 1           -5.056572         -5.047414
# 2           -5.963532         -6.034681
# 3           -5.742247         -5.734914
# 4           -5.975993         -6.289475
# ..                ...               ...
# 724         -5.097394         -4.320308
# 725         -5.951224         -5.298405
# 727         -4.283575         -4.708679
# 728         -4.799027         -5.192171
# 729         -4.936569         -4.909574
#
# [583 rows x 22 columns]

# %%
plot_hexplot(df,"log_F_prevalence","F_unique_genes_ratio","ratio of female only sig genes over F_prevalence hex plot",True)
plot_hexplot(df,"log_M_prevalence","F_unique_genes_ratio","ratio of female only sig genes over M_prevalence hex plot",True)
plot_hexplot(df,"log_M_prevalence","M_unique_genes_ratio","ratio of male only sig genes over M_prevalence hex plot",True)
plot_hexplot(df,"log_F_prevalence","M_unique_genes_ratio","ratio of male only sig genes over F_prevalence hex plot",True)

# plot_hexplot(df,"log_M_prevalence","M_unique_genes_ratio","ratio of male only sig genes over M_prevalence hex plot",True)

# %%
# plot_scatter_plot(df,'log_F_prevalence','F_unique_genes_ratio',"number of female only sig genes over F/M case ratio logarithmic scale")
# plot_hexplot(df,"log_F_prevalence","F_unique_genes_ratio","ratio of female only sig genes over F_prevalence hex plot")
# plot_hexplot(df,"log_F_prevalence","female_sig","ratio of female only sig genes over F_prevalence hex plot")
# plot_mean_group_bar_plot(df,'log_F_prevalence','F_unique_genes_ratio',list(np.arange(-7,-1,0.5)),'log_F_prevalence Group',
#                         'Mean F_unique_genes_ratio',
#                          'Mean F_unique_genes_ratio by log_F_prevalence Group')
# plot_histplot(df,"log_F_prevalence",24)

# %% [markdown]
# ### MF ratio

# %%
# cols

# %%
plot_hexplot(df,"log_MF_ratio","F_unique_genes_ratio","ratio of female only sig genes over F_prevalence hex plot",True)
count = int(len(df)*(10/100))
# count = 10
print("count",count)
print("low male to female ratio")
print("mean number of female sig genes",df.sort_values(by="FM_ratio").tail(count)["female_sig"].mean())
print("mean number of male sig genes",df.sort_values(by="FM_ratio").tail(count)["male_sig"].mean())
print("mean male prevalence",df.sort_values(by="FM_ratio").tail(count)["M_prevalence"].mean())
print("mean female prevalence",df.sort_values(by="FM_ratio").tail(count)["F_prevalence"].mean())

print("high male to female ratio")
print("mean number of female sig genes",df.sort_values(by="MF_ratio").tail(count)["female_sig"].mean())
print("mean number of male sig genes",df.sort_values(by="MF_ratio").tail(count)["male_sig"].mean())
print("mean male prevalence",df.sort_values(by="MF_ratio").tail(count)["M_prevalence"].mean())
print("mean female prevalence",df.sort_values(by="MF_ratio").tail(count)["F_prevalence"].mean())
# df.sort_values(by="FM_ratio").tail(10)
# Out:
# count 58
# low male to female ratio
# mean number of female sig genes 2.7241379310344827
# mean number of male sig genes 8.293103448275861
# mean male prevalence 0.006342235636346469
# mean female prevalence 0.014604257164366745
# high male to female ratio
# mean number of female sig genes 8.655172413793103
# mean number of male sig genes 2.0344827586206895
# mean male prevalence 0.026142218565266283
# mean female prevalence 0.006797830112379913

# %%
cols = list(df.columns)
# cols.remove("female_cases")
cols.remove("female_control")
cols.remove("male_control")
cols.remove("both_control")
cols.remove("both_cases")
df.sort_values(by="MF_ratio")[cols].tail(20)
# Out:
#                name  female_sig  male_sig  all_genes  female_cases  \
# 142   Phecode_316.0           2         0          2          1345
# 264   Phecode_442.1           9         1         33           183
# 66    Phecode_189.2          16         2         33           401
# 365   Phecode_550.4           8         0          8           909
# 239  Phecode_426.21          25         0         31           304
# 520   Phecode_726.3          13         3         25           199
# 245  Phecode_427.12          27         5         39           228
# 20    Phecode_150.0          20         1         24           205
# 555   Phecode_594.3           8         0          8           521
# 522  Phecode_728.71          21         2         37           803
# 227            I251           1         3         31          4237
# 226   Phecode_411.4           1         3         28          4517
# 33   Phecode_189.21          10         0         12           504
# 223   Phecode_411.2           0         4         10          2807
# 263   Phecode_440.2          15         0         29           191
# 400  Phecode_317.11           2         0         36           169
# 457   Phecode_274.1           5         0         14           477
# 363            K409           9         2         19           902
# 362   Phecode_550.1           5         3         23           966
# 361             K40           5         3         23           966
#
#      male_cases  FM_ratio  log_FM_ratio   MF_ratio  log_MF_ratio  \
# 142        3786  0.355256     -0.449458   2.814870      0.449458
# 264         522  0.350575     -0.455219   2.852459      0.455219
# 66         1152  0.348090     -0.458308   2.872818      0.458308
# 365        2612  0.348009     -0.458409   2.873487      0.458409
# 239         888  0.342342     -0.465539   2.921053      0.465539
# 520         598  0.332776     -0.477848   3.005025      0.477848
# 245         694  0.328530     -0.483425   3.043860      0.483425
# 20          630  0.325397     -0.487587   3.073171      0.487587
# 555        1642  0.317296     -0.498535   3.151631      0.498535
# 522        2561  0.313549     -0.503694   3.189290      0.503694
# 227       13519  0.313411     -0.503886   3.190701      0.503886
# 226       14427  0.313094     -0.504326   3.193934      0.504326
# 33         1624  0.310345     -0.508155   3.222222      0.508155
# 223        9062  0.309755     -0.508982   3.228358      0.508982
# 263         654  0.292049     -0.534544   3.424084      0.534544
# 400         670  0.252239     -0.598188   3.964497      0.598188
# 457        3059  0.155933     -0.807061   6.412998      0.807061
# 363       12345  0.073066     -1.136285  13.686253      1.136285
# 362       13632  0.070863     -1.149582  14.111801      1.149582
# 361       13632  0.070863     -1.149582  14.111801      1.149582
#
#      F_unique_genes_ratio  M_unique_genes_ratio  F_prevalence  M_prevalence  \
# 142              1.000000              0.000000      0.009016      0.030133
# 264              0.272727              0.030303      0.001227      0.004155
# 66               0.484848              0.060606      0.002688      0.009169
# 365              1.000000              0.000000      0.006093      0.020789
# 239              0.806452              0.000000      0.002038      0.007068
# 520              0.520000              0.120000      0.001334      0.004760
# 245              0.692308              0.128205      0.001528      0.005524
# 20               0.833333              0.041667      0.001374      0.005014
# 555              1.000000              0.000000      0.003492      0.013069
# 522              0.567568              0.054054      0.005383      0.020383
# 227              0.032258              0.096774      0.028401      0.107600
# 226              0.035714              0.107143      0.030278      0.114827
# 33               0.833333              0.000000      0.003378      0.012926
# 223              0.000000              0.400000      0.018816      0.072126
# 263              0.517241              0.000000      0.001280      0.005205
# 400              0.055556              0.000000      0.001133      0.005333
# 457              0.357143              0.000000      0.003197      0.024347
# 363              0.473684              0.105263      0.006046      0.098256
# 362              0.217391              0.130435      0.006475      0.108500
# 361              0.217391              0.130435      0.006475      0.108500
#
#      B_prevalence  log_F_prevalence  log_M_prevalence  log_B_prevalence
# 142      0.018670         -4.708780         -3.502119         -3.980830
# 264      0.002565         -6.703443         -5.483516         -5.965688
# 66       0.005651         -5.918968         -4.691929         -5.175942
# 365      0.012812         -5.100584         -3.873312         -4.357386
# 239      0.004337         -6.195901         -4.952212         -5.440498
# 520      0.002900         -6.619624         -5.347593         -5.843031
# 245      0.003355         -6.483583         -5.198712         -5.697341
# 20       0.003038         -6.589919         -5.295464         -5.796454
# 555      0.007870         -5.657179         -4.337514         -4.844635
# 522      0.012241         -5.224574         -3.893031         -4.403000
# 227      0.064609         -3.561318         -2.229333         -2.739407
# 226      0.068931         -3.497326         -2.164327         -2.674644
# 33       0.007743         -5.690353         -4.348536         -4.860948
# 223      0.043188         -3.973057         -2.629339         -3.142201
# 263      0.003075         -6.660656         -5.258077         -5.784550
# 400      0.003053         -6.783030         -5.233906         -5.791675
# 457      0.012866         -5.745413         -3.715341         -4.353135
# 363      0.048202         -5.108314         -2.320178         -3.032360
# 362      0.053118         -5.039765         -2.221009         -2.935246
# 361      0.053118         -5.039765         -2.221009         -2.935246

# %%
# df

# %% [markdown]
# ## Male/Female comparison

# %%
df = prepare_df(metrics)

plot_scatter_plot(df,'F_unique_genes_ratio','M_unique_genes_ratio',"M/F uniqe ratio comparison",False)

# %% [markdown]
# ## Gene based view

# %%
curr_list_female = sorted(list(unique_counts_female.items()),key=lambda x:-x[1])
curr_list_male = sorted(list(unique_counts_male.items()),key=lambda x:-x[1])

# %%
curr_list_female[:5]
# Out:
# [('CYP4Z1', 8), ('DEFB124', 6), ('VLDLR', 6), ('PCYT1B', 6), ('PPP1R10', 6)]

# %%
def add_ratio(curr_list,overall_count):
    for i in range(len(curr_list)):
        curr_list[i] = list(curr_list[i])
        curr_list[i].append(curr_list[i][1] / overall_count[curr_list[i][0]])
add_ratio(curr_list_female,overall_count)
add_ratio(curr_list_male,overall_count)

# %%
def display(curr_list):
    female_above_five = list(map(lambda x:x[2],filter(lambda x:x[1]  >5,curr_list)))
    female_above_four = list(map(lambda x:x[2],filter(lambda x:x[1]  >4,curr_list)))
    female_above_one = list(map(lambda x:x[2],filter(lambda x:x[1]  >1,curr_list)))
    female_above_two = list(map(lambda x:x[2],filter(lambda x:x[1]  >2,curr_list)))
    
    female_all = list(map(lambda x:x[2],filter(lambda x:x[1]  >0,curr_list)))
    print("above 5 avarage:",sum(female_above_five) / len(female_above_five))
    print("above 0 avarage:",sum(female_all) / len(female_all))
display(curr_list_female)
display(curr_list_male)
# Out:
# above 5 avarage: 0.8528571428571429
# above 0 avarage: 0.7727761962171741
# above 5 avarage: 0.75
# above 0 avarage: 0.7423416867419882

# %% [markdown]
# ## gene point of view comparison

# %%
number_pairs = []
for val in set(unique_counts_female).union(set(unique_counts_male)):
    count_male = 0
    count_female = 0
    if val in unique_counts_female:
        count_female = unique_counts_female[val]
    if val in unique_counts_male:
        count_male = unique_counts_male[val]
    if (count_male == 1 and count_female == 0) or  (count_male == 0 and count_female == 1) :
        continue
#     if val in unique_counts_male :
    number_pairs.append([val,count_female,count_male])

# %%
gene_pov_df = pd.DataFrame(number_pairs,columns=["name","uniqe_female_count","uniqe_male_count"])
plot_hexplot(gene_pov_df,'uniqe_female_count','uniqe_male_count',"M/F uniqe disease comparison",True)
plot_hexplot(gene_pov_df,'uniqe_female_count','uniqe_male_count',"M/F uniqe disease comparison",False)


# sumfor pair in number_pairs:
#     if pair[1] != pair[2]:
#         print(pair)

# %%
len(set(unique_counts_male).intersection(set(unique_counts_female)))
# Out:
# 494

# %% [markdown]
# ## specific genes study

# %%
female_interesting_genes = sorted(filter(lambda x:x[1] > 3,curr_list_female),key=lambda x:-x[2])
female_interesting_genes
female_gene_set = set(map(lambda x:x[0],female_interesting_genes[:5]))

# %%
male_interesting_genes = sorted(filter(lambda x:x[1] > 3,curr_list_male),key=lambda x:-x[2])
male_interesting_genes
male_gene_set = set(map(lambda x:x[0],male_interesting_genes[:5]))

# %%
trios[0][0][0]
# Out:
# 'Phecode_8.0'

# %%
def get_dict_for_genes(trios,genes : set,res_type = "uniprot_id"):
    res = dict()
    for trio in trios:
        curr = sorted(trio,key=lambda x:x[0])
        if curr[0][1] == -1 or curr[1][1] == -1 or curr[2][1] == -1:
            continue
        
        both_df = pd.read_csv(curr[0][2],nrows=int(curr[0][1]))
        both_df.dropna(subset=[res_type],inplace=True)
        both_set = set(both_df[both_df["fdr_significance"] == True][res_type])
        female_df = pd.read_csv(curr[1][2],nrows=int(curr[1][1]))
        female_df.dropna(subset=[res_type],inplace=True)
        female_set = set(female_df[female_df["fdr_significance"] == True][res_type])
        male_df = pd.read_csv(curr[2][2],nrows=int(curr[2][1]))
        male_df.dropna(subset=[res_type],inplace=True)
        male_set = set(male_df[male_df["fdr_significance"] == True][res_type])
        for female_u in (female_set - (both_set.union(male_set))):
            if female_u in genes:
                if female_u not in res.keys():
                    res[female_u] = []
                res[female_u].append(trio[0][0])
    return res
sig_genes_phens_res = get_dict_for_genes(trios,female_gene_set,"symbol")

#     print(both_df)

# %%
sig_genes_phens_res["BIK"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_15517/4238496902.py in <module>
# ----> 1 sig_genes_phens_res["BIK"]
#
# KeyError: 'BIK'

# %%
for val in female_interesting_genes:
    print(val)
# Out:
# ['PCYT1B', 6, 1.0]
# ['NSD3', 5, 1.0]
# ['HIC1', 5, 1.0]
# ['ABCF1', 5, 1.0]
# ['XXYLT1', 5, 1.0]
# ['PPP1R1A', 5, 1.0]
# ['SORL1', 4, 1.0]
# ['RASGEF1B', 4, 1.0]
# ['DEFB123', 4, 1.0]
# ['SMIM7', 4, 1.0]
# ['CACNA2D3', 4, 1.0]
# ['COMMD7', 4, 1.0]
# ['TGM1', 4, 1.0]
# ['SAP18', 4, 1.0]
# ['CASP1', 4, 1.0]
# ['MYADM', 4, 1.0]
# ['MAX', 4, 1.0]
# ['SNAI3', 4, 1.0]
# ['NOA1', 4, 1.0]
# ['BCOR', 4, 1.0]
# ['DEFB124', 6, 0.8571428571428571]
# ['PPP1R10', 6, 0.8571428571428571]
# ['UBXN4', 5, 0.8333333333333334]
# ['CXXC5', 5, 0.8333333333333334]
# ['SH3PXD2A', 5, 0.8333333333333334]
# ['CYP4Z1', 8, 0.8]
# ['C5orf24', 4, 0.8]
# ['SOD1', 4, 0.8]
# ['IL17RE', 4, 0.8]
# ['PRPF3', 4, 0.8]
# ['CYLC1', 4, 0.8]
# ['BAMBI', 4, 0.8]
# ['VLDLR', 6, 0.75]
# ['BTLA', 5, 0.7142857142857143]
# ['AZIN1', 5, 0.7142857142857143]
# ['GRM3', 5, 0.7142857142857143]
# ['LRP12', 4, 0.6666666666666666]
# ['IGKV1-12', 4, 0.6666666666666666]
# ['NUDCD2', 4, 0.6666666666666666]
# ['SLIT2', 4, 0.6666666666666666]
# ['PRMT8', 4, 0.6666666666666666]
# ['CHTF8', 5, 0.625]
# ['BMPER', 4, 0.5714285714285714]
# ['KSR2', 5, 0.5555555555555556]
# ['LMO2', 4, 0.5]
# ['ACTR2', 4, 0.4444444444444444]

# %%
for val in male_interesting_genes:
    print(val)
# Out:
# ['NPB', 5, 1.0]
# ['TLE4', 4, 1.0]
# ['HSD17B10', 4, 1.0]
# ['CALN1', 4, 1.0]
# ['RRP36', 4, 1.0]
# ['SGF29', 4, 1.0]
# ['MAP2K6', 4, 1.0]
# ['IL6R', 4, 1.0]
# ['IFI30', 4, 1.0]
# ['SIT1', 4, 1.0]
# ['WAS', 4, 1.0]
# ['GPRC5B', 4, 1.0]
# ['CDK2AP1', 4, 0.8]
# ['NME9', 4, 0.8]
# ['MINAR2', 6, 0.75]
# ['CSNK2A2', 4, 0.5714285714285714]
# ['C6orf47', 4, 0.17391304347826086]

# %%
sig_genes_phens_res
# Out:
# {'PCYT1B': ['Phecode_189.21',
#   'Phecode_433.0',
#   'Phecode_401.22',
#   'Phecode_447.1',
#   'Phecode_503.0',
#   'Phecode_447.0'],
#  'NSD3': ['Phecode_204.2',
#   'Phecode_531.0',
#   'Phecode_531.3',
#   'Phecode_747.1',
#   'Phecode_854.0'],
#  'HIC1': ['Phecode_250.23',
#   'Phecode_250.7',
#   'Phecode_361.1',
#   'Phecode_362.7',
#   'Phecode_447.1'],
#  'ABCF1': ['Phecode_291.8',
#   'Phecode_531.2',
#   'Phecode_571.51',
#   'ICD10_K746',
#   'Phecode_571.81'],
#  'XXYLT1': ['Phecode_442.1',
#   'Phecode_530.3',
#   'ICD10_K746',
#   'Phecode_596.5',
#   'Phecode_747.1']}

# %%
sorted(filter(lambda x:x[1] > 3,curr_list_male),key=lambda x:-x[2])
# Out:
# [['NPB', 5, 1.0],
#  ['TLE4', 4, 1.0],
#  ['HSD17B10', 4, 1.0],
#  ['CALN1', 4, 1.0],
#  ['RRP36', 4, 1.0],
#  ['SGF29', 4, 1.0],
#  ['MAP2K6', 4, 1.0],
#  ['IL6R', 4, 1.0],
#  ['IFI30', 4, 1.0],
#  ['SIT1', 4, 1.0],
#  ['WAS', 4, 1.0],
#  ['GPRC5B', 4, 1.0],
#  ['CDK2AP1', 4, 0.8],
#  ['NME9', 4, 0.8],
#  ['MINAR2', 6, 0.75],
#  ['CSNK2A2', 4, 0.5714285714285714],
#  ['C6orf47', 4, 0.17391304347826086]]

# %%
len(unique_counts_female)
# Out:
# 2862

# %%
sorted_females = sorted(list(unique_counts_female.items()),key=lambda x:-x[1])
sorted_males = sorted(list(unique_counts_male.items()),key=lambda x:-x[1])

# %%
def Merge(dict1, dict2):
    for i in dict2.keys():
        dict1[i]=dict2[i]
    return dict1

# %%
df = pd.read_csv("/cs/usr/roeizucker/my_storage/thesis/signif.sbgenes.txt",sep="\t")
# requests.get(url, params={key: value}, args)
curr_dict = {}
for i in range(20):
    starting_loc = i*100
    end_loc = starting_loc+99
    genes_to_translate =  list(df["gene"].value_counts().sort_values(ascending=False)[starting_loc:end_loc].index)
    for i in range(len(genes_to_translate)):
        genes_to_translate[i] = genes_to_translate[i].split(".")[0]
    obj = {'api':1,"ids":genes_to_translate}
    url = "http://www.biotools.fr/human/ensembl_symbol_converter/?api=1&ids=["
    for val in genes_to_translate:
        url+="\"" + val + "\","
    url = url[:-1]
    url+="]"
    x = requests.get(url)
    # print(x.text)
    json_object = json.loads(x.text)
    Merge(curr_dict,json_object)
print(len(curr_dict))
diff_set = set(curr_dict.values())
# print(url)
# Out:
# 1980

# %%
num_genes = len(sorted_females)
num_genes = 100
female_set = set(map(lambda x:x[0],sorted_females[:num_genes]))

# %%
print(len(female_set))
print(len(diff_set))
print(len(df["gene"].unique()))
# Out:
# 100
# 1979
# 13294

# %%
# for gene in female_set:
#     print(gene)

# %% [markdown]
# # Method for identifying sex depandent disease

# %%
# run with similar population sizes
# find the number of genes that appear only in one sex, and not in both, out of all.
# create unified score
from scipy import stats

# %%
# find the number of male/female sig:
female_sig = 0
male_sig = 0
overall = 0
for val in metrics:
    female_sig+=val["female_sig"]
    male_sig+=val["male_sig"]
    overall+=val["all_genes"]

# %%
for val in metrics:
#     print(val)
    female_p = stats.binom_test(val["female_sig"], n=val["all_genes"], p=female_sig/overall, alternative='greater')
#     print("female test",female_p)
    male_p = stats.binom_test(val["male_sig"], n=val["all_genes"], p=male_sig/overall, alternative='greater')
#     print("male test",male_p)
    if min([male_p,femlae_p]) < 5*10**-4:
        print(val)
        print(male_p,femlae_p)
# Out:
# {'name': 'Phecode_8.52', 'female_sig': 7, 'male_sig': 18, 'all_genes': 27, 'female_cases': 335, 'male_cases': 323, 'both_cases': 658, 'female_control': 148848, 'male_control': 125318, 'both_control': 274166}
# 4.6650682600922365e-07 1.0
# {'name': 'Phecode_198.2', 'female_sig': 0, 'male_sig': 5, 'all_genes': 5, 'female_cases': 1296, 'male_cases': 1248, 'both_cases': 2544, 'female_control': 147887, 'male_control': 124393, 'both_control': 272280}
# 0.00042740379670429165 1.0
# {'name': 'Phecode_244.1', 'female_sig': 0, 'male_sig': 23, 'all_genes': 33, 'female_cases': 906, 'male_cases': 201, 'both_cases': 1107, 'female_control': 148277, 'male_control': 125440, 'both_control': 273717}
# 3.0528739745902425e-09 1.0
# {'name': 'Phecode_251.1', 'female_sig': 2, 'male_sig': 13, 'all_genes': 22, 'female_cases': 375, 'male_cases': 611, 'both_cases': 986, 'female_control': 148808, 'male_control': 125030, 'both_control': 273838}
# 0.00012177085189347343 1.0
# {'name': 'Phecode_251.0', 'female_sig': 0, 'male_sig': 14, 'all_genes': 21, 'female_cases': 379, 'male_cases': 613, 'both_cases': 992, 'female_control': 148804, 'male_control': 125028, 'both_control': 273832}
# 9.214138532789512e-06 1.0
# {'name': 'Phecode_352.1', 'female_sig': 3, 'male_sig': 27, 'all_genes': 52, 'female_cases': 315, 'male_cases': 146, 'both_cases': 461, 'female_control': 148868, 'male_control': 125495, 'both_control': 274363}
# 1.0378539804050892e-06 1.0
# {'name': 'Phecode_375.2', 'female_sig': 1, 'male_sig': 17, 'all_genes': 29, 'female_cases': 549, 'male_cases': 276, 'both_cases': 825, 'female_control': 148634, 'male_control': 125365, 'both_control': 273999}
# 1.2651204350464027e-05 1.0
# {'name': 'Phecode_380.1', 'female_sig': 0, 'male_sig': 13, 'all_genes': 17, 'female_cases': 254, 'male_cases': 241, 'both_cases': 495, 'female_control': 148929, 'male_control': 125400, 'both_control': 274329}
# 1.7254780778612119e-06 1.0
# {'name': 'Phecode_380.0', 'female_sig': 13, 'male_sig': 17, 'all_genes': 36, 'female_cases': 414, 'male_cases': 475, 'both_cases': 889, 'female_control': 148769, 'male_control': 125166, 'both_control': 273935}
# 0.0004497305569865803 1.0
# {'name': 'Phecode_452.0', 'female_sig': 4, 'male_sig': 14, 'all_genes': 22, 'female_cases': 261, 'male_cases': 305, 'both_cases': 566, 'female_control': 148922, 'male_control': 125336, 'both_control': 274258}
# 2.036894804890052e-05 1.0
# {'name': 'Phecode_474.1', 'female_sig': 1, 'male_sig': 10, 'all_genes': 15, 'female_cases': 275, 'male_cases': 233, 'both_cases': 508, 'female_control': 148908, 'male_control': 125408, 'both_control': 274316}
# 0.0001890865876479115 1.0
# {'name': 'Phecode_476.0', 'female_sig': 5, 'male_sig': 11, 'all_genes': 17, 'female_cases': 633, 'male_cases': 567, 'both_cases': 1200, 'female_control': 148550, 'male_control': 125074, 'both_control': 273624}
# 0.00013193401378113915 1.0
# {'name': 'Phecode_501.0', 'female_sig': 1, 'male_sig': 10, 'all_genes': 11, 'female_cases': 281, 'male_cases': 560, 'both_cases': 841, 'female_control': 148902, 'male_control': 125081, 'both_control': 273983}
# 1.6222951137962617e-06 1.0
# {'name': 'Phecode_540.1', 'female_sig': 13, 'male_sig': 22, 'all_genes': 41, 'female_cases': 262, 'male_cases': 227, 'both_cases': 489, 'female_control': 148921, 'male_control': 125414, 'both_control': 274335}
# 5.072351989527753e-06 1.0
# {'name': 'Phecode_550.3', 'female_sig': 0, 'male_sig': 26, 'all_genes': 52, 'female_cases': 438, 'male_cases': 161, 'both_cases': 599, 'female_control': 148745, 'male_control': 125480, 'both_control': 274225}
# 4.104246204576924e-06 1.0
# {'name': 'Phecode_575.7', 'female_sig': 5, 'male_sig': 14, 'all_genes': 23, 'female_cases': 932, 'male_cases': 438, 'both_cases': 1370, 'female_control': 148251, 'male_control': 125203, 'both_control': 273454}
# 4.185782822432894e-05 1.0
# {'name': 'Phecode_698.0', 'female_sig': 3, 'male_sig': 16, 'all_genes': 32, 'female_cases': 434, 'male_cases': 288, 'both_cases': 722, 'female_control': 148749, 'male_control': 125353, 'both_control': 274102}
# 0.0002913616960894711 1.0
# {'name': 'Phecode_695.7', 'female_sig': 0, 'male_sig': 29, 'all_genes': 30, 'female_cases': 482, 'male_cases': 243, 'both_cases': 725, 'female_control': 148701, 'male_control': 125398, 'both_control': 274099}
# 6.8616841068328285e-19 1.0
# {'name': 'Phecode_694.2', 'female_sig': 0, 'male_sig': 13, 'all_genes': 20, 'female_cases': 470, 'male_cases': 295, 'both_cases': 765, 'female_control': 148713, 'male_control': 125346, 'both_control': 274059}
# 2.9266483882670004e-05 1.0
# {'name': 'Phecode_569.2', 'female_sig': 7, 'male_sig': 13, 'all_genes': 20, 'female_cases': 232, 'male_cases': 274, 'both_cases': 506, 'female_control': 148951, 'male_control': 125367, 'both_control': 274318}
# 2.9266483882670004e-05 1.0
# {'name': 'Phecode_714.0', 'female_sig': 2, 'male_sig': 25, 'all_genes': 43, 'female_cases': 443, 'male_cases': 231, 'both_cases': 674, 'female_control': 148740, 'male_control': 125410, 'both_control': 274150}
# 1.459383007619862e-07 1.0
# {'name': 'Phecode_735.2', 'female_sig': 2, 'male_sig': 10, 'all_genes': 12, 'female_cases': 1663, 'male_cases': 362, 'both_cases': 2025, 'female_control': 147520, 'male_control': 125279, 'both_control': 272799}
# 7.86226292897435e-06 1.0
# {'name': 'Phecode_741.2', 'female_sig': 4, 'male_sig': 29, 'all_genes': 45, 'female_cases': 320, 'male_cases': 246, 'both_cases': 566, 'female_control': 148863, 'male_control': 125395, 'both_control': 274258}
# 4.795225424724168e-10 1.0
# {'name': 'Phecode_737.3', 'female_sig': 0, 'male_sig': 19, 'all_genes': 25, 'female_cases': 885, 'male_cases': 283, 'both_cases': 1168, 'female_control': 148298, 'male_control': 125358, 'both_control': 273656}
# 7.2560778741851876e-09 1.0
# {'name': 'Phecode_738.4', 'female_sig': 0, 'male_sig': 17, 'all_genes': 17, 'female_cases': 1061, 'male_cases': 549, 'both_cases': 1610, 'female_control': 148122, 'male_control': 125092, 'both_control': 273214}
# 3.5063113504867407e-12 1.0
# {'name': 'ICD10_M511', 'female_sig': 1, 'male_sig': 9, 'all_genes': 10, 'female_cases': 1825, 'male_cases': 1432, 'both_cases': 3257, 'female_control': 147358, 'male_control': 124209, 'both_control': 271567}
# 6.975969887339948e-06 1.0
# {'name': 'Phecode_727.6', 'female_sig': 21, 'male_sig': 34, 'all_genes': 72, 'female_cases': 161, 'male_cases': 176, 'both_cases': 337, 'female_control': 149022, 'male_control': 125465, 'both_control': 274487}
# 8.017241947760573e-07 1.0
# {'name': 'Phecode_743.11', 'female_sig': 0, 'male_sig': 6, 'all_genes': 6, 'female_cases': 5106, 'male_cases': 1055, 'both_cases': 6161, 'female_control': 144077, 'male_control': 124586, 'both_control': 268663}
# 9.057452203244066e-05 1.0
# {'name': 'Phecode_756.5', 'female_sig': 6, 'male_sig': 25, 'all_genes': 37, 'female_cases': 227, 'male_cases': 183, 'both_cases': 410, 'female_control': 148956, 'male_control': 125458, 'both_control': 274414}
# 1.7273343805608143e-09 1.0
# {'name': 'Phecode_592.12', 'female_sig': 0, 'male_sig': 17, 'all_genes': 28, 'female_cases': 490, 'male_cases': 303, 'both_cases': 793, 'female_control': 148693, 'male_control': 125338, 'both_control': 274031}
# 6.529220298442634e-06 1.0
# {'name': 'Phecode_612.2', 'female_sig': 3, 'male_sig': 22, 'all_genes': 30, 'female_cases': 514, 'male_cases': 153, 'both_cases': 667, 'female_control': 148669, 'male_control': 125488, 'both_control': 274157}
# 1.4373588057024298e-09 1.0
# {'name': 'Phecode_293.0', 'female_sig': 0, 'male_sig': 5, 'all_genes': 5, 'female_cases': 495, 'male_cases': 1273, 'both_cases': 1768, 'female_control': 148688, 'male_control': 124368, 'both_control': 273056}
# 0.00042740379670429165 1.0
# {'name': 'Phecode_250.42', 'female_sig': 12, 'male_sig': 23, 'all_genes': 49, 'female_cases': 181, 'male_cases': 211, 'both_cases': 392, 'female_control': 149002, 'male_control': 125430, 'both_control': 274432}
# 5.2867546595028124e-05 1.0
# {'name': 'Phecode_965.1', 'female_sig': 0, 'male_sig': 14, 'all_genes': 16, 'female_cases': 1047, 'male_cases': 327, 'both_cases': 1374, 'female_control': 148136, 'male_control': 125314, 'both_control': 273450}
# 2.84591959491662e-08 1.0

# %%
data = {'age': [13, 14, 15, 16, 17, 18, 19, 20, 21],
        'income': [15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000]}
df = pd.DataFrame(data)

# Define the age groups
age_groups = pd.cut(df['age'], bins=[10, 15, 20, 25])

# Group the data by age groups and calculate the mean income for each group
grouped_df = df.groupby(age_groups)['income'].mean()

# Create a bar plot of the mean income for each age group
grouped_df.plot(kind='bar')

# Set the x-axis labels to be the age group categories
plt.xticks(range(len(grouped_df.index)), grouped_df.index.categories)

# Add labels to the x and y axes and a title to the plot
plt.xlabel('Age Group')
plt.ylabel('Mean Income')
plt.title('Mean Income by Age Group')

# Show the plot
plt.show()

# %%
list(np.arange(-2,1,0.25))
# Out:
# [-2.0, -1.75, -1.5, -1.25, -1.0, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.75]
