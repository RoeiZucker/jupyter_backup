# %%
import pandas as pd
import os

# %%
PROJECT_PATH = "/sci/nosnap/michall/roeizucker/Hypothyroidism_hackaton"
SOURCE_DATASET_FILE = "ukbb_dataset.csv"
RESULT_FILE = "ukbb_dataset_filtered.csv"
PHENOTYPES = ["E03","E04","E05","E06","E07"]

# %%
phens_with_sex = []
for phen in PHENOTYPES:
    phens_with_sex.append(phen)
    phens_with_sex.append(phen + "_F" )
    phens_with_sex.append(phen+"_M")

# %%
dataset_file = os.path.join(PROJECT_PATH,SOURCE_DATASET_FILE)
phenotypes_dataset = pd.read_csv(dataset_file)

# %%
phenotypes_dataset["sum"] = 0
for phen in PHENOTYPES:
    phenotypes_dataset["sum"] = phenotypes_dataset["sum"] + phenotypes_dataset[phen]

# %%
for phen in phens_with_sex:
    phenotypes_dataset.loc[phenotypes_dataset[phen] & (phenotypes_dataset["sum"] == 1),phen+"_reduced"] = 1
    phenotypes_dataset.loc[(phenotypes_dataset[phen] == False) & (phenotypes_dataset["sum"] == 0),phen+"_reduced"] = 0

# %%
phenotypes_daztaset.to_csv(os.path.join(PROJECT_PATH,RESULT_FILE))

# %%
print("[",end="")
for phen in phens_with_sex:
    print(f'"{phen}_reduced",',end="")
print("]")
# Out:
# ["E03_reduced","E03_F_reduced","E03_M_reduced","E04_reduced","E04_F_reduced","E04_M_reduced","E05_reduced","E05_F_reduced","E05_M_reduced","E06_reduced","E06_F_reduced","E06_M_reduced","E07_reduced","E07_F_reduced","E07_M_reduced",]

# %%
phenotypes_dataset
# Out:
#         sample_index      eid    E01    E02    E03    E04    E05    E06  \
# 0                  0  5895328  False  False  False  False  False  False
# 1                  1  5764375  False  False  False  False  False  False
# 2                  2  5503073  False  False  False  False  False  False
# 3                  3  2563626  False  False  False  False  False  False
# 4                  4  4980832  False  False  False  False  False  False
# ...              ...      ...    ...    ...    ...    ...    ...    ...
# 333627        502513  2243883  False  False  False  False  False  False
# 333628        502515  3570729  False  False  False  False  False  False
# 333629        502516  1663456  False  False  False  False  False  False
# 333630        502517  3118989  False  False  False  False  False  False
# 333631        502519  4573284  False  False  False  False  False  False
#
#           E07  E01_F  ... E03_F_reduced E03_M_reduced E04_F_reduced  \
# 0       False    NaN  ...           NaN           0.0           NaN
# 1       False  False  ...           0.0           NaN           0.0
# 2       False    NaN  ...           NaN           0.0           NaN
# 3       False    NaN  ...           NaN           0.0           NaN
# 4       False    NaN  ...           NaN           0.0           NaN
# ...       ...    ...  ...           ...           ...           ...
# 333627  False    NaN  ...           NaN           0.0           NaN
# 333628  False    NaN  ...           NaN           0.0           NaN
# 333629  False    NaN  ...           NaN           0.0           NaN
# 333630  False  False  ...           0.0           NaN           0.0
# 333631  False  False  ...           0.0           NaN           0.0
#
#        E04_M_reduced E05_F_reduced E05_M_reduced E06_F_reduced E06_M_reduced  \
# 0                0.0           NaN           0.0           NaN           0.0
# 1                NaN           0.0           NaN           0.0           NaN
# 2                0.0           NaN           0.0           NaN           0.0
# 3                0.0           NaN           0.0           NaN           0.0
# 4                0.0           NaN           0.0           NaN           0.0
# ...              ...           ...           ...           ...           ...
# 333627           0.0           NaN           0.0           NaN           0.0
# 333628           0.0           NaN           0.0           NaN           0.0
# 333629           0.0           NaN           0.0           NaN           0.0
# 333630           NaN           0.0           NaN           0.0           NaN
# 333631           NaN           0.0           NaN           0.0           NaN
#
#        E07_F_reduced E07_M_reduced
# 0                NaN           0.0
# 1                0.0           NaN
# 2                NaN           0.0
# 3                NaN           0.0
# 4                NaN           0.0
# ...              ...           ...
# 333627           NaN           0.0
# 333628           NaN           0.0
# 333629           NaN           0.0
# 333630           0.0           NaN
# 333631           0.0           NaN
#
# [333632 rows x 212 columns]
