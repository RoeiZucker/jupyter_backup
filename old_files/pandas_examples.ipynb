# %%
import pandas as pd

# %% [markdown]
# # remove caucasion from df

# %%
full_df = pd.read_csv("/cs/labs/michall/roeizucker/non_caucasian_run/ukbb_dataset.csv")
only_caucasion = pd.read_csv("/cs/labs/michall/roeizucker/non_caucasian_run/ukbb_dataset2.csv")

# %%
non_caucasion = full_df[~full_df.eid.isin(only_caucasion["eid"])]

# %%
non_caucasion
# Out:
#         sample_index      eid  F329  F329_F  F329_M  H26  H26_F  H26_M  H269  \
# 5                  5  5427659   0.0     0.0     NaN  0.0    0.0    NaN   0.0
# 9                 11  5761858   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 10                13  1842631   NaN     NaN     NaN  NaN    NaN    NaN   NaN
# 12                15  4347495   0.0     0.0     NaN  0.0    0.0    NaN   0.0
# 13                16  1110672   1.0     NaN     1.0  0.0    NaN    0.0   0.0
# ...              ...      ...   ...     ...     ...  ...    ...    ...   ...
# 400686        502463  5445956   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 400691        502471  3226893   NaN     NaN     NaN  NaN    NaN    NaN   NaN
# 400709        502495  1210318   0.0     NaN     0.0  0.0    NaN    0.0   0.0
# 400714        502500  3814605   0.0     0.0     NaN  0.0    0.0    NaN   0.0
# 400717        502505  2031201   0.0     0.0     NaN  0.0    0.0    NaN   0.0
#
# ...

# %%
non_caucasion.to_csv("/cs/labs/michall/roeizucker/non_caucasian_run/ukbb_dataset_non_caucasion.csv")

# %%
for i in range(17597,17780):
    print(f"${i}", end=' "," ')
# Out:
# $17597 "," $17598 "," $17599 "," $17600 "," $17601 "," $17602 "," $17603 "," $17604 "," $17605 "," $17606 "," $17607 "," $17608 "," $17609 "," $17610 "," $17611 "," $17612 "," $17613 "," $17614 "," $17615 "," $17616 "," $17617 "," $17618 "," $17619 "," $17620 "," $17621 "," $17622 "," $17623 "," $17624 "," $17625 "," $17626 "," $17627 "," $17628 "," $17629 "," $17630 "," $17631 "," $17632 "," $17633 "," $17634 "," $17635 "," $17636 "," $17637 "," $17638 "," $17639 "," $17640 "," $17641 "," $17642 "," $17643 "," $17644 "," $17645 "," $17646 "," $17647 "," $17648 "," $17649 "," $17650 "," $17651 "," $17652 "," $17653 "," $17654 "," $17655 "," $17656 "," $17657 "," $17658 "," $17659 "," $17660 "," $17661 "," $17662 "," $17663 "," $17664 "," $17665 "," $17666 "," $17667 "," $17668 "," $17669 "," $17670 "," $17671 "," $17672 "," $17673 "," $17674 "," $17675 "," $17676 "," $17677 "," $17678 "," $17679 "," $17680 "," $17681 "," $17682 "," $17683 "," $17684 "," $17685 "," $17686 "," $17687 "
# ...
